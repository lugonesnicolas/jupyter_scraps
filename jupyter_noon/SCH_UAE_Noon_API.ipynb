# %%
import requests
from random import choice

# %%
url = 'https://www.noon.com/_svc/catalog/api/v3/u/search/?q=lays'

# %%
headers = {
  'authority': 'www.noon.com',
  'accept': 'application/json, text/plain, /',
  'accept-language': 'en-US,en;q=0.9',
  'cookie': 'nloc=en-ae; visitor_id=3267c39a-e696-4a80-9df2-0c03adaaee63; _gcl_aw=GCL.1709045261.EAIaIQobChMI88D3q-HLhAMVtZGDBx0HkAkyEAAYASAAEgJdpvD_BwE; _gcl_au=1.1.710803922.1709045261; __rtbh.lid=%7B%22eventType%22%3A%22lid%22%2C%22id%22%3A%22H6KSnbiGCiTQr9LW4dhJ%22%7D; _ga=GA1.2.283034145.1709045283; _gid=GA1.2.1571097066.1709045283; _scid=a13d6a14-4c65-46af-9f30-6771f6fc4d71; _ym_uid=1709045283770148733; _ym_d=1709045283; __rtbh.uid=%7B%22eventType%22%3A%22uid%22%2C%22id%22%3Anull%7D; _fbp=fb.1.1709045283686.2128396882; _tt_enable_cookie=1; _ttp=YXro6juiwWPPS6YCeokzbXLv4IU; _clck=10xutt%7C2%7Cfjm%7C0%7C1518; _sctr=1%7C1708992000000; __zlcmid=1KWmWrx22LiRryh; _gac_UA-84507530-14=1.1709045396.EAIaIQobChMI88D3q-HLhAMVtZGDBx0HkAkyEAAYASAAEgJdpvD_BwE; x-available-ae=ecom-food-nooninstant-daily; dcae=1; x-location-ecom-ae=eyJsYXQiOiAyNTEwMTMzMDEsICJsbmciOiA1NTE1ODIxMzQsICJhcmVhIjogIkQ5NCAtIEFsIFN1Zm91aCAtIER1YmFpIC0gRHViYWkifQ; x-lat=251013301; x-lng=551582134; __gads=ID=e68396953ab7428c:T=1709045917:RT=1709056011:S=ALNI_MaAnOTAgTLqqJ13wndkbqtdnGE5fw; __gpi=UID=00000d3324a4520f:T=1709045917:RT=1709056011:S=ALNI_MZO3gCr4VS6nWG6GOQXk6YkWqCljQ; __eoi=ID=39be49001643e36c:T=1709056011:RT=1709056011:S=AA-AfjauuZ-0Tm18sEZke30jT1sE; bm_mi=700A0D34DAD740A6E64F631547EBC132~...~1; ak_bmsc=637451A8FEA95CDBAE653916F89BEC76~000000000000000000000000000000~...; _scid_r=a13d6a14-4c65-46af-9f30-6771f6fc4d71; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiJmMmQyOTY2MmY1YTc0ZThhYjFkNTYwMTVlYjdhNTg4NiIsImlhdCI6MTcwOTA2MDE4NCwiZXhwIjoxNzA5MDYwNDg0fQ.XaiNBmOTFWjMLLqYkVxKhLMi4Lc47dC27g9gtYSk3DA; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiI0MDI5YjlhYmI0MDI0ZDU2YTdkOWJmNjg1NmM4NmNjNiIsImlhdCI6MTcwOTA2MDE4NCwiZXhwIjoxNzA5MDYwNDg0fQ.G2l39F-XetIIehCZQgmNC5jGW9wOjdIrVP1Ubg9anMQ; _gat_UA-84507530-14=1; review_lang=xx; AKA_A2=A; _clsk=1otolye%7C1709060192041%7C3%7C0%7Cy.clarity.ms%2Fcollect; RT="z=1&dm=noon.com&si=bp4d8cyeu0v&ss=lt4o8ckn&sl=0&tt=0"; _etc=f7QUxIvD25DSSDpL; _uetsid=35c7c130d57f11eea7c1c58c3b2547b0; _uetvid=35c7ff40d57f11eea2b9d326f5987445; bm_sv=C9914782F7541D83934ACB0EBBA314D7~YAAQlidzaFj3x82NAQAACWDt6xYteS/Rb5DyVXqQObMrU04m1huVdbqL/jBNPMpb7BXV+5HxdQaNChFE/Di3HO9yScqD297yhp2PvyGlpbtbYI7g9s0QnjbpV0QuZszQGWqIFbnyGj1+OvV86sYd8nvA9t/fxKfS8W0fp78OVcB12CRVNR5Y0MoPTDydbLM30PyiPIcQUy8//437R0oGKL/5W+xVE4Ff+ua5bcVFhVh7gCXK1mj5n83NIAXSsVA=~1; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiIwMzQ0NDZiZTM3ZGU0ODE5YmZmODdhMDA2ZjQ2NjFhZSIsImlhdCI6MTcwOTMwNTg5MCwiZXhwIjoxNzA5MzA2MTkwfQ.ypNfcNj7667CC36S6eCPhYj9w3C-no2hAopAphUi1No; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiJiYWM0NDZjNjNhMGQ0YjY3YjE5ZDlhMDNjNjg5NTQ1OSIsImlhdCI6MTcwOTA0Nzc5MiwiZXhwIjoxNzA5MDQ4MDkyfQ.d_wxgHplxK11Y-lDTjWYfEl0LXR-_8SLgTfyJ8gZb9k',
  'referer': 'https://www.noon.com/automatic-powder-original-scent-white-2-5kg/Z6FCD511DD0D5F4D033E2Z/p/?o=z6fcd511dd0d5f4d033e2z-1',
  'sec-ch-ua': '"Chromium";v="122", "Not(A:Brand";v="24", "Google Chrome";v="122"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
  'x-aby': '{"hplp_fashion.enabled":1,"mid_roll_filters.enabled":1,"noon_pass.enabled":1,"otp_login.enabled":1,"pdp_bos.enabled":1,"pdp_flyout.flyout_value":0,"plp_revamp_v3.enabled":1,"tag_nudge.enabled":1}',
  'x-cms': 'v3',
  'x-content': 'desktop',
  'x-daily-zonecode': 'AE-DXB-NAKHEELOFFICE',
  'x-ecom-zonecode': 'AE_DXB-S1',
  'x-food-zonecode': 'FOOD-AE-DXB-HUB4-GREENS',
  'x-lat': '251013301',
  'x-lng': '551582134',
  'x-locale': 'en-ae',
  'x-mp': 'noon',
  'x-nooninstant-zonecode': 'W00000122A',
  'x-platform': 'web',
  'x-rocket-zonecode': 'W00067526A',
  'x-visitor-id': '3267c39a-e696-4a80-9df2-0c03adaaee63'
}

# %%
response = requests.get(url, headers=headers)
data_json = response.json()
data_grid = data_json.get('hits', None)
print(f"{data_grid[1]}")
# Out:
# {'offer_code': 'da21ae03175d099c', 'sku': 'N25262102A', 'sku_config': 'N25262102A', 'brand': "Lay's", 'name': 'French Cheese 21grams Pack of 12 ', 'plp_specifications': {'Item Pack Quantity': 'Pack of 12'}, 'price': 14.5, 'sale_price': 12, 'url': 'french-cheese-21grams-pack-of-12', 'image_key': 'v1656932501/N25262102A_1', 'is_buyable': True, 'stock_minimum_quantity': 1, 'product_badges': [], 'show_3d': False, 'plp_product_group_code': 'N25262102A', 'image_keys': ['v1656932501/N25262102A_1', 'v1656932501/N25262102A_2', 'v1656932500/N25262102A_3', 'v1628443835/N25262102A_15'], 'attributes': ['item_pack_quantity', 'shelf_life'], 'is_collection_eligible': False, 'product_rating': {'value': 4, 'count': 3, 'best_rating': 2}, 'flags': ['fbn', 'free_delivery_eligible', 'grocery', 'quick_atc'], 'free_delivery_text': 'Free Delivery above AED 100', 'is_bestseller': False, 'instant': {'sku': 'Z666F0BF4F6B055340C05Z-1', 'price': 15.1, 'sale_price': 12, 'estimation_text': 'Get in 15 MINS', 'link_u
# ...

# %%
count = 1
for product in data_grid[0:50]:# Recorremos 20 indices
    title = product.get('name', '')
    sku = product.get('sku', '')
    brand = product.get('brand', '')
    stock = 1 if product.get('is_buyable', '') == True else 0
    old_price = product.get('price', 0)
    final_price = product.get('sale_price', 0)
    is_freebie = product.get('is_freebie', '')
    if final_price == 0 or final_price == None and old_price != 0:
                                 final_price = old_price
                                 old_price = 0    
    url = product.get('url', '')
    product_rating = product.get('product_rating', '')
    # bestseller = product.get('is_bestseller', '')
    bestseller = product.get('is_bestseller', '')
    print(f"Title:{title}")
    print(f"SKU:{sku}")
    print(f"Brand:{brand}")
    print(f"Stock:{stock}")
    print(f"OldPrice:{old_price}")
    print(f"FinalPrice:{final_price}")
    print(f"URL:{url}")
    print(f"ProductRating:{product_rating}")
    print(f"BestSeller:{bestseller}")
    print(f"IsFreebie:{is_freebie}")
    print(f"Producto:{count}\n")
    count += 1
# Out:
# Title:American Style Cream And Onion Chips Indian Import 90grams
# SKU:N52093662A
# Brand:Lay's
# Stock:1
# OldPrice:5.9
# FinalPrice:4.5
# URL:american-style-cream-and-onion-chips-indian-import-90grams
# ProductRating:{'value': 3.9, 'count': 7, 'best_rating': 2.4}
# BestSeller:True
# IsFreebie:False
# Producto:1
#
# Title:French Cheese 21grams Pack of 12
# SKU:N25262102A
# Brand:Lay's
# Stock:1
# OldPrice:14.5
# FinalPrice:12
# URL:french-cheese-21grams-pack-of-12
# ProductRating:{'value': 4, 'count': 3, 'best_rating': 2}
# BestSeller:False
# IsFreebie:False
# Producto:2
#
# Title:Magic Masala Chips Indian Import Special South Flavour 90grams
# SKU:N52093661A
# Brand:Lay's
# Stock:1
# OldPrice:5.9
# FinalPrice:4.5
# URL:magic-masala-chips-indian-import-special-south-flavour-90grams
# ProductRating:{'value': 5, 'count': 2, 'best_rating': 2.4}
# BestSeller:False
# IsFreebie:False
# Producto:3
#
# Title:Salt Chips 21grams Pack of 12
# SKU:N25262101A
# Brand:Lay's
# Stock:1
# ...
