# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
url = 'https://www.carrefouruae.com/mafuae/en/v4/search?keyword=tvs'

# %%
payload = {}
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:123.0) Gecko/20100101 Firefox/123.0',
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
  'Accept-Language': 'es-AR,es;q=0.8,en-US;q=0.5,en;q=0.3',
  'Accept-Encoding': 'gzip, deflate, br',
  'Connection': 'keep-alive',
  'Cookie': 'cart_api=v2; _abck=59F693FA2C262E4EB9B6DF0D13FE55B8~0~...~-1~-1~-1; storeInfo=mafuae|en|AED; OptanonConsent=isGpcEnabled=1&datestamp=Tue+Mar+19+2024+11%3A37%3A04+GMT-0300+(hora+est%C3%A1ndar+de+Argentina)&version=202301.2.0&hosts=&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&consentId=ccb02f39-f0b2-4416-b38b-a3192a1b75c6&landingPath=NotLandingPage; mafuae-web-preferred-delivery-area="Dubai Festival City - Dubai"; ab.storage.sessionId.e6577fac-30b0-4270-a5df-788ef16dc4cd=%7B%22g%22%3A%220e04a7eb-c8cc-972e-4668-ee26f7f07c7a%22%2C%22e%22%3A1710860822264%2C%22c%22%3A1710859022048%2C%22l%22%3A1710859022264%7D; guest-session-token=aOTnKRB7qXnobya0Pn_-DppGGlE; _gcl_au=1.1.885303438.1710425902; OptanonAlertBoxClosed=2024-03-14T14:42:37.947Z; lat=25.183604; long=55.40198700000001; mafuae-cart=eb38b524-f52f-493b-a815-1aa49d1ef3f5; mafuae-preferred-delivery-area=5CM2%2BCR3%20-%20Al%20Warqa%20 - %20Al%20Warqa%201%20; prevAreaCode=5CM2%2BCR3%20-%20Al%20Warqa%20 - %20Al%20Warqa%201%20; maf-session-id=982F8D31-79B7-9E28-DE0B-4A1AB4730E8B; hideCoachMark=true; AKA_A2=A; ak_bmsc=1BF0653CF2B36E6B711B3BBE402E24E7~000000000000000000000000000000~...; bm_sz=2B314C125A28A0FBFB0808B10AC32880~...~3491395~3424567; page_type=productsearch; app_version=v4; bm_sv=9B870D5819BA421950F96774F2A2DC78~~1; _abck=59F693FA2C262E4EB9B6DF0D13FE55B8~-1~...~0~-1~-1; bm_sv=9B870D5819BA421950F96774F2A2DC78~~1; cart_api=v2; storeInfo=mafuae|en|AED',
  'Upgrade-Insecure-Requests': '1',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'none',
  'Sec-Fetch-User': '?1',
  'Sec-GPC': '1',
  'TE': 'trailers'
}

# %%
response = requests.request("GET", url, headers=headers)
html = response.text

# %%
soup = BeautifulSoup(html, "html.parser")
data_grid = soup.find(id="__NEXT_DATA__").text
data_grid = json.loads(data_grid)
products = data_grid["props"]["initialState"]["search"]["products"]

# %%
# print(products[1])

# %%
count=1
for product in products[0:20]:
    title = product.get('name', '')
    brand = product.get('brand', '')
    promotion = product.get('discount', '')
    sku = product.get('productId', '')
    old_price = product.get('originalPrice', 0)
    final_price = product.get('applicablePrice', 0)
    stock = 0 if product.get('isAvailable',0) == None else 1
    link = product.get('url', '')
    url = f"https://www.carrefouruae.com{link}"
    supplier = product.get('supplier', '')
    print(f"Title:{title}")
    print(f"Brand:{brand}")
    print(f"Promotion:{promotion}")
    print(f"SKU:{sku}")
    print(f"OldPrice:{old_price}")
    print(f"FinalPrice:{final_price}")
    print(f"Stock:{stock}")
    print(f"URL:{url}")
    print(f"Supplier:{supplier}")
    print(f"Producto:{count}\n")
    count += 1
# Out:
# Title:Samsung Smart TV, Crystal UHD, CU7000C, 65 Inch, Black, 2023, Crystal Processor 4K, Smart Hub, Object Tracking Sound Lite, UA65CU7000UXZN
# Brand:Samsung
# Promotion:{'price': 1669.75, 'type': 'percentage', 'value': 27, 'minBuyingValue': '1669.75'}
# SKU:1935455
# OldPrice:2299
# FinalPrice:1669.75
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/uhd-tv/samsung-uhd-tv-65-ua65cu7000uxzn/p/1935455
# Supplier:MSGT
# Producto:1
#
# Title:Samsung Smart TV, QLED, Q60C, 65 Inch, Titan Gray, 2023, Quantum Dot, HDR10+, AirSlim, Smart Hub, QA65Q60CAUXZN
# Brand:Samsung
# Promotion:{'price': 0, 'type': 'none', 'value': 0, 'minBuyingValue': ''}
# SKU:1935459
# OldPrice:2294.98
# FinalPrice:2294.98
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/qled-qned-tv/samsung-qled-4k-65-qa65q60cauxzn/p/1935459
# Supplier:Emirates Retail
# Producto:2
#
# Title:Samsung Smart TV, Crystal UHD 4K, CU7000, 55 Inch, Black, 2023, Crystal Processor 4K, PurColor, Smart Hub, UA55CU7000UXZN
# Brand:Samsung
# Promotion:{'price': 1499, 'type': 'percentage', 'value': 25, 'minBuyingValue': '1499.00'}
# SKU:8806094850123
# OldPrice:1999
# FinalPrice:1499.00
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/uhd-tv/samsung-smart-tv-crystal-uhd-4k-cu7000-55-inch-black-2023-crystal-processor-4k-purcolor-smart-hub-ua55cu7000uxzn/p/8806094850123
# Supplier:MSGT
# Producto:3
#
# Title:Samsung Smart TV, QLED, Q60C, 55 Inch, Titan Gray, 2023, Quantum Dot, HDR10+, AirSlim, Smart Hub, QA55Q60CAUXZN
# Brand:Samsung
# Promotion:{'price': 1748.11, 'type': 'percentage', 'value': 50, 'minBuyingValue': '1748.11'}
# SKU:1935458
# OldPrice:3499
# FinalPrice:1748.11
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/qled-qned-tv/samsung-qled4k-55-qa55q60cauxzn/p/1935458
# Supplier:MSGT
# Producto:4
#
# Title:Samsung Smart TV, Crystal UHD 4K, CU7000, 55 Inch, Black, 2023, Crystal Processor 4K, PurColor, Smart Hub, UA55CU7000UXZN
# Brand:Samsung
# Promotion:{'price': 1499, 'type': 'percentage', 'value': 40, 'minBuyingValue': '1499.00'}
# SKU:1938752
# OldPrice:2499
# FinalPrice:1499.00
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/uhd-tv/samsung-uhd-tv-55-ua55cu7000uxzn/p/1938752
# Supplier:MSGT
# Producto:5
#
# Title:Samsung Smart TV, Crystal UHD, CU7000C, 70 Inch, Black, 2023, Crystal Processor 4K, Smart Hub, Object Tracking Sound Lite, UA70CU7000UXZN
# Brand:Samsung
# Promotion:{'price': 2437.8, 'type': 'percentage', 'value': 42, 'minBuyingValue': '2437.80'}
# SKU:8806094850840
# OldPrice:4199
# FinalPrice:2437.80
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/uhd-tv/samsung-smart-tv-crystal-uhd-cu7000c-70-inch-black-2023-crystal-processor-4k-smart-hub-object-tracking-sound-lite-ua70cu7000uxzn/p/8806094850840
# Supplier:MSGT
# Producto:6
#
# Title:Samsung Smart TV, QLED, Q60C, 75 Inch, 2023, Quantum Dot, HDR10+, AirSlim, Smart Hub, QA75Q60CAUXZN, Titan Gray
# Brand:Samsung
# Promotion:{'price': 3621.05, 'type': 'percentage', 'value': 40, 'minBuyingValue': '3621.05'}
# SKU:8806094785166
# OldPrice:5999
# FinalPrice:3621.05
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/qled-qned-tv/samsung-smart-tv-qled-q60c-75-inch-2023-quantum-dot-hdr10-airslim-smart-hub-qa75q60cauxzn-titan-gray/p/8806094785166
# Supplier:MSGT
# Producto:7
#
# Title:Samsung Smart TV, Crystal UHD 4K, CU8000, 65 Inch, 2023, Crystal Processor 4K, Airslim, Dynamic Crystal Color, UA65CU8000UXZN, Titan Gray
# Brand:Samsung
# Promotion:{'price': 1828.59, 'type': 'percentage', 'value': 39, 'minBuyingValue': '1828.59'}
# SKU:8806094850833
# OldPrice:2999
# FinalPrice:1828.59
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/uhd-tv/samsung-smart-tv-crystal-uhd-4k-cu8000-65-inch-2023-crystal-processor-4k-airslim-dynamic-crystal-color-ua65cu8000uxzn-titan-gray/p/8806094850833
# Supplier:MSGT
# Producto:8
#
# Title:Samsung Smart TV, QLED, Q70C, 65 Inch Titan Gray, 2023, Quantum Processor 4K, Motion Enhancemnet, HDR10+, QA65Q70CAUXZN
# Brand:Samsung
# Promotion:{'price': 0, 'type': 'none', 'value': 0, 'minBuyingValue': ''}
# SKU:1935460
# OldPrice:2799.48
# FinalPrice:2799.48
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/qled-qned-tv/samsung-qled-4k-65-qa65q70cauxzn/p/1935460
# Supplier:Emirates Retail
# Producto:9
#
# Title:LG 65-Inch 4K Smart OLED evo TV G3 Black
# Brand:LG
# Promotion:{'price': 6998.99, 'type': 'percentage', 'value': 53, 'minBuyingValue': '6998.99'}
# SKU:1946835
# OldPrice:14999
# FinalPrice:6998.99
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/oled-tv/lg-oled-tv-65-g3/p/1946835
# Supplier:MSGT
# Producto:10
#
# Title:Samsung Smart TV, Crystal UHD 4K, CU7000, 50 Inch, Black, 2023, Crystal Processor 4K, PurColor, Smart Hub, UA50CU7000UXZN
# Brand:Samsung
# Promotion:{'price': 1295.8, 'type': 'percentage', 'value': 19, 'minBuyingValue': '1295.80'}
# SKU:8806094850857
# OldPrice:1599
# FinalPrice:1295.80
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/uhd-tv/samsung-smart-tv-crystal-uhd-4k-cu7000-50-inch-black-2023-crystal-processor-4k-purcolor-smart-hub-ua50cu7000uxzn/p/8806094850857
# Supplier:MSGT
# Producto:11
#
# Title:Samsung Smart TV, QLED, Q70C, 85 Inch Titan Gray, 2023, Quantum Processor 4K, Motion Enhancemnet, HDR10+, QA85Q70CAUXZN
# Brand:Samsung
# Promotion:{'price': 5979.44, 'type': 'percentage', 'value': 46, 'minBuyingValue': '5979.44'}
# SKU:1935461
# OldPrice:10999
# FinalPrice:5979.44
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/qled-qned-tv/samsung-qled-4k-85-qa85q70cauxzn/p/1935461
# Supplier:MSGT
# Producto:12
#
# Title:Philips 55-Inch 4K UHD LED Android TV 55PUT7406 Black
# Brand:Philips
# Promotion:{'price': 1389, 'type': 'percentage', 'value': 13, 'minBuyingValue': '1389.00'}
# SKU:1858885
# OldPrice:1589
# FinalPrice:1389.00
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/uhd-tv/philips-4k-uhd-android-5555put7406/p/1858885
# Supplier:Carrefour
# Producto:13
#
# Title:Samsung Smart TV, Neo QLED 4K, QN90C, 55 Inch, 2023, Neural Quantum Processor 4K, Anti Reflection, OTS+, QA55QN90CAUXZN, Carbon Silver
# Brand:Samsung
# Promotion:{'price': 3848.99, 'type': 'percentage', 'value': 23, 'minBuyingValue': '3848.99'}
# SKU:8806094860955
# OldPrice:4999
# FinalPrice:3848.99
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/qled-qned-tv/samsung-smart-tv-neo-qled-4k-qn90c-55-inch-2023-neural-quantum-processor-4k-anti-reflection-ots-qa55qn90cauxzn-carbon-silver/p/8806094860955
# Supplier:DOCTOR TV
# Producto:14
#
# Title:Samsung S95C 65-Inch OLED 4K Smart TV QA65S95CAUXZN Black
# Brand:Samsung
# Promotion:{'price': 6999, 'type': 'percentage', 'value': 16, 'minBuyingValue': '6999.00'}
# SKU:1935442
# OldPrice:8299
# FinalPrice:6999.00
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/oled-tv/samsung-oled-4k-65-qa65s95cauxzn/p/1935442
# Supplier:Jackys Electronics Nasser Square
# Producto:15
#
# Title:Samsung Smart TV, QLED, Q60C, 85 Inch, 2023, Quantum Dot, HDR10+, AirSlim, Smart Hub, QA85Q60CAUXZN, Titan Gray
# Brand:Samsung
# Promotion:{'price': 5181.1, 'type': 'percentage', 'value': 60, 'minBuyingValue': '5181.10'}
# SKU:8806094785197
# OldPrice:12999
# FinalPrice:5181.10
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/qled-qned-tv/samsung-smart-tv-qled-q60c-85-inch-2023-quantum-dot-hdr10-airslim-smart-hub-qa85q60cauxzn-titan-gray/p/8806094785197
# Supplier:MSGT
# Producto:16
#
# Title:Samsung Smart TV, Crystal UHD, CU7000C, 75 Inch, Black, 2023, Crystal Processor 4K, Smart Hub, Object Tracking Sound Lite, UA75CU7000UXZN
# Brand:Samsung
# Promotion:{'price': 2755, 'type': 'percentage', 'value': 39, 'minBuyingValue': '2755.00'}
# SKU:1935456
# OldPrice:4499
# FinalPrice:2755.00
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/uhd-tv/samsung-uhd-tv-75-ua75cu7000uxzn/p/1935456
# Supplier:DOCTOR TV
# Producto:17
#
# Title:LG OLED Evo TV 65-Inch C2 Series, Cinema Screen Design 4K Cinema HDR Webos22 With Thinq AI Pixel Dimming OLED65C26La, Black
# Brand:LG
# Promotion:{'price': 4879, 'type': 'percentage', 'value': 39, 'minBuyingValue': '4879.00'}
# SKU:1886918
# OldPrice:7999
# FinalPrice:4879.00
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/oled-tv/lg-oled-tv-65-c2/p/1886918
# Supplier:Taj Online UAE
# Producto:18
#
# Title:Samsung QN900C 85-Inch Neo QLED 8K Smart TV QA85QN900CUXZN Black
# Brand:Samsung
# Promotion:{'price': 26098.99, 'type': 'percentage', 'value': 42, 'minBuyingValue': '26098.99'}
# SKU:1935435
# OldPrice:44999
# FinalPrice:26098.99
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/qled-qned-tv/samsung-8k-tv-85-qa85qn900cuxzn/p/1935435
# Supplier:MSGT
# Producto:19
#
# Title:Samsung  85 Inch Smart TV QLED 4K Q60B Quantum HDR Object Tracking Sound Lite Black (2022)
# Brand:Samsung
# Promotion:{'price': 5091.58, 'type': 'percentage', 'value': 36, 'minBuyingValue': '5091.58'}
# SKU:1877770
# OldPrice:7999
# FinalPrice:5091.58
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/qled-qned-tv/samsung-qled-tv-85-qa85q60bauxzn/p/1877770
# Supplier:MSGT
# Producto:20
