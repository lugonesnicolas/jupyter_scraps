# %%
import requests
import re
from bs4 import BeautifulSoup
import time

# %%
url = 'https://www.amazon.ae/TOSHIBA-Long-lasting-Vibration-resistance-Alkaline/dp/B07WRTHKRN/ref=sr_1_1?crid=23392WD8W866G&dib=eyJ2IjoiMSJ9.Kf6ngJmZdEbQ0WSYJ9Z9ig._Nn91QtQS-xujxKSNjFXSAzCI_4vLwVNEYGIVmwuH6E&dib_tag=se&keywords=B07WRTHKRN&qid=1709646998&sprefix=b07wrthkrn%2Caps%2C262&sr=8-1&th=1'

# %%
url = 'https://www.amazon.ae/dp/B0839X3NZH/ref=syn_sd_onsite_desktop_0?ie=UTF8&psc=1&pd_rd_plhdr=t&aref=wTa3cmYa7B'

# %%
url = 'https://www.amazon.ae/Ariel-Automatic-Laundry-Detergent-Original/dp/B076L3PYX6/ref=sr_1_1_f3_0o_lulu?dib=eyJ2IjoiMSJ9.0km0ra4b8e1MpGPtWDvXOw.QWzWTfcnWFY2AoUWRnvf5sdvhfdcy0b3ojKgc_TwtvA&dib_tag=se&keywords=B076L3PYX6&qid=1708098279&sr=8-1'

# %%
payload = {}

# %%
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:123.0) Gecko/20100101 Firefox/123.0',
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
  'Accept-Language': 'es-AR,es;q=0.8,en-US;q=0.5,en;q=0.3',
  'Accept-Encoding': 'gzip, deflate, br',
  'Alt-Used': 'www.amazon.ae',
  'Connection': 'keep-alive',
  'Cookie': 'session-id=257-2861550-0109024; session-id-time=2082787201l; i18n-prefs=AED; csm-hit=tb:66MHB1N659SQMYKBDPHY+s-66MHB1N659SQMYKBDPHY|1709900943401&t:1709900943401&adb:adblk_yes; ubid-acbae=257-3832480-6790808; session-token=; lc-acbae=en_AE; ld=AZAESOA_pcdisc_C; s_pers=%20s_fid%3D3504FFD318A2EA58-3D892D2C174744DD%7C1866804897117%3B%20s_dl%3D1%7C1708953897117%3B%20gpv_page%3DAZ%253ASD%253ASOA-home%7C1708953897118%3B%20s_ev15%3D%255B%255B%2527AZAESOA_pcdisc_C%2527%252C%25271708952097118%2527%255D%255D%7C1866804897118%3B; session-token=',
  'Upgrade-Insecure-Requests': '1',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'cross-site',
  'Sec-Fetch-User': '?1',
  'Sec-GPC': '1',
  'TE': 'trailers'
}

# %%
response = requests.request("GET", url, headers=headers, data=payload)
html_content = response.text
soup = BeautifulSoup(html_content, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-ae"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %%
stock_string =

# %%
stock_string = soup.select_one("#fod-cx-box > div:nth-child(1) > span:nth-child(1)").text if soup.select_one("#fod-cx-box > div:nth-child(1) > span:nth-child(1)") != None else ''
if stock_string == '':
    stock_string = soup.find("div", id="availability").text if soup.find("div", id="availability") != None else ''

if stock_string == '':
    stock_string = soup.select_one("#availability-string").text if soup.select_one("#availability-string") != None else ''

stock_string = stock_string.strip() if stock_string != '' else ''

print(f"---- StockString: {stock_string}")
# Out:
# ---- StockString: In Stock

# %%
#Capturo el elemento que tiene el contenido
best_sellers_rank_container = soup.find('#productDetails_detailBullets_sections1 > tr:nth-child(3) > td:nth-child(2) > span:nth-child(1)')
#Si el elemento no tiene Customer Reviews cambia el selector
if best_sellers_rank_container == []:
    best_sellers_rank_container = soup.find('#productDetails_detailBullets_sections1 > tr:nth-child(2) > td:nth-child(2) > span:nth-child(1)')
if best_sellers_rank_container == None or best_sellers_rank_container == []:
    best_sellers_rank_container = soup.find('#productDetails_detailBullets_sections1 > tr > td > span')

    
try:
    if best_sellers_rank_container != None:
        #Extraigo el contenido como lista de elementos
        best_sellers_rank_element = best_sellers_rank_container.find("span span")
        
        #Extraigo solamente el contenido de cada elemento
        best_sellers_rank_content = []
        if best_sellers_rank_element:
            for i in best_sellers_rank_element:
                pattern = r">([^<]+)<"
                matches = re.findall(pattern, i.extract(), re.DOTALL)
                cadena = "".join(matches)
                best_sellers_rank_content.append(cadena)
            
            #print(f"El elemento best_sellers_rank_container:{best_sellers_rank_content}")# Print para testear el elemento  
            
        if len(best_sellers_rank_content) == 3:
            catgroup_best_sellers_rank = best_sellers_rank_content[0]
            # category_best_sellers_rank = f"{best_sellers_rank_content[1]}, {best_sellers_rank_content[2]}"
            category_best_sellers_rank = f"{best_sellers_rank_content[1]}"
        else:
            catgroup_best_sellers_rank = best_sellers_rank_content[0]
            category_best_sellers_rank = best_sellers_rank_content[1]
    #Elimino (See Top 100 in Grocery) de la cadena
    category_best_sellers_rank = re.sub(r"[^\d]", "", category_best_sellers_rank)
    catgroup_best_sellers_rank = re.sub(r"\(.*?\)", "", catgroup_best_sellers_rank)
    catgroup_best_sellers_rank = re.sub(r"[^\d]", "", catgroup_best_sellers_rank)

except:
    catgroup_best_sellers_rank = ""
    category_best_sellers_rank = ""
    print(f"ADVERTENCIA No se pudo extraer Best Selle Rank")

if best_sellers_rank_container == None or best_sellers_rank_container == []:
    best_sellers_list = soup.select_one('ul.a-unordered-list:nth-child(4) > li:nth-child(1) > span:nth-child(1)').text
    best_sellers_list = re.findall(r"#(\d+)", best_sellers_list)
    catgroup_best_sellers_rank = best_sellers_list[0]
    category_best_sellers_rank = best_sellers_list[1]
    
a_plus = 1 if soup.find('div', id='aplus') != None else 0
bullet_points = ''
bullet_points_list = soup.find(class_='a-unordered-list a-vertical a-spacing-mini').find_all(class_='a-spacing-mini')
for i in bullet_points_list:
    bullet_points += f"{i.text}\n"

print(f"Cat group best sellers rank: {catgroup_best_sellers_rank}")
print(f"Category best sellers rank: {category_best_sellers_rank}")
print(f"A+ content: {a_plus}")
print(f"Bullet points: {bullet_points}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 44
#      41     print(f"ADVERTENCIA No se pudo extraer Best Selle Rank")
#      43 if best_sellers_rank_container == None or best_sellers_rank_container == []:
# ---> 44     best_sellers_list = soup.select_one('ul.a-unordered-list:nth-child(4) > li:nth-child(1) > span:nth-child(1)').text
#      45     best_sellers_list = re.findall(r"#(\d+)", best_sellers_list)
#      46     catgroup_best_sellers_rank = best_sellers_list[0]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
print(catgroup_best_sellers_rank)
print(category_best_sellers_rank)

# %%
contenedor = soup.find('div', id='detailBulletsWrapper_feature_div').find_all('ul', class_='a-unordered-list a-nostyle a-vertical a-spacing-none detail-bullet-list')
contenedor =  contenedor[1].find('span' ,class_='a-list-item')
print(contenedor.text)

#productDetails_detailBullets_sections1 > tbody:nth-child(1) > tr:nth-child(1) > td:nth-child(2) > span:nth-child(1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 3
#       1 contenedor = soup.find('div', id='detailBulletsWrapper_feature_div').find_all('ul', class_='a-unordered-list a-nostyle a-vertical a-spacing-none detail-bullet-list')
#       2 contenedor =  contenedor[1].find('span' ,class_='a-list-item')
# ----> 3 print(contenedor.text)
#       5 #productDetails_detailBullets_sections1 > tbody:nth-child(1) > tr:nth-child(1) > td:nth-child(2) > span:nth-child(1)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
best_sellers = ''
for i in contenedor:
    best_sellers += f"{i.text},"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 best_sellers = ''
# ----> 2 for i in contenedor:
#       3     best_sellers += f"{i.text},"
#
# TypeError: 'NoneType' object is not iterable

# %%
a_plus = soup.find('div', class_='celwidget aplus-module module-12 aplus-standard')
print(a_plus)
# Out:
# None

# %%
bullet_points = ''
bullet_points_list = soup.find(class_='a-unordered-list a-vertical a-spacing-mini').find_all(class_='a-spacing-mini')
for i in bullet_points:
    bullet_points += f"{i.text}"

# %%
def scrap(url, headers, payload):
    response = requests.request("GET", url, headers=headers, data=payload)
    html_content = response.text
    soup = BeautifulSoup(html_content, "html.parser")
    # #Capturo el elemento que tiene el contenido
    # best_sellers_rank_container = soup.find('#productDetails_detailBullets_sections1 > tbody > tr:nth-child(3) > td:nth-child(2) > span:nth-child(1)')
    # #Si el elemento no tiene Customer Reviews cambia el selector
    # if best_sellers_rank_container == []:
    #     best_sellers_rank_container = soup.find('#productDetails_detailBullets_sections1 > tbody > tr:nth-child(2) > td:nth-child(2) > span:nth-child(1)')
    # if best_sellers_rank_container == None or best_sellers_rank_container == []:
    #     best_sellers_rank_container = soup.find('#productDetails_detailBullets_sections1 > tbody > tr > td > span')
        
    # try:
    #     if best_sellers_rank_container != None:
    #         #Extraigo el contenido como lista de elementos
    #         best_sellers_rank_element = best_sellers_rank_container.find("span span")
            
    #         #Extraigo solamente el contenido de cada elemento
    #         best_sellers_rank_content = []
    #         if best_sellers_rank_element:
    #             for i in best_sellers_rank_element:
    #                 pattern = r">([^<]+)<"
    #                 matches = re.findall(pattern, i.extract(), re.DOTALL)
    #                 cadena = "".join(matches)
    #                 best_sellers_rank_content.append(cadena)
                
    #             #print(f"El elemento best_sellers_rank_container:{best_sellers_rank_content}")# Print para testear el elemento  
                
    #         if len(best_sellers_rank_content) == 3:
    #             catgroup_best_sellers_rank = best_sellers_rank_content[0]
    #             # category_best_sellers_rank = f"{best_sellers_rank_content[1]}, {best_sellers_rank_content[2]}"
    #             category_best_sellers_rank = f"{best_sellers_rank_content[1]}"
    #         else:
    #             catgroup_best_sellers_rank = best_sellers_rank_content[0]
    #             category_best_sellers_rank = best_sellers_rank_content[1]
    #     #Elimino (See Top 100 in Grocery) de la cadena
    #     category_best_sellers_rank = re.sub(r"[^\d]", "", category_best_sellers_rank)
    #     catgroup_best_sellers_rank = re.sub(r"\(.*?\)", "", catgroup_best_sellers_rank)
    #     catgroup_best_sellers_rank = re.sub(r"[^\d]", "", catgroup_best_sellers_rank)
    
    # except:
    #     catgroup_best_sellers_rank = ""
    #     category_best_sellers_rank = ""
    #     print(f"ADVERTENCIA No se pudo extraer Best Selle Rank")
        
    contenedor = soup.find(id="productDetails_detailBullets_sections1").find('tr').find('td').find('span').find_all('span') if soup.find(id="productDetails_detailBullets_sections1") != None else ''
    best_sellers = ''
    for i in contenedor:
        best_sellers += f"{i.text},"
    a_plus = soup.find_all('div', class_='celwidget aplus-module module-12 aplus-standard')
    bullet_points = ''
    bullet_points_list = soup.find(class_='a-unordered-list a-vertical a-spacing-mini').find_all(class_='a-spacing-mini')
    for i in bullet_points_list:
        bullet_points += f"{i.text}\n"
    
    print(f"Number of items in contenedor: {len(contenedor)}")
    print(f"Best sellers: {best_sellers}")
    print(f"A+ content: {len(a_plus)}")
    print(f"Bullet points: {bullet_points}")

# %%
inicio = time.perf_counter()
for i in range(0, 1):
    scrap(url, headers, payload)
    print(f"Producto{i}")
fin = time.perf_counter()
tiempo_ejecucion = fin - inicio
print(f"Tiempo de ejecución: {tiempo_ejecucion}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 3
#       1 inicio = time.perf_counter()
#       2 for i in range(0, 1):
# ----> 3     scrap(url, headers, payload)
#       4     print(f"Producto{i}")
#       5 fin = time.perf_counter()
#
# Cell In[15], line 46, in scrap(url, headers, payload)
#       4 soup = BeautifulSoup(html_content, "html.parser")
#       5 # #Capturo el elemento que tiene el contenido
#       6 # best_sellers_rank_container = soup.find('#productDetails_detailBullets_sections1 > tbody > tr:nth-child(3) > td:nth-child(2) > span:nth-child(1)')
#       7 # #Si el elemento no tiene Customer Reviews cambia el selector
#    (...)
#      43 #     category_best_sellers_rank = ""
#      44 #     print(f"ADVERTENCIA No se pudo extraer Best Selle Rank")
# ...

# %%
best_sellers_list = soup.select_one('ul.a-unordered-list:nth-child(4) > li:nth-child(1) > span:nth-child(1)').text
print(best_sellers_list)
best_sellers_list = re.findall(r"#(\d+)", best_sellers_list)
print(best_sellers_list)
catgroup_best_sellers_rank = best_sellers_list[0]
category_best_sellers_rank = best_sellers_list[1]
print(catgroup_best_sellers_rank)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 best_sellers_list = soup.select_one('ul.a-unordered-list:nth-child(4) > li:nth-child(1) > span:nth-child(1)').text
#       2 print(best_sellers_list)
#       3 best_sellers_list = re.findall(r"#(\d+)", best_sellers_list)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:124.0) Gecko/20100101 Firefox/124.0',
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
  'Accept-Language': 'es-AR,es;q=0.8,en-US;q=0.5,en;q=0.3',
  'Accept-Encoding': 'gzip, deflate, br',
  'Referer': 'http://localhost:8888/',
  'Alt-Used': 'm.media-amazon.com',
  'Connection': 'keep-alive',
  'Upgrade-Insecure-Requests': '1',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'cross-site',
  'Sec-Fetch-User': '?1',
  'Sec-GPC': '1',
  'If-Modified-Since': 'Sat, 18 Apr 2020 06:10:49 GMT',
  'TE': 'trailers'
}

# %%
image_url = soup.find('img', id='landingImage')['src'] if soup.find('img', id='landingImage') != None else ''
print(image_url)
response_image = requests.get(image_url)

with open("imagen.jpg", "wb") as f:
    f.write(response_image.content)

print("Imagen descargada")
# Out:
# https://m.media-amazon.com/images/I/71rQyx6jqVL.__AC_SX300_SY300_QL70_ML2_.jpg
# Imagen descargada

# %% [markdown]
# # Testeo para Spider HTML

# %%
buy_box = soup.select_one('#merchantInfoFeature_feature_div > div:nth-child(2) > div:nth-child(1) > span:nth-child(1) > a:nth-child(1)').text if soup.select_one('#merchantInfoFeature_feature_div > div:nth-child(2) > div:nth-child(1) > span:nth-child(1) > a:nth-child(1)') != None else ''
if buy_box == '':
    buy_box = soup.select_one('#merchantInfoFeature_feature_div > div:nth-child(2) > div:nth-child(1) > span:nth-child(1)').text if soup.select_one('#merchantInfoFeature_feature_div > div:nth-child(2) > div:nth-child(1) > span:nth-child(1)') != None else ''
if buy_box == '':
    buy_box = soup.select_one('tr.a-spacing-micro:nth-child(2) > td:nth-child(2) > span:nth-child(1) > a:nth-child(1)').text if soup.select_one('tr.a-spacing-micro:nth-child(2) > td:nth-child(2) > span:nth-child(1) > a:nth-child(1)') != None else ''

print(f"BuyBox: {buy_box}")
# Out:
# BuyBox: LuLu

# %%
if buy_box == '' or 'Amazon.ae' not in buy_box:
    # Check if the store is transmed
    others_offer = soup.find_all('span', class_='a-size-small mbcMerchantName')# Catura para testear que lleguen los nombres
    others_offer_container = soup.find_all('div', class_='a-box-inner a-padding-small')  # Assuming class names remain the same

    # Print others_offer for debugging purposes (if needed)
    print(f"OTHERS OFFER:{[o.text.strip() for o in others_offer]}\n")

    for container in others_offer_container:
        title_store = container.find('span', class_='a-size-small mbcMerchantName').text if container.find('span', class_='a-size-small mbcMerchantName') != None else ''
        if title_store and 'Amazon.ae' in title_store.text.strip():
            final_price_element = container.find('span', class_='a-size-medium a-color-price')
            if final_price_element:
                final_price = fc.just_price(price_str=final_price_element.text.strip(), dotted_price=False)
                is_transmed = True
                break  # Exit the loop after finding the first Transmed offer
# Out:
# OTHERS OFFER:[]

# %% [markdown]
# # Best seller cat y group string

# %%
best_sellers_string = soup.select_one('ul.a-unordered-list:nth-child(4) > li:nth-child(1) > span:nth-child(1)').text
print(best_sellers_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 best_sellers_string = soup.select_one('ul.a-unordered-list:nth-child(4) > li:nth-child(1) > span:nth-child(1)').text
#       2 print(best_sellers_list)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
# Borramos Best Sellers Rank:
best_sellers_string = best_sellers_string.replace('Best Sellers Rank:  ', '')
print(best_sellers_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # Borramos Best Sellers Rank:
# ----> 2 best_sellers_string = best_sellers_string.replace('Best Sellers Rank:  ', '')
#       3 print(best_sellers_string)
#
# NameError: name 'best_sellers_string' is not defined

# %%
#Eliminamos todo lo que esta dentro del parentesis
patron = r"\(([^)]+)\)"# Reemplazar con cadena vacía
texto_sin_numeros_parentesis = re.sub(patron, "", best_sellers_string)
texto_sin_numeros_parentesis = texto_sin_numeros_parentesis.replace('  ', '')
texto_sin_numeros_parentesis = texto_sin_numeros_parentesis[1:]
print(f"Texto filtrado: {texto_sin_numeros_parentesis}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 #Eliminamos todo lo que esta dentro del parentesis
#       2 patron = r"\(([^)]+)\)"# Reemplazar con cadena vacía
# ----> 3 texto_sin_numeros_parentesis = re.sub(patron, "", best_sellers_string)
#       4 texto_sin_numeros_parentesis = texto_sin_numeros_parentesis.replace('  ', '')
#       5 texto_sin_numeros_parentesis = texto_sin_numeros_parentesis[1:]
#
# NameError: name 'best_sellers_string' is not defined

# %%
lista_catgroup = texto_sin_numeros_parentesis.split('#')
category_string = re.sub(r'[0-9]', '', lista_catgroup[0]).replace(' in ', '')
group_string = re.sub(r'[0-9]', '', lista_catgroup[1]).replace(' in ', '')

print(category_string)
print(group_string)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 lista_catgroup = texto_sin_numeros_parentesis.split('#')
#       2 category_string = re.sub(r'[0-9]', '', lista_catgroup[0]).replace(' in ', '')
#       3 group_string = re.sub(r'[0-9]', '', lista_catgroup[1]).replace(' in ', '')
#
# NameError: name 'texto_sin_numeros_parentesis' is not defined

# %%
best_sellers_string = soup.select_one('ul.a-unordered-list:nth-child(4) > li:nth-child(1) > span:nth-child(1)').text
best_sellers_string = best_sellers_string.replace('  Best Sellers Rank:  ', '')
print(best_sellers_string)

patron = r"\(([^)]+)\)"# Reemplazar con cadena vacía
best_sellers_string = re.sub(patron, "", best_sellers_string)
best_sellers_strings = best_sellers_string.replace('  ', '')
best_sellers_string = best_sellers_string[1:]
print(best_sellers_string)

lista_catgroup = best_sellers_string.split('#')
category_string = re.sub(r'[0-9]', '', lista_catgroup[0]).replace(' in ', '')
group_string = re.sub(r'[0-9]', '', lista_catgroup[1]).replace(' in ', '')

print(category_string)
print(group_string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 best_sellers_string = soup.select_one('ul.a-unordered-list:nth-child(4) > li:nth-child(1) > span:nth-child(1)').text
#       2 best_sellers_string = best_sellers_string.replace('  Best Sellers Rank:  ', '')
#       3 print(best_sellers_string)
#
# AttributeError: 'NoneType' object has no attribute 'text'
