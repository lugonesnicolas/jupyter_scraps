# %% [markdown]
# # API Test

# %%
import requests
import re

# %%
username = 'user-spwnapellv-country-ae-city-dubai'
password = '3dxWxvajxn4k7SiF4G'
proxy = f"http://{username}:{password}@gate.smartproxy.com:7000"
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:126.0) Gecko/20100101 Firefox/126.0',
  'Accept': '*/*',
  'Accept-Language': 'en-US,en;q=0.5',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMDg4MDMwNTciLCJpZCI6ImM5ZTQ5ZDUyNDc1ZjBlMmUiLCJ0ciI6IjcxMTM3NzFhNjgwNTdiZDEwYmNhMTczNzI1YjkzYTcwIiwidGkiOjE3MTc3ODE2MDYxMDF9fQ==',
  'traceparent': '00-7113771a68057bd10bca173725b93a70-c9e49d52475f0e2e-01',
  'tracestate': '3355720^@nr=0-1-3355720-1008803057-c9e49d52475f0e2e----1717781606101',
  'X-Requested-With': 'XMLHttpRequest',
  'userId': 'anonymous',
  'appId': 'Reactweb',
  'env': 'prod',
  'token': 'pGW_4vxTn2nhMfIl34uQvxyRNmU',
  'storeId': 'mafuae',
  'langCode': 'en',
  'lang': 'en',
  'intent': '',
  'posInfo': 'food=072_Zone01,nonfood=099_Zone01,express=015_Zone01',
  'Connection': 'keep-alive',
  'Referer': 'https://www.carrefouruae.com/mafuae/en/cream-chocolate-filled/oreo-original-36-8gx12/p/1939410?list_name=search^%^7Coreo&offer=offer_carrefour_',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-origin',
  'If-None-Match': 'W/6dcc-xU83W5qbgO7uSJH8d2OCtZOLwWk',
  'TE': 'trailers'
}

payload = ''

# %%
url = f"https://www.carrefouruae.com/mafuae/en/sparkling-juice/freez-blue-hawai-275m/p/1263674?list_name=search%7C1263674&offer=offer_carrefour_"

# %%
sku = None
match = re.search(r'/p/(\d+)?', url)    
if match != None:
    sku = match.group(1)
    print(f"El sku encontrado es: {sku}")
else:
    sku = ''
    print("No se encontró el sku.")

api_url = f"https://www.carrefouruae.com/api/v4/relevance/products/{sku}?lang=en&placements=personal_page.echo_seed|item_page.frequently_bought_together_web&displayCurr=AED&latitude=25.216319&longitude=55.40779490000001"
# Out:
# El sku encontrado es: 1263674

# %%
response = requests.get(api_url, json=payload, headers=headers, proxies = {'https': proxy}, timeout=15000)
print(response.text)
data_product = response.json()
print(data_product)
# Out:
# {"rcs":"eF4FwbkRgDAMBMDEEb3cjPVYTwe0YVsJARlQP7utvfvkIdumMWYEQ6smJJej1JRUI0riuL_nqk4-GOSUokncLQNOAP2KixE-","placements":[{"htmlElementId":"item_page_0","strategyName":"EchoProducts","strategyMessage":"echo_product","placementType":"item_page","placement":"item_page.echo_seed","recommendedProducts":[{"id":"1263674","ean":"762571500197","category":[{"id":"F1500000","level":1,"name":"Beverages","url":"/c/F1500000/"},{"id":"F1550000","level":2,"name":"Soft Drinks","url":"/c/F1550000/"},{"id":"F1550100","level":3,"name":"Carbonated Drinks","url":"/c/F1550100/"},{"id":"F1550104","level":4,"name":"Other Flavours","url":"/c/F1550104/"}],"name":"Freez Mix Carbonated Flavored Drink Blue Hawai Tropical Fruits 275ml","type":"FOOD","preorder":false,"isExpress":true,"brand":{"id":"01095","name":"Freez"},"productOrigin":"Lebanon","supplier":"Carrefour","delivery":[],"isBulk":false,"bulkMessage":"","availability":{"isAvailable":true,"max":10},"size":"275ml","isScalable":false,"price":{"currency":"AED","price":6.3,"formattedValue":"AED6.30","minBuyingValue":"6.30"},"isFBC":false,"offers":[{"id":"offer_carrefour_","sellerName":"Carrefour","shopId":"0000","type":"main","purchaseIndicators":{"SHIPPING":["EXPRESS","SLOTTED"]}}],"stock":{"stockLevelStatus":"inStock"},"unit":{"unitOfMeasure":"pieces","itemsPerUnit":0,"incrementBy":1,"size":"275ml","max":10,"min":1,"unitItem":0},"availableVariants":[],"variants":[],"isMarketPlace":false,"foodType":"DRY","promoVoucher":{},"promoBadges":[],"productCategoriesHearchi":"Beverages/Soft Drinks/Carbonated Drinks/Other Flavours","deliveryFees":{"freeDeliveryThreshold":75},"amendableOrders":[],"soldByWeight":false,"links":{"images":[{"rel":"assets","href":"https://cdnprod.mafretailproxy.com/sys-master-root/h04/hbb/49833164046366/200Wx200H_1263674_main.jpg","type":"GET","kind":"image","properties":{"format":"plpThumbnail","url":"https://cdnprod.mafretailproxy.com/sys-master-root/h04/hbb/49833164046366/200Wx200H_1263674_main.jpg","imageType":"GALLERY"}},{"rel":"assets","href":"https://cdnprod.mafretailproxy.com/sys-master-root/h06/hcc/49833177186334/200Wx200H_1263674_1.jpg","type":"GET","kind":"image","properties":{"format":"plpThumbnail","url":"https://cdnprod.mafretailproxy.com/sys-master-root/h06/hcc/49833177186334/200Wx200H_1263674_1.jpg","imageType":"GALLERY"}},{"rel":"assets","href":"https://cdnprod.mafretailproxy.com/sys-master-root/h25/h64/49833228795934/200Wx200H_1263674_2.jpg","type":"GET","kind":"image","properties":{"format":"plpThumbnail","url":"https://cdnprod.mafretailproxy.com/sys-master-root/h25/h64/49833228795934/200Wx200H_1263674_2.jpg","imageType":"GALLERY"}},{"rel":"assets","href":"https://cdnprod.mafretailproxy.com/sys-master-root/hb0/hb8/49833229123614/200Wx200H_1263674_3.jpg","type":"GET","kind":"image","properties":{"format":"plpThumbnail","url":"https://cdnprod.mafretailproxy.com/sys-master-root/hb0/hb8/49833229123614/200Wx200H_1263674_3.jpg","imageType":"GALLERY"}},{"rel":"assets","href":"https://cdnprod.mafretailproxy.com/sys-master-root/h40/hc3/49833229451294/200Wx200H_1263674_4.jpg","type":"GET","kind":"image","properties":{"format":"plpThumbnail","url":"https://cdnprod.mafretailproxy.com/sys-master-root/h40/hc3/49833229451294/200Wx200H_1263674_4.jpg","imageType":"GALLERY"}},{"rel":"assets","href":"https://cdnprod.mafretailproxy.com/sys-master-root/hbc/hcd/49833229778974/200Wx200H_1263674_5.jpg","type":"GET","kind":"image","properties":{"format":"plpThumbnail","url":"https://cdnprod.mafretailproxy.com/sys-master-root/hbc/hcd/49833229778974/200Wx200H_1263674_5.jpg","imageType":"GALLERY"}},{"rel":"assets","href":"https://cdnprod.mafretailproxy.com/sys-master-root/hf2/h2f/49833230106654/200Wx200H_1263674_6.jpg","type":"GET","kind":"image","properties":{"format":"plpThumbnail","url":"https://cdnprod.mafretailproxy.com/sys-master-root/hf2/h2f/49833230106654/200Wx200H_1263674_6.jpg","imageType":"GALLERY"}}],"productUrl":{"href":"/mafuae/en/other-flavours/freez-blue-hawai-275m/p/1263674","r ...
# {'rcs': 'eF4FwbkRgDAMBMDEEb3cjPVYTwe0YVsJARlQP7utvfvkIdumMWYEQ6smJJej1JRUI0riuL_nqk4-GOSUokncLQNOAP2KixE-', 'placements': [{'htmlElementId': 'item_page_0', 'strategyName': 'EchoProducts', 'strategyMessage': 'echo_product', 'placementType': 'item_page', 'placement': 'item_page.echo_seed', 'recommendedProducts': [{'id': '1263674', 'ean': '762571500197', 'category': [{'id': 'F1500000', 'level': 1, 'name': 'Beverages', 'url': '/c/F1500000/'}, {'id': 'F1550000', 'level': 2, 'name': 'Soft Drinks', 'url': '/c/F1550000/'}, {'id': 'F1550100', 'level': 3, 'name': 'Carbonated Drinks', 'url': '/c/F1550100/'}, {'id': 'F1550104', 'level': 4, 'name': 'Other Flavours', 'url': '/c/F1550104/'}], 'name': 'Freez Mix Carbonated Flavored Drink Blue Hawai Tropical Fruits 275ml', 'type': 'FOOD', 'preorder': False, 'isExpress': True, 'brand': {'id': '01095', 'name': 'Freez'}, 'productOrigin': 'Lebanon', 'supplier': 'Carrefour', 'delivery': [], 'isBulk': False, 'bulkMessage': '', 'availability': {'isAvailable': True, 'max': 10}, 'size': '275ml', 'isScalable': False, 'price': {'currency': 'AED', 'price': 6.3, 'formattedValue': 'AED6.30', 'minBuyingValue': '6.30'}, 'isFBC': False, 'offers': [{'id': 'offer_carrefour_', 'sellerName': 'Carrefour', 'shopId': '0000', 'type': 'main', 'purchaseIndicators': {'SHIPPING': ['EXPRESS', 'SLOTTED']}}], 'stock': {'stockLevelStatus': 'inStock'}, 'unit': {'unitOfMeasure': 'pieces', 'itemsPerUnit': 0, 'incrementBy': 1, 'size': '275ml', 'max': 10, 'min': 1, 'unitItem': 0}, 'availableVariants': [], 'variants': [], 'isMarketPlace': False, 'foodType': 'DRY', 'promoVoucher': {}, 'promoBadges': [], 'productCategoriesHearchi': 'Beverages/Soft Drinks/Carbonated Drinks/Other Flavours', 'deliveryFees': {'freeDeliveryThreshold': 75}, 'amendableOrders': [], 'soldByWeight': False, 'links': {'images': [{'rel': 'assets', 'href': 'https://cdnprod.mafretailproxy.com/sys-master-root/h04/hbb/49833164046366/200Wx200H_1263674_main.jpg', 'type': 'GET', 'kind': 'image', 'properties': {'format': 'plpThumbnail', 'url': 'https://cdnprod.mafretailproxy.com/sys-master-root/h04/hbb/49833164046366/200Wx200H_1263674_main.jpg', 'imageType': 'GALLERY'}}, {'rel': 'assets', 'href': 'https://cdnprod.mafretailproxy.com/sys-master-root/h06/hcc/49833177186334/200Wx200H_1263674_1.jpg', 'type': 'GET', 'kind': 'image', 'properties': {'format': 'plpThumbnail', 'url': 'https://cdnprod.mafretailproxy.com/sys-master-root/h06/hcc/49833177186334/200Wx200H_1263674_1.jpg', 'imageType': 'GALLERY'}}, {'rel': 'assets', 'href': 'https://cdnprod.mafretailproxy.com/sys-master-root/h25/h64/49833228795934/200Wx200H_1263674_2.jpg', 'type': 'GET', 'kind': 'image', 'properties': {'format': 'plpThumbnail', 'url': 'https://cdnprod.mafretailproxy.com/sys-master-root/h25/h64/49833228795934/200Wx200H_1263674_2.jpg', 'imageType': 'GALLERY'}}, {'rel': 'assets', 'href': 'https://cdnprod.mafretailproxy.com/sys-master-root/hb0/hb8/49833229123614/200Wx200H_1263674_3.jpg', 'type': 'GET', 'kind': 'image', 'properties': {'format': 'plpThumbnail', 'url': 'https://cdnprod.mafretailproxy.com/sys-master-root/hb0/hb8/49833229123614/200Wx200H_1263674_3.jpg', 'imageType': 'GALLERY'}}, {'rel': 'assets', 'href': 'https://cdnprod.mafretailproxy.com/sys-master-root/h40/hc3/49833229451294/200Wx200H_1263674_4.jpg', 'type': 'GET', 'kind': 'image', 'properties': {'format': 'plpThumbnail', 'url': 'https://cdnprod.mafretailproxy.com/sys-master-root/h40/hc3/49833229451294/200Wx200H_1263674_4.jpg', 'imageType': 'GALLERY'}}, {'rel': 'assets', 'href': 'https://cdnprod.mafretailproxy.com/sys-master-root/hbc/hcd/49833229778974/200Wx200H_1263674_5.jpg', 'type': 'GET', 'kind': 'image', 'properties': {'format': 'plpThumbnail', 'url': 'https://cdnprod.mafretailproxy.com/sys-master-root/hbc/hcd/49833229778974/200Wx200H_1263674_5.jpg', 'imageType': 'GALLERY'}}, {'rel': 'assets', 'href': 'https://cdnprod.mafretailproxy.com/sys-master-root/hf2/h2f/49833230106654/200Wx200H_1263674_6.jpg', 'type': 'GET', 'kind': 'image', 'prope ...

# %%
print(data_product['placements'][0]['recommendedProducts'][0]['stock'])
# Out:
# {'stockLevelStatus': 'inStock'}

# %%
aux_title = data_product['placements'][0]['recommendedProducts'][0].get('name', '')       
old_price = data_product['placements'][0]['recommendedProducts'][0]['price'].get('price', 0)
stock = data_product['placements'][0]['recommendedProducts'][0]['stock'].get('stockLevelStatus' , 0)
print(f"Stock: {stock}")
if stock != 0 and stock != None and 'inStock' in stock or "lowStock" in stock:
    stock = 1
else:
    stock = 0

print(f"---- Title: {aux_title}")
print(f"Stock: {stock}")
# Out:
# Stock: inStock
# ---- Title: Freez Mix Carbonated Flavored Drink Blue Hawai Tropical Fruits 275ml
# Stock: 1
