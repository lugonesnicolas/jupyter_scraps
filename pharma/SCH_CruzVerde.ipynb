# %%
import requests

# %%
url = "https://api.cruzverde.cl/product-service/products/search?limit=12&offset=0&sort=&q=hipertensión&inventoryId=zonaS2Soriente&inventoryZone=zonaS2Soriente"
payload = {}
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:127.0) Gecko/20100101 Firefox/127.0',
  'Accept': 'application/json, text/plain, */*',
  'Accept-Language': 'es-AR,es;q=0.8,en-US;q=0.5,en;q=0.3',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'Origin': 'https://www.cruzverde.cl',
  'DNT': '1',
  'Sec-GPC': '1',
  'Connection': 'keep-alive',
  'Referer': 'https://www.cruzverde.cl/',
  'Cookie': '_gcl_au=1.1.777836959.1719923788; _fbp=fb.1.1719923788466.9758656431; _ga_CVCL=GS1.1.1719934540.4.1.1719934575.0.0.631042250; _ga=GA1.1.348827162.1719923789; _ga_GMKXQPNSW5=GS1.1.1719934539.4.1.1719934575.0.0.1124912275; connect.sid=s%3Acruzverde-2148cd0f-9465-4322-b7ee-83bf7e9d25c8.wkWNteuRg93oa07CAPqMgRmKfp41WLYsvr0%2F4usFpvo',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'TE': 'trailers'
}
response = requests.request("GET", url, headers=headers, data=payload)
data = response.json()
data_products = data.get("hits", "")

# %%
print(data)
# Out:
# {'v': '19.1', 'type': 'product_search_result', 'count': 12, 'hits': [{'type': 'product_search_hit', 'hitType': 'product', 'image': {'type': 'image', 'alt': 'Valmira Amlodipino 5 mg Valsartán 160 mg 28 Comprimidos Recubiertos', 'disBaseLink': 'https://beta.cruzverde.cl/dw/image/v2/BDPM_PRD/on/demandware.static/-/Sites-masterCatalog_Chile/default/dw27fafeab/images/large/403293-valmira-amlodipino-5-mg-valsartan-160-mg-28-comprimidos-recubiertos.jpg', 'link': 'https://beta.cruzverde.cl/on/demandware.static/-/Sites-masterCatalog_Chile/default/dw27fafeab/images/large/403293-valmira-amlodipino-5-mg-valsartan-160-mg-28-comprimidos-recubiertos.jpg', 'title': 'Valmira Amlodipino 5 mg Valsartán 160 mg 28 Comprimidos Recubiertos'}, 'link': 'https://beta.cruzverde.cl/s/Chile/dw/shop/v19_1/products/403293?q=hipertensi%C3%B3n&start=0&count=12&sort=&searchDrivenRedirect=true', 'productId': '403293', 'productName': 'Valmira Amlodipino 5 mg Valsartán 160 mg 28 Comprimidos Recubiertos', 'productType': 
# ...

# %%
print(data_products[0])
# Out:
# {'type': 'product_search_hit', 'hitType': 'product', 'image': {'type': 'image', 'alt': 'Valmira Amlodipino 5 mg Valsartán 160 mg 28 Comprimidos Recubiertos', 'disBaseLink': 'https://beta.cruzverde.cl/dw/image/v2/BDPM_PRD/on/demandware.static/-/Sites-masterCatalog_Chile/default/dw27fafeab/images/large/403293-valmira-amlodipino-5-mg-valsartan-160-mg-28-comprimidos-recubiertos.jpg', 'link': 'https://beta.cruzverde.cl/on/demandware.static/-/Sites-masterCatalog_Chile/default/dw27fafeab/images/large/403293-valmira-amlodipino-5-mg-valsartan-160-mg-28-comprimidos-recubiertos.jpg', 'title': 'Valmira Amlodipino 5 mg Valsartán 160 mg 28 Comprimidos Recubiertos'}, 'link': 'https://beta.cruzverde.cl/s/Chile/dw/shop/v19_1/products/403293?q=hipertensi%C3%B3n&start=0&count=12&sort=&searchDrivenRedirect=true', 'productId': '403293', 'productName': 'Valmira Amlodipino 5 mg Valsartán 160 mg 28 Comprimidos Recubiertos', 'productType': {'type': 'product_type', 'item': True}, 'representedProduct': {'type'
# ...

# %%
for i in data_products:
    title = i.get("productName", "")
    prices = i.get("prices", 0)
    final_price = float(prices.get("price-sale-cl", 0)) if prices.get("price-sale-cl", 0) != None else 0
    old_price = float(prices.get("price-list-cl", 0)) if prices.get("price-list-cl", 0) != None else 0
    brand = i.get("brand", "")
    
    print(f"Title: {title}")
    print(f"Brand: {brand}")
    print(f"FinalPrice: {final_price}")
    print(f"OldPrice: {old_price}\n")
# Out:
# Title: Valmira Amlodipino 5 mg Valsartán 160 mg 28 Comprimidos Recubiertos
# Brand: ASCEND
# FinalPrice: 18594.0
# OldPrice: 30990.0
#
# Title: Valmira Amlodipino 10 mg Valsartán 160 mg 28 Comprimidos Recubiertos
# Brand: ASCEND
# FinalPrice: 17394.0
# OldPrice: 28990.0
#
# Title: Valkem D Valsartán 80 mg Hidroclorotiazida 12,5 mg 30 Comprimidos Recubiertos
# Brand: ASCEND
# FinalPrice: 9894.0
# OldPrice: 16490.0
#
# Title: Valkem D Valsartán 160 mg Hidroclorotiazida 25 mg 30 Comprimidos Recubiertos
# Brand: ASCEND
# FinalPrice: 9894.0
# OldPrice: 16490.0
#
# Title: Valkem D Valsartán 160 mg Hidroclorotiazida 12,5 mg 30 Comprimidos Recubiertos
# Brand: ASCEND
# FinalPrice: 9894.0
# OldPrice: 16490.0
#
# Title: Meprokem Metoprolol Tartrato de Liberación Prolongada 50 mg 30 Comprimidos
# Brand: ASCEND
# FinalPrice: 18594.0
# OldPrice: 30990.0
#
# Title: Meprokem Metoprolol Tartrato de Liberación Prolongada 25 mg 30 Comprimidos
# Brand: ASCEND
# FinalPrice: 14994.0
# OldPrice: 24990.0
# ...
