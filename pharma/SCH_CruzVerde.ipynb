# %%
import requests

# %%
url = "https://api.cruzverde.cl/product-service/products/search?limit=12&offset=0&sort=&q=antigripal&inventoryId=zonaS2Soriente&inventoryZone=zonaS2Soriente"
payload = {}
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:127.0) Gecko/20100101 Firefox/127.0',
  'Accept': 'application/json, text/plain, */*',
  'Accept-Language': 'es-AR,es;q=0.8,en-US;q=0.5,en;q=0.3',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'Origin': 'https://www.cruzverde.cl',
  'DNT': '1',
  'Sec-GPC': '1',
  'Connection': 'keep-alive',
  'Referer': 'https://www.cruzverde.cl/',
  'Cookie': '_gcl_au=1.1.18108492.1720028843; _fbp=fb.1.1720028843140.2747394740; _ga_CVCL=GS1.1.1720037343.3.1.1720037360.0.0.373722177; _ga=GA1.1.194071466.1720028843; _ga_GMKXQPNSW5=GS1.1.1720037345.3.1.1720037361.0.0.389589578; _tt_enable_cookie=1; _ttp=vqugx8V6bgEhlpkLrGU9yEiUECs; _gid=GA1.2.1139719028.1720028846; _hjSessionUser_1614665=eyJpZCI6Ijg1OTVkMzdhLWYwYjItNTVhNi1iMDkwLWZlYWM2Y2E4MDJiMyIsImNyZWF0ZWQiOjE3MjAwMjg4NDU3MDIsImV4aXN0aW5nIjp0cnVlfQ==; connect.sid=s^%^3Acruzverde-50b04a03-2fd5-46d2-8d61-c17cfab4dbbf.xe7bjN7GHYeiR9kmbzXu1SqHw5l93DhCorsJNm6xslk; _hjSession_1614665=eyJpZCI6IjkwYTM2M2NiLTc4ODEtNDdjMS1hYTYwLWFmMzk4MmU2YWE4YSIsImMiOjE3MjAwMzczNDQ4ODIsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowfQ==; _gat_UA-149350909-1=1',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'If-None-Match': 'W/9c7e-5f4Yc6sgyhjTTE3eYCopNiKpr5Q',
  'TE': 'trailers'
}

response = requests.get(url, headers=headers, data=payload)
data = response.json()
data_products = data.get("hits", "")

# %%
print(data)
# Out:
# {'v': '19.1', 'type': 'product_search_result', 'count': 12, 'hits': [{'type': 'product_search_hit', 'hitType': 'product', 'image': {'type': 'image', 'alt': 'Nastul Compuesto Pseudoefedrina 30 mg Jarabe 100 mL', 'disBaseLink': 'https://beta.cruzverde.cl/dw/image/v2/BDPM_PRD/on/demandware.static/-/Sites-masterCatalog_Chile/default/dw53fa171f/images/large/12136-nastul-compuesto-pseudoef-30-mg5ml-jarabe-100-ml.jpg', 'link': 'https://beta.cruzverde.cl/on/demandware.static/-/Sites-masterCatalog_Chile/default/dw53fa171f/images/large/12136-nastul-compuesto-pseudoef-30-mg5ml-jarabe-100-ml.jpg', 'title': 'Nastul Compuesto Pseudoefedrina 30 mg Jarabe 100 mL'}, 'link': 'https://beta.cruzverde.cl/s/Chile/dw/shop/v19_1/products/12136?q=antigripal&start=0&count=12&sort=&searchDrivenRedirect=true', 'productId': '12136', 'productName': 'Nastul Compuesto Pseudoefedrina 30 mg Jarabe 100 mL', 'productType': {'type': 'product_type', 'item': True}, 'representedProduct': {'type': 'product_ref', 'id': '1213
# ...

# %%
print(data_products[0])
# Out:
# {'type': 'product_search_hit', 'hitType': 'product', 'image': {'type': 'image', 'alt': 'Nastul Compuesto Pseudoefedrina 30 mg Jarabe 100 mL', 'disBaseLink': 'https://beta.cruzverde.cl/dw/image/v2/BDPM_PRD/on/demandware.static/-/Sites-masterCatalog_Chile/default/dw53fa171f/images/large/12136-nastul-compuesto-pseudoef-30-mg5ml-jarabe-100-ml.jpg', 'link': 'https://beta.cruzverde.cl/on/demandware.static/-/Sites-masterCatalog_Chile/default/dw53fa171f/images/large/12136-nastul-compuesto-pseudoef-30-mg5ml-jarabe-100-ml.jpg', 'title': 'Nastul Compuesto Pseudoefedrina 30 mg Jarabe 100 mL'}, 'link': 'https://beta.cruzverde.cl/s/Chile/dw/shop/v19_1/products/12136?q=antigripal&start=0&count=12&sort=&searchDrivenRedirect=true', 'productId': '12136', 'productName': 'Nastul Compuesto Pseudoefedrina 30 mg Jarabe 100 mL', 'productType': {'type': 'product_type', 'item': True}, 'representedProduct': {'type': 'product_ref', 'id': '12136', 'link': 'https://beta.cruzverde.cl/s/Chile/dw/shop/v19_1/products
# ...

# %%
for i in data_products:
    title = i.get("productName", "")
    prices = i.get("prices", 0)
    final_price = float(prices.get("price-sale-cl", 0)) if prices.get("price-sale-cl", 0) != None else 0
    old_price = float(prices.get("price-list-cl", 0)) if prices.get("price-list-cl", 0) != None else 0
    brand = i.get("brand", "")
    
    print(f"Title: {title}")
    print(f"Brand: {brand}")
    print(f"FinalPrice: {final_price}")
    print(f"OldPrice: {old_price}\n")
# Out:
# Title: Nastul Compuesto Pseudoefedrina 30 mg Jarabe 100 mL
# Brand: SANITAS
# FinalPrice: 6923.0
# OldPrice: 9890.0
#
# Title: Trio-Val Pseudoefedrina 60 mg 10 Comprimidos
# Brand: SAVAL
# FinalPrice: 4616.0
# OldPrice: 6690.0
#
# Title: Trio-Val Pseudoefedrina 30 mg Suspensión Oral 100 mL
# Brand: SAVAL
# FinalPrice: 12872.0
# OldPrice: 16090.0
#
# Title: Trio-Val Paracetamol 120 mg Gotas 15 mL
# Brand: SAVAL
# FinalPrice: 13112.0
# OldPrice: 16390.0
#
# Title: Trio-Val Día/Noche Pseudoefedrina 60 mg 20 Comprimidos
# Brand: SAVAL
# FinalPrice: 5034.0
# OldPrice: 8390.0
#
# Title: Triofeno Ibuprofeno 200 mg 20 Comprimidos
# Brand: SAVAL
# FinalPrice: 7912.0
# OldPrice: 9890.0
#
# Title: Tapsin Plus Noche Paracetamol 650 mg Solución Oral 1 Sobre
# Brand: MAVER
# FinalPrice: 630.0
# OldPrice: 750.0
#
# Title: Tapsin Plus Día Paracetamol 650 mg Solución Oral 1 Sobre
# Brand: MAVER
# FinalPrice: 630.0
# OldPrice: 750.0
#
# Title: Tapsin Nocturno Paracetamol 500 mg 600 Comprimidos
# ...

# %% [markdown]
# # Test selenium

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep 
import json

# %%
driver = webdriver.Chrome()
driver.get(url)
sleep(1)
html = driver.page_source
driver.quit()

# %%
data = json.loads(html)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = json.loads(html)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
# ...
