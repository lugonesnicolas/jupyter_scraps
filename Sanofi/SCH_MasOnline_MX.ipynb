# %%
# Importacion de librerias necesarias
import requests
import re
from bs4 import BeautifulSoup

# Proxy y datos como header para la coneccion
username = 'Ec0m37ry'
password = 'fK7Ulvdm8zSVnyn22+'
proxy = f"http://{username}:{password}@mx.smartproxy.com:20000"

url = "https://super.walmart.com.mx/search?q=oreo"
payload = {}
headers = {
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'es-419,es-US;q=0.9,es;q=0.8,en-US;q=0.7,en;q=0.6',
  'cache-control': 'max-age=0',
  'downlink': '10',
  'dpr': '1',
  'priority': 'u=0, i',
  'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36'
}

# Consulta
response = requests.request("GET", url, headers=headers, data=payload, proxies = {'https': proxy})
html_content = response.text
soup = BeautifulSoup(html_content, "html.parser")


# Parseo
count = 0
products_list = soup.select("div.sans-serif.mid-gray.relative.flex.flex-column.w-100.hide-child-opacity") if soup.select("div.sans-serif.mid-gray.relative.flex.flex-column.w-100.hide-child-opacity") != None else ""
for product in products_list:
    title = product.select_one("span.normal.dark-gray.mb0.mt1.lh-title.f6.f5-l.lh-copy").text if product.select_one("span.normal.dark-gray.mb0.mt1.lh-title.f6.f5-l.lh-copy") != None else ""
    brand = product.select_one("div.mb1.mt2.b.f6.black.mr1.lh-copy").text if product.select_one("div.mb1.mt2.b.f6.black.mr1.lh-copy") != None else ""
    final_price = product.select_one("div.mr1.mr2-xl.b.black.lh-copy.f5.f4-l").text if product.select_one("div.mr1.mr2-xl.b.black.lh-copy.f5.f4-l") != None else 0

    print(f"Title: {title}")
    print(f"Brand: {brand}")
    print(f"FinalPrice: {final_price}\n")

#     if count < 10:
        # Producto
# Out:
# Title: Galletas Oreo 252 g
# Brand: Oreo
# FinalPrice: $37.00
#
# Title: Galletas Oreo Coca Cola 105 gr
# Brand: Oreo
# FinalPrice: $23.00
#
# Title: Galletas Oreo chocolate con relleno sabor cajeta 252 g
# Brand: Oreo
# FinalPrice: $39.00
#
# Title: Galletas Oreo tipo sándwich 307.8 g
# Brand: Oreo
# FinalPrice: $40.00
#
# Title: Galletas Oreo sabor chocolate 114 g
# Brand: Oreo
# FinalPrice: $20.50
#
# Title: Galletas Oreo chocolate relleno sabor vainilla 63 g
# Brand: Oreo
# FinalPrice: $10.00
#
# Title: Galletas Oreo mini sabor chocolate 226 g
# Brand: Oreo
# FinalPrice: $51.00
#
# Title: Galletas Oreo pay de limón 252 g
# Brand: Oreo
# FinalPrice: $37.00
#
# Title: Galletas Oreo Coca Cola 252 g
# Brand: Oreo
# FinalPrice: $42.00
