# %%
# Importacion de librerias necesarias
import requests
import re
from bs4 import BeautifulSoup

# Proxy y datos como header para la coneccion
username = 'Ec0m37ry'
password = 'fK7Ulvdm8zSVnyn22+'
proxy = f"http://{username}:{password}@mx.smartproxy.com:20000"

url = "https://www.fahorro.com/catalogsearch/result/?form_key=aSjCT4HUn9xRWmbQ&q=alergias"
payload = {}
headers = {
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'es-419,es-US;q=0.9,es;q=0.8,en-US;q=0.7,en;q=0.6',
  'cache-control': 'max-age=0',
  'cookie': 'visid_incap_2896117=/b90rrf1TbOEGt0/2rzlKZsmCGcAAAAAQUIPAAAAAABZ5OkLHRJgoKWheywfdeeZ; incap_ses_877_2896117=345iU8fC828ctxqI77orDJsmCGcAAAAAgQftesbZTy/GvrJ3IUyLYA==; reese84=3:tPjIhTi+9c0zxlo4eGw55w==:...:tVC6efCLVFEdJk6UuIT1ow2hrjYlnLmolqP1STBVavU=; PHPSESSID=43166d24f083eed4bca5662dde286361; nlbi_2896117=XT3cAO/BiFzUlOW9luKKigAAAADOj7JIEihKxoWfZ9diEDUP; incap_ses_1597_2896117=QKIbJBb3NDYSE2SEP68pFqYmCGcAAAAAMizHxchO2OcRQvmC6ECMnQ==; _gcl_au=1.1.623846958.1728587436; _ga=GA1.1.86380364.1728587436; form_key=QQiL7OsqMm7EWi5S; mage-cache-storage={}; mage-cache-storage-section-invalidation={}; mage-cache-sessid=true; mage-messages=; recently_viewed_product={}; recently_viewed_product_previous={}; recently_compared_product={}; recently_compared_product_previous={}; product_data_storage={}; form_key=QQiL7OsqMm7EWi5S; nlbi_2896117_2147483392=XhEbM3ixCHm2/UnvluKKigAAAAA8sNKlfTsTEfmTDgwAONI7; _ga_66JLCL0N63=GS1.1.1728587436.1.1.1728587458.38.0.0; section_data_ids={%22cart%22:1728587457}',
  'priority': 'u=0, i',
  'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36'
}

# Consulta
response = requests.request("GET", url, headers=headers, data=payload, proxies = {'https': proxy})
html_content = response.text
soup = BeautifulSoup(html_content, "html.parser")


# Parseo
# count = 0
products_list = soup.select("div.product-item-info")
for product in products_list:
    title = product.select_one("div.product > strong").text
    final_price = product.select_one("span.price").text
    
    print(f"Title: {title}")
    print(f"FinalPrice: {final_price}\n")
# Out:
# Title: Stérimar Manganeso Agua de Mar para Alergias 100 ml
# FinalPrice: $259.00
#
# Title: Clarityne Pediátrico jarabe sabor Uva 60 ml - Alivia los síntomas de alergias
# FinalPrice: $244.00
#
# Title: A-Derma Dermalibour Crema Protectora 50 ml
# FinalPrice: $300.80
#
# Title: Montelukast 10 mg Oral 20 tabletas Marca del Ahorro
# FinalPrice: $367.00
#
# Title: Ketotifeno 20 ml Oral Adulto 120 ml Solución Marca del Ahorro
# FinalPrice: $143.00
#
# Title: Dutina Pediátrico 0.05% Suspensión Nasal Spray 10 g
# FinalPrice: $379.00
#
# Title: Montelukast 10 mg Oral 30 Tabs Marca Del Ahorro
# FinalPrice: $386.00
#
# Title: Montelukast 4 mg Oral 10 Sobres Marca Del Ahorro
# FinalPrice: $239.00
#
# Title: Salbutamol 100 mcg oral 200 Dosis Marca Del Ahorro
# FinalPrice: $78.00
#
# Title: Budesonida 0.500 Mg/ 2 Ml Con 5 Ampolletas Marca Del Ahorro
# FinalPrice: $372.00
#
# Title: Nutrilon Premium+ Pepti Syneo en Polvo de 400 gr
# FinalPrice: $541.00
#
# Title: Toleriane Dermallergo Serum 20 ml
# FinalPrice: $981.00
#
# Title: Clarityne 10 Tabletas - Antihistamínico
# FinalPrice: $210.00
#
# Title: Soltrictor Solución Oftálmica Gotas 15 ml
# FinalPrice: $325.00
#
# Title: NasaMist Solución Salina Isotónica 75 ml
# FinalPrice: $167.00
#
# Title: Neilmed NasaMist Spray Nasal Extra Fuerte 125 ml
# FinalPrice: $189.00
#
# Title: Nutrilon Premium HA 400 gr
# FinalPrice: $320.00
#
# Title: Benadryl Antihistamínico 24 tabletas
# FinalPrice: $151.00
#
# Title: Allegra® 120 mg antialérgico 10 Tabs
# FinalPrice: $280.50
#
# Title: Tela Adhesiva Leukoplast 1.25 cm X 4.57 M
# FinalPrice: $41.00
#
# Title: Similac Arroz 400 gr
# FinalPrice: $538.00
#
# Title: Sterimar Infantil Agua de Mar Congestion Nasal 3 Años en Adelante 50 ml
# FinalPrice: $229.00
#
# Title: Bloqueador Nivea Sun Sens FPS 50 125 ml
# FinalPrice: $205.00
#
# Title: Suplemento Alimenticio Casec 100 g
# FinalPrice: $299.00
