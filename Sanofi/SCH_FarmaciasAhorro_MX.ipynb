# %%
# Importacion de librerias necesarias
import BeOnFastCode as fc
import requests
import re
from bs4 import BeautifulSoup

# Proxy y datos como header para la coneccion
username = 'Ec0m37ry'
password = 'fK7Ulvdm8zSVnyn22+'
proxy = f"http://{username}:{password}@mx.smartproxy.com:20000"

url = "https://www.fahorro.com/catalogsearch/result/?q=advil%20analgesico"
payload = {}
headers = {
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'es-419,es-US;q=0.9,es;q=0.8,en-US;q=0.7,en;q=0.6',
  'cache-control': 'max-age=0',
  'cookie': 'visid_incap_2896117=/b90rrf1TbOEGt0/2rzlKZsmCGcAAAAAQUIPAAAAAABZ5OkLHRJgoKWheywfdeeZ; incap_ses_877_2896117=345iU8fC828ctxqI77orDJsmCGcAAAAAgQftesbZTy/GvrJ3IUyLYA==; reese84=3:tPjIhTi+9c0zxlo4eGw55w==:...:tVC6efCLVFEdJk6UuIT1ow2hrjYlnLmolqP1STBVavU=; PHPSESSID=43166d24f083eed4bca5662dde286361; nlbi_2896117=XT3cAO/BiFzUlOW9luKKigAAAADOj7JIEihKxoWfZ9diEDUP; incap_ses_1597_2896117=QKIbJBb3NDYSE2SEP68pFqYmCGcAAAAAMizHxchO2OcRQvmC6ECMnQ==; _gcl_au=1.1.623846958.1728587436; _ga=GA1.1.86380364.1728587436; form_key=QQiL7OsqMm7EWi5S; mage-cache-storage={}; mage-cache-storage-section-invalidation={}; mage-cache-sessid=true; mage-messages=; recently_viewed_product={}; recently_viewed_product_previous={}; recently_compared_product={}; recently_compared_product_previous={}; product_data_storage={}; form_key=QQiL7OsqMm7EWi5S; nlbi_2896117_2147483392=XhEbM3ixCHm2/UnvluKKigAAAAA8sNKlfTsTEfmTDgwAONI7; _ga_66JLCL0N63=GS1.1.1728587436.1.1.1728587458.38.0.0; section_data_ids={%22cart%22:1728587457}',
  'priority': 'u=0, i',
  'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'none',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36'
}

# Consulta
response = requests.request("GET", url, headers=headers, data=payload, proxies = {'https': proxy})
html_content = response.text
soup = BeautifulSoup(html_content, "html.parser")


# Parseo
# count = 0
products_list = soup.select("div.product-item-info")
for product in products_list:
    title = product.select_one("div.product > strong").text
    price = product.select("span.price")
    # print(f"Prices: {price}")
    final_price = fc.get_nested_value(data=price, keys=[0], default='0')
    final_price = fc.just_price(price_str=final_price.text, dotted_price=False) if final_price != '0' else '0'
    old_price = fc.get_nested_value(data=price, keys=[1], default='0')
    old_price = fc.just_price(price_str=old_price.text, dotted_price=False) if old_price != '0' else '0'
    
    
    # final_price = product.select_one("span.price").text
    # old_price = product.select_one("span.price")
    
    print(f"Title: {title}")
    print(f"FinalPrice: {final_price}")
    print(f"OldPrice: {old_price}")
# Out:
# Title: Advil Analgésico 200 mg 12 tabletas
# FinalPrice: 41.65
# OldPrice: 49.0
# Title: Advil Analgésico 200 mg 24 tabletas
# FinalPrice: 79.0
# OldPrice: 0
# Title: Advil Analgésico 400 mg 10 cápsulas
# FinalPrice: 73.95
# OldPrice: 87.0
# Title: Advil Analgésico 400 mg 20 cápsulas
# FinalPrice: 161.0
# OldPrice: 0
# Title: Advil 12 Horas 12 tabletas
# FinalPrice: 157.0
# OldPrice: 0
# Title: Advil Analgésico grageas 200 mg 100 tabletas
# FinalPrice: 284.0
# OldPrice: 0
# Title: Advil Analgésico Fastgel 200 mg 20 cápsulas
# FinalPrice: 101.0
# OldPrice: 0
# Title: Advil Analgésico Fastgel 200 mg 10 Caps
# FinalPrice: 59.0
# OldPrice: 0
# Title: Advil 12 Horas 6 tabletas
# FinalPrice: 77.35
# OldPrice: 91.0
# Title: Advil Solución Infantil Oral 100 ml
# FinalPrice: 126.0
# OldPrice: 0
# Title: Bexident Aftas Gel 8 ml
# FinalPrice: 261.0
# OldPrice: 0
# Title: Keral 25 mg /10 ml 20 Sobres
# FinalPrice: 393.0
# OldPrice: 0
# Title: Bexident Aftas Spray 15 ml
# FinalPrice: 303.0
# ...

# %%
price = products_list[0].select("span.price")
print(f"Prices: {price[0]}")
# Out:
# Prices: <span class="price">$244.00</span>
