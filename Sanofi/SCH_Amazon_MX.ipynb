# %%
# Importacion de librerias necesarias
import requests
import re
from bs4 import BeautifulSoup

# Proxy 
username = 'Ec0m37ry'
password = 'fK7Ulvdm8zSVnyn22+'
proxy = f"http://{username}:{password}@mx.smartproxy.com:20000"

# Datos como header para la coneccion
url = "https://www.amazon.com.mx/s?k=oreo&__mk_es_MX=%C3%85M%C3%85%C5%BD%C3%95%C3%91&crid=24B86QV3CV7P1&sprefix=or%2Caps%2C198&ref=nb_sb_noss_2"
payload = {}
headers = {
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'es-419,es-US;q=0.9,es;q=0.8,en-US;q=0.7,en;q=0.6',
  'cache-control': 'max-age=0',
  'cookie': 'session-id=139-1320918-4816959; session-id-time=2082787201l; i18n-prefs=MXN; ubid-acbmx=130-7583797-4600915; session-token=; csm-hit=tb:s-8X7CKC058YXMFY1AJFTT|1728397088109&t:1728397088545&adb:adblk_yes',
  'device-memory': '8',
  'downlink': '10',
  'dpr': '1',
  'ect': '4g',
  'priority': 'u=0, i',
  'rtt': '50',
  'sec-ch-device-memory': '8',
  'sec-ch-dpr': '1',
  'sec-ch-ua': '"Google Chrome";v="129", "Not=A?Brand";v="8", "Chromium";v="129"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-ch-ua-platform-version': '"15.0.0"',
  'sec-ch-viewport-width': '1124',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36',
  'viewport-width': '1124'
}

# Consulta
response = requests.request("GET", url, headers=headers, data=payload, proxies = {'https': proxy})
html_content = response.text
soup = BeautifulSoup(html_content, "html.parser")

# Parseo
# count = 0
# products_list = soup.select("test")
# for product in products_list:
#     if count < 10:
        # Producto

# %%
products_list = soup.select("div.sg-col-4-of-24.sg-col-4-of-12.s-result-item.s-asin.sg-col-4-of-16.sg-col.s-widget-spacing-small.sg-col-4-of-20")

# %%
count = 0
for product in products_list:
    if count < 10:
        count += 1
        sponsored = product.select_one("span.puis-label-popover-default").text if product.select_one("span.puis-label-popover-default")!= None else "No sponsored"
        title = product.select_one("span.a-size-base-plus.a-color-base.a-text-normal").text if product.select_one("span.a-size-base-plus.a-color-base.a-text-normal") != None else ''
        final_price = product.select_one("span.a-price").span.text if product.select_one("span.a-price") != None else 0
        old_price = product.select_one("div.a-section.aok-inline-block span.a-price.a-text-price").span.text if product.select_one("div.a-section.aok-inline-block span.a-price.a-text-price") != None else 0
        brand = product.select_one("h2.a-size-mini.s-line-clamp-1").text if product.select_one("h2.a-size-mini.s-line-clamp-1") != None else ''
        asin = product["data-asin"]
        product_url = product.select_one("a.a-link-normal.s-underline-text.s-underline-link-text.s-link-style.a-text-normal")["href"] if product.select_one("a.a-link-normal.s-underline-text.s-underline-link-text.s-link-style.a-text-normal") != None else ''
        product_url = f"https://www.amazon.ae{product_url}" if product_url != '' else ''
        print(f"Sponsored:{sponsored}")
        print(f"Title:{title}")
        print(f"FinalPrice:{final_price}")
        print(f"OldPrice:{old_price}")
        print(f"Asin:{asin}")
        print(f"Brand:{brand}")
        print(f"ProductUrl:{product_url}\n")
# Out:
# Sponsored:Patrocinado
# Title:Oreo Galletas Sabor Vainilla con Relleno Sabor Vainilla, Caja con 4 Paquetes de 6 Galletas, 63 gr cada uno
# FinalPrice:$37.00
# OldPrice:0
# Asin:B0CWMQ9223
# Brand:
# ...
