# %%
import http.client
import json

conn = http.client.HTTPSConnection("www.carrefouruae.com")
payload = ''
headers = {
  'accept': '*/*',
  'accept-language': 'en-US,en;q=0.9',
  'appid': 'Reactweb',
  'cookie': 'maf-session-id=3555C6F5-8CC3-81F7-0B90-A2F157B6CCB4; storeInfo=mafuae|en|AED; cart_api=v2; _gcl_au=1.1.751254030.1713963550; _gid=GA1.2.1907853551.1713963551; _scid=57f347c7-8bc4-4877-9ce3-e34b0fe66b50; _fbp=fb.1.1713963551464.265288769; _tt_enable_cookie=1; _ttp=hiBXSO45TnhWXcNoshkUb9blgfC; _sctr=1%7C1713927600000; hideCoachMark=true; _abck=EE2538F5807725CC47F66F215D03069C~0~...~-1~-1~-1; guest-session-token=lM500_g78KDHOP8_34lBdmBtbCM; OptanonAlertBoxClosed=2024-04-24T13:08:32.221Z; mafuae-web-preferred-delivery-area="Dubai Festival City - Dubai"; ROUTE=.accstorefront-87c8dd7ff-qfqkw; lat=24.4658714; long=54.59926599999999; mafuae-preferred-delivery-area=247%20Yas%20Dr%20St%20-%20Yas%20Island%20 - %20Yas%20Plaza%20; prevAreaCode=247%20Yas%20Dr%20St%20-%20Yas%20Island%20 - %20Yas%20Plaza%20; JSESSIONID=9B4AA3EC10B4824F286D6BC2D7E1437B.accstorefront-87c8dd7ff-qfqkw; search_type=search_native; RT="z=1&dm=www.carrefouruae.com&si=03e00687-cf1d-4839-aeb8-379ce1d1a805&ss=lve1ij30&sl=0&tt=0"; app_version=v4; posInfo=food=074_Zone01,nonfood=099_Zone01,express=074_Zone01; AKA_A2=A; bm_mi=F2476CD5E470FADDCBBEA9A6C5C0F0DF~...~1; page_type=product-details; ak_bmsc=407C5B8BFDE5F96E3B5E49DD378894D2~000000000000000000000000000000~...; _scid_r=57f347c7-8bc4-4877-9ce3-e34b0fe66b50; _ga=GA1.1.1711637497.1713963550; _ga_BWW6C6N1ZH=GS1.1.1713976767.3.1.1713976777.50.0.0; TEAL=v:218f103048af08744309300847533566f3227671856^$t:1713978577882^$sn:3^$en:4^$s:1713976773644%3Bexp-sess; cto_bundle=RseB8191QXlXb0hRaDhIU1hUcjN3UmhuN0NLZHc4OFU2M0R0bjZMQkZhMXRGWDQ1WU5Qc1AlMkJkOUE4MVRGVTB3JTJCYVE5NzFSdTJ2YXI5cHdHdmU0RDdlT05SWkhtZXdKYkRwMERNbDlYeTE2Q1F3RTRmbkl6JTJGWkElMkJDTyUyQlRNOWpJYzlERkI; OptanonConsent=isGpcEnabled=0&datestamp=Wed+Apr+24+2024+13%3A39%3A39+GMT-0300+(Argentina+Standard+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=ed34728b-f1b1-4ae4-ace8-81828cd9c6ab&interactionCount=1&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&geolocation=AR%3BB&AwaitingReconsent=false; bm_sv=4FFBB715DFD1990D5AABB26C73A1671C~~1; bm_sz=005032F40433D8DE38114DAB650C63F9~...~3425335~3749433; _abck=EE2538F5807725CC47F66F215D03069C~-1~...~0~-1~-1; bm_sv=4FFBB715DFD1990D5AABB26C73A1671C~~1; bm_sz=58A8150B64A9B2868FF1B5123C809794~...~4535859~3294278; cart_api=v2; posInfo=food=074_Zone01,nonfood=099_Zone01,express=074_Zone01; storeInfo=mafuae|en|AED',
  'env': 'prod',
  'if-modified-since': 'Wed, 24 Apr 2024 16:39:38 GMT',
  'if-none-match': 'W/"6c2a-DX+XmBVmUqMrNxD5HT2CR/yjl4w"',
  'intent': '',
  'lang': 'en',
  'langcode': 'en',
  'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMDg4MDMwNTciLCJpZCI6Ijk3NzYwYzQ1ZGFlNDk2OWEiLCJ0ciI6Ijk5ZDlmYmEwZmJlMTZkNWNlY2Q5ODM5YjFiNzc5NGQwIiwidGkiOjE3MTM5NzY4MjcxNzF9fQ==',
  'posinfo': 'food=074_Zone01,nonfood=099_Zone01,express=074_Zone01',
  'priority': 'u=1, i',
  'referer': 'https://www.carrefouruae.com/mafuae/en/cream-chocolate-filled/oreo-original-36-8gx24/p/1944189?list_name=search%7Coreo&offer=offer_carrefour_',
  'sec-ch-ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'storeid': 'mafuae',
  'token': 'lM500_g78KDHOP8_34lBdmBtbCM',
  'traceparent': '00-99d9fba0fbe16d5cecd9839b1b7794d0-97760c45dae4969a-01',
  'tracestate': '3355720^@nr=0-1-3355720-1008803057-97760c45dae4969a----1713976827171',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
  'userid': 'anonymous',
  'x-requested-with': 'XMLHttpRequest'
}
conn.request("GET", "/api/v4/relevance/products/1944189?lang=en&placements=personal_page.echo_seed%7Citem_page.frequently_bought_together_web&displayCurr=AED&latitude=24.4658714&longitude=54.59926599999999&requireSponsProducts=true&categoryId=F1700000", payload, headers)
res = conn.getresponse()
data_product = res.read()
data_product = data_product.decode("utf-8")
data_product = json.loads(data_product)
print(data_product)
# Out:
# {'rcs': 'eF4dxLkNgDAMAMCGil0sxX-8AQVLJEaWKOiA-ZG44pblya3bKMUSyAoDmbNB-WjQyzhFBqbFer33eezoSoCOHB6dWKMBgambgJkT_vMHxhcU_A', 'placements': [{'htmlElementId': 'item_page_0', 'strategyName': 'EchoProducts', 'strategyMessage': 'echo_product', 'placementType': 'item_page', 'placement': 'item_page.echo_seed', 'recommendedProducts': [{'id': '1944189', 'ean': '7622202017728', 'category': [{'level': 1, 'id': 'F1700000', 'name': 'Food Cupboard', 'url': '/c/F1700000/'}, {'level': 2, 'id': 'F1710000', 'name': 'Biscuits, Crackers & Cakes', 'url': '/c/F1710000/'}, {'level': 3, 'id': 'F1710500', 'name': 'Filled Biscuits', 'url': '/c/F1710500/'}, {'level': 4, 'id': 'F1710501', 'name': 'Cream & Chocolate Filled', 'url': '/c/F1710501/'}], 'name': 'Oreo Original Cookies Monopoly Edition 36.8g Pack of 24', 'type': 'FOOD', 'preorder': False, 'isExpress': True, 'brand': {'id': '03044', 'name': 'Oreo'}, 'productOrigin': 'Bahrain', 'supplier': 'Carrefour', 'delivery': [], 'isBulk': False, 'bulkMessage': '', '
# ...
