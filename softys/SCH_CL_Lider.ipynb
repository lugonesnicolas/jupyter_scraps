# %%
# Importacion de librerias
import time
import json
import logging
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
username = 'spl7rorb75'
password = 's6_rtuzLl39yr0WjUI'
proxy = f"http://{username}:{password}@cl.smartproxy.com:30000"

# %%
url = "https://apps.lider.cl/supermercado/bff/search"

payload = json.dumps({
  "page": 1,
  "facets": [],
  "sortBy": "",
  "hitsPerPage": 16,
  "query": "lays"
})
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:128.0) Gecko/20100101 Firefox/128.0',
  'Accept': 'application/json, text/plain, */*',
  'Accept-Language': 'en-US,en;q=0.5',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'Content-Type': 'application/json',
  'X-FlowId': '751d16a5-112e-4416-9014-96af15da2ac8',
  'tenant': 'supermercado',
  'X-SessionId': '171d3d00-ee14-463a-8590-de15c5597b90',
  'x-channel': 'SOD',
  'Origin': 'https://www.lider.cl',
  'Connection': 'keep-alive',
  'Referer': 'https://www.lider.cl/',
  'Cookie': 'vtc=fQD_-XQKdR143QDjvyuqLI; _pxvid=305309d3-50fc-11ef-b178-6c07b3145acd; _gcl_au=1.1.1875602731.1722622955; _ga_LT7B42QQTE=GS1.1.1723556299.2.1.1723556327.0.0.0; _ga=GA1.1.1605522486.1722622955; _ga_835TB8N4KP=GS1.1.1723556299.2.1.1723556328.31.0.0; _ga_S5V4J9JZ4W=GS1.1.1723556300.2.1.1723556328.32.0.0; _ga_PNF51KE2NM=GS1.1.1723556301.2.0.1723556301.60.0.0; __pxvid=30e7f9f9-50fc-11ef-ba03-0242ac120002; _px3=91085dd157ec27a1856457c96528b3295661c59670ed1941fe4aabdfec0c91a2:2dbUG7IG5GT8wrn0x8OAsmM6oQEFrAC8MY1g6+awMlIdY2gzMYYZ+tqyBXTM1a4BG4/jNITiLj74wAJr++B6Sg==:1000:ihEgXCEFiMBb0d7NewqUJagqI+BSg5Ye6kSbsLPj7dUgOyQJOFFa9M5dBbdIZ9cYH/XCaBE8Wx+ezDiTYIc5/jqBol+bMrtrI9Uz4VT2kno4NMAyVCjikeyTeXUCySF77j2lrr+Ki9Ib1s5F8T5pSkdyJhslpNOBVFeb6eQGb7gx6w+O3SGqgF1EV/wg037JtSevXaqyYFlHXS48MPyr+RMDlWYA7BjZvJ0A8GBw+U4=; _tt_enable_cookie=1; _ttp=cFLVAR_mlxUaywBBu7EUeqPPoDn; fs_uid=#16PCMB#fc479c5e-918c-4974-965f-853cd0a4be3e:0285e6c0-0d14-4532-8e20-5ff4d4cdc830:1723556304131::1#/1754158970; _fbp=fb.1.1722622959976.540433419608167381; TSe3289311027=0801b8b042ab2000476f1e95659ced79fbff8e95cf6d9f346ae3091d9120eb3654c2021368de038308409d0d41113000f5377cd0d041727e74907c46f24a1617bfeb169cb483928ecee20779f284b22789bbe057b7735778c2ac5156df623933; _ga_LFTL75YJRF=GS1.1.1723556295.1.0.1723556298.0.0.0; bstc=eQYiljIFrZh73yN-wzjMKc; xpa=; xpm=3%2B1723556299%2BfQD_-XQKdR143QDjvyuqLI~%2B1; exp-ck=1; TS017e8d10=01e5446e1506303b45fd594306215a5929541912c71621bf0c974d7434cd51cf75d2eec79c5b377835516cbc25c95f38c8efa71676; TS01fffdff=01e5446e1506303b45fd594306215a5929541912c71621bf0c974d7434cd51cf75d2eec79c5b377835516cbc25c95f38c8efa71676; pxcts=4d76ae03-5979-11ef-8388-cd19ec3e0fe2; TS01cc7ea9=01c35f3b2b581a68303cc8c9c8c286ce782b891d50a9e7481fbdc19fed3fc72ee56fd29f1b7ce116c3845cdfa8035b5139b56454ff; _uetsid=4fc528b0597911ef88ac0be01654ffb1; _uetvid=32bf9ae050fc11ef8ae5d94fdbdf913a; fs_lua=1.1723556304131; vtc=fQD_-XQKdR143QDjvyuqLI',
  'Sec-Fetch-Dest': 'empty',
  'Sec-Fetch-Mode': 'cors',
  'Sec-Fetch-Site': 'same-site',
  'TE': 'trailers'
}

# %%
# Conexión  via https a la pagina
response = requests.request("POST", url, headers=headers, data=payload, proxies = {'http': proxy})
data = response.json()
data_products = data.get("products", "")

# %%
for i in data_products:
    title = i.get("displayName", "") if i.get("displayName", "") != None else ''
    description = i.get("description","") if i.get("description","") != None else ''
    brand = i.get("brand","") if i.get("brand","") != None else ''
    final_price = i.get("price","").get("BasePriceSales", "") if i.get("price","") != None else ''
    
    print(f"Title: {title}")
    print(f"Description: {description}")
    print(f"Brand: {brand}")
    print(f"FinalPrice: {final_price}\n")
# Out:
# Title: Papas Fritas Merken, 180 g
# Description: Papas Fritas Merken
# Brand: Lay'S
# FinalPrice: 2000
#
# Title: Papas Fritas Artesanas Sabor Original., 150 g
# Description: Papas Fritas Artesanas Sabor Original.
# Brand: Lay's
# FinalPrice: 2150
#
# Title: Papas Fritas Sabor Jamón Serrano, 180 g
# Description: Papas Fritas Sabor Jamón Serrano
# Brand: Lay's
# FinalPrice: 1990
#
# Title: Papas Fritas Corte Americano, 230 g
# Description: Papas Fritas Corte Americano
# Brand: Lay's
# FinalPrice: 2000
#
# Title: Papas Fritas Corte Liso, 230 g
# Description: Papas Fritas Corte Liso
# Brand: Lay's
# FinalPrice: 2000
#
# Title: Papas Fritas Sabor Orégano_, 180 g
# Description: Papas Fritas Sabor Orégano_
# Brand: Lay's
# FinalPrice: 1990
#
# Title: Papas Fritas Tarro Stax Crema y Cebolla, 134 g
# Description: Papas Fritas Tarro Stax Crema y Cebolla
# Brand: Lay's
# FinalPrice: 2290
#
# Title: Papas Fritas Stax Sabor Original Tarro, 134 g
# ...

# %%
driver = webdriver.Chrome()
driver.get(url)
time.sleep(1)

# %%
html = driver.page_source
driver.quit()
soup = BeautifulSoup(html, "lxml")

# %%
print(soup)
# Out:
# <html lang="es-AR"><head><style type="text/css">.styles_overlay__CLSq- {
#   background: rgba(0, 0, 0, 0.75);
#   display: flex;
#   align-items: flex-start;
#   position: fixed;
#   top: 0;
#   left: 0;
#   right: 0;
#   bottom: 0;
#   overflow-y: auto;
#   overflow-x: hidden;
#   z-index: 1000;
#   padding: 1.2rem;
# }
# .styles_overlayCenter__YHoO7 {
#   align-items: center;
# }
# .styles_modal__gNwvD {
#   max-width: 800px;
#   position: relative;
#   padding: 1.2rem;
#   background: #ffffff;
#   background-clip: padding-box;
#   box-shadow: 0 12px 15px 0 rgba(0, 0, 0, 0.25);
#   margin: auto;
# }
# .styles_closeButton__20ID4 {
#   position: absolute;
#   top: 14px;
#   right: 14px;
#   border: none;
#   padding: 0;
#   background-color: transparent;
#   display: flex;
# }
# .styles_closeIcon__1QwbI {
# }
# .styles_transitionEnter__3j_-a {
#   opacity: 0.01;
# }
# .styles_transitionEnterActive___eQs7 {
#   opacity: 1;
#   transition: opacity 500ms cubic-bezier(0.23, 1, 0.32, 1);
# ...

# %%
product_list = soup.select("article.vtex-product-summary-2-x-element.vtex-product-summary-2-x-element--defaultShelf.vtex-product-summary-2-x-element--cross-selling-shelf.vtex-product-summary-2-x-element--custom-landing-shelf.pointer.pt3.pb4.flex.flex-column.h-100")

# %%
for i in product_list:
    title = i.select_one("span.vtex-product-summary-2-x-productBrand.vtex-product-summary-2-x-productBrand--defaultShelf-name.vtex-product-summary-2-x-brandName.vtex-product-summary-2-x-brandName--defaultShelf-name.t-body").text if i.select_one("span.vtex-product-summary-2-x-productBrand.vtex-product-summary-2-x-productBrand--defaultShelf-name.vtex-product-summary-2-x-brandName.vtex-product-summary-2-x-brandName--defaultShelf-name.t-body") != None else ''
    old_price = i.select_one("div.vtex-search-result-3-x-galleryItem > section:nth-child(1) > a:nth-child(1) > article:nth-child(1) > div:nth-child(6) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > span").text if i.select_one("div.vtex-search-result-3-x-galleryItem > section:nth-child(1) > a:nth-child(1) > article:nth-child(1) > div:nth-child(6) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > span") != None else 0
    final_price = i.select_one("div.vtex-search-result-3-x-galleryItem > section:nth-child(1) > a:nth-child(1) > article:nth-child(1) > div:nth-child(6) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > span:nth-child(1) > span:nth-child(1)").text if i.select_one("div.vtex-search-result-3-x-galleryItem > section:nth-child(1) > a:nth-child(1) > article:nth-child(1) > div:nth-child(6) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(2) > span:nth-child(1) > span:nth-child(1)") != None else 0
    brand = i.select_one("div.vtex-search-result-3-x-galleryItem > section:nth-child(1) > a:nth-child(1) > article:nth-child(1) > div:nth-child(4) > span:nth-child(1)").text if i.select_one("div.vtex-search-result-3-x-galleryItem > section:nth-child(1) > a:nth-child(1) > article:nth-child(1) > div:nth-child(4) > span:nth-child(1)") != None else ''
    
    print(f"Title: {title}")
    print(f"Brand: {brand}")
    print(f"OldPrice: {old_price}")
    print(f"FinalPrice: {final_price}\n")
# Out:
# Title: LAYS CHEDDAR 77G
# Brand: Mir
# OldPrice: $ 2.508,00
# FinalPrice: $ 1.630,20
#
# Title: Papas fritas Lays Clásicas x 40 g
# Brand: Lay's
# OldPrice: $ 1.644,00
# FinalPrice: $ 1.007,20
#
# Title: Papas fritas Lays Clásicas x 85 g
# Brand: Lay's
# OldPrice: $ 2.508,00
# FinalPrice: $ 1.630,20
#
# Title: Papas fritas Lays Clásicas x 230 g
# Brand: Lay's
# OldPrice: $ 6.305,00
# FinalPrice: $ 4.098,25
#
# Title: Papas fritas sabor a queso y cebolla Lays x 34 g
# Brand: Lay's
# OldPrice: 0
# FinalPrice: $ 1.586,00
#
# Title: LAYS ACANALADAS FLAMIN HOT 30
# Brand: Mir
# OldPrice: $ 1.332,00
# FinalPrice: $ 1.065,60
#
# Title: Papas fritas Lays Clásicas x 330 g
# Brand: Lay's
# OldPrice: $ 7.292,00
# FinalPrice: $ 4.739,80
#
# Title: Papas fritas sabor a ketchup Lays x 77 g
# Brand: Lay's
# OldPrice: $ 2.508,00
# FinalPrice: $ 1.630,20
#
# Title: Papas fritas sabor a jamón serrano Lays x 34 g
# Brand: Lay's
# OldPrice: 0
# FinalPrice: $ 1.586,00
#
# ...
