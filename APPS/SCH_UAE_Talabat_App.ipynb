# %%
import requests
import json

url = "https://api.talabat.com/grocery/v1/ae/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/products/search"

payload = json.dumps({
  "config": "Control",
  "country_code": "ae",
  "is_darkstore": True,
  "language_code": "en",
  "limit": 20,
  "offset": 0,
  "query": "shampoo",
  "customer_id": None,
  "filters": {
    "variant": 2,
    "category_ids": []
  }
})
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'content-type': 'application/json',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6IjViZWRiOGZkZjQxYjRjNGM4MDgxNGRlMzk2NTFhZGNjIiwiaWQiOiI4MDYxZjdiODIyZjQ0MDVlIiwidGkiOjE3MTUwODk1Nzk2MzAsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-5bedb8fdf41b4c4c80814de39651adcc-8061f7b822f4405e-00',
  'tracestate': '346080@nr=0-2-938958-414461638-8061f7b822f4405e----1715089579630',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1715088150051.536399785542626270.uYxRL3Gkhf',
  'x-primary-request-id': '',
  'Cookie': '__cf_bm=b1ruXqUETQdIFiaLh8f6VEa0ZQHeo3c8jKW3jfM_Y4Y-1715088276-1.0.1.1-HsTRR794WuluJG28kl8VZfyeee57SQJM9yOkJuskt0EBVQ1J7anSeigNmivpbOaGY5t99b3K4InZ2sCHpoca7tYcsazawCLq7R3Aj.Vxg58; AWSALB=LkdYPwbuuOUoJwoZpIxZKYQhxuUagtWOZClppiJdTEIgUeQ9ok4uMFucJ3XyvXbHLWV5eFUVZHyA9LcRpZoWL1gRDI8WgNmzmI/wFE6RXRKvz2Gvxdw+FJJHXgZ6; AWSALBCORS=LkdYPwbuuOUoJwoZpIxZKYQhxuUagtWOZClppiJdTEIgUeQ9ok4uMFucJ3XyvXbHLWV5eFUVZHyA9LcRpZoWL1gRDI8WgNmzmI/wFE6RXRKvz2Gvxdw+FJJHXgZ6'
}

response = requests.request("POST", url, headers=headers, data=payload)
data = response.json()
print(data)
# Out:
# {'filters': {'categories': [{'count': 0, 'id': 'all', 'name': 'All'}, {'count': 136, 'id': '6fdbaa71-4bfc-4ca3-84c2-270f7b862a0f', 'name': 'Personal Care'}, {'count': 28, 'id': '8d5b40e9-7969-41aa-98f3-6ba1a7040fa7', 'name': 'Cleaning & Laundry'}, {'count': 5, 'id': 'a49eeddf-c4a6-4c8d-835e-95609b09732d', 'name': 'Baby Corner'}, {'count': 2, 'id': 'c60072bd-9c79-4691-b3e3-b7bacd9ce5c1', 'name': 'Happy Diwali'}]}, 'graphql_config': {'search_products_graphql': 'ae,kw,bh,qa,jo,iq,eg,om', 'search_vendors_graphql': ''}, 'item_counts': {'returned': 20, 'total': 166, 'total_high_precision_count': 110}, 'metadata': {'exp_oos_experiment': {'abTest': False, 'explanation': {'kind': 'DEFAULT_RULE'}, 'holdoutsEvaluations': None, 'relevantContext': 'googleClientId,userId,email,appVersion,country', 'trackInfo': {'flagEnabled': True, 'flagType': 'abntest', 'variationName': 'Variation3'}, 'variation': 'Variation3'}, 'rc_qcommerce_search_config': {'abTest': False, 'explanation': {'kind': 'RULE'}, 'hol
# ...

# %%
print(data)
# Out:
# {'filters': {'categories': [{'count': 0, 'id': 'all', 'name': 'All'}, {'count': 136, 'id': '6fdbaa71-4bfc-4ca3-84c2-270f7b862a0f', 'name': 'Personal Care'}, {'count': 28, 'id': '8d5b40e9-7969-41aa-98f3-6ba1a7040fa7', 'name': 'Cleaning & Laundry'}, {'count': 5, 'id': 'a49eeddf-c4a6-4c8d-835e-95609b09732d', 'name': 'Baby Corner'}, {'count': 2, 'id': 'c60072bd-9c79-4691-b3e3-b7bacd9ce5c1', 'name': 'Happy Diwali'}]}, 'graphql_config': {'search_products_graphql': 'ae,kw,bh,qa,jo,iq,eg,om', 'search_vendors_graphql': ''}, 'item_counts': {'returned': 20, 'total': 166, 'total_high_precision_count': 110}, 'metadata': {'exp_oos_experiment': {'abTest': False, 'explanation': {'kind': 'DEFAULT_RULE'}, 'holdoutsEvaluations': None, 'relevantContext': 'googleClientId,userId,email,appVersion,country', 'trackInfo': {'flagEnabled': True, 'flagType': 'abntest', 'variationName': 'Variation3'}, 'variation': 'Variation3'}, 'rc_qcommerce_search_config': {'abTest': False, 'explanation': {'kind': 'RULE'}, 'hol
# ...

# %%
# print(data['products'][4]['attributes'])
for i in data['products'][4]['attributes']:
    brand = ''
    if i.get('id', '') == 'brand':
        print(f"{i}\n")
# Out:
# {'id': 'brand', 'name': '', 'type': 'characteristic'}

# %%
for i in products[0:5]:
    title = i.get('name')
    sponsored = i.get('is_sponsored', False) if i.get('is_sponsored', False) != None else False

    print(f"Title: {title}")
    print(f"Sponsored: {sponsored}")
# Out:
# Title: Giovanni Tea Tree Triple Treat Shampoo 8.5 oz
# Sponsored: True
# Title: Sunsilk Soft And Smooth Shampoo 400 ml x 2 Pcs
# Sponsored: True
# Title: Dabur Vatika Naturals Honey & Egg Repair & Restore Shampoo, 2x400ml
# Sponsored: True
# Title: SUNSILK Shampoo, For Weak & Dull Hair, Strength & Shine, With Provitamin B5, Argenine & Coconut Oil, 400ml
# Sponsored: False
# Title: Tresemme Shampoo Keratin 400 ml + Tresemme Conditioner Keratin 400 ml
# Sponsored: False

# %%
for i in data['products']:
    print(i['name'])
    print(i.get('is_sponsored'))
# Out:
# Giovanni Tea Tree Triple Treat Shampoo 8.5 oz
# True
# Sunsilk Soft And Smooth Shampoo 400 ml x 2 Pcs
# True
# Dabur Vatika Naturals Honey & Egg Repair & Restore Shampoo, 2x400ml
# True
# SUNSILK Shampoo, For Weak & Dull Hair, Strength & Shine, With Provitamin B5, Argenine & Coconut Oil, 400ml
# False
# Tresemme Shampoo Keratin 400 ml + Tresemme Conditioner Keratin 400 ml
# False
# Pantene Pro-V Anti-Hair Fall Shampoo, 400ml
# False
# Elvive Hyaluron Moisture 72H Moisture Filling Shampoo 400 ml
# False
# Herbal Essences Bio:Renew Argan Oil of Morocco Shampoo, 400ml
# False
# Garnier Ultra Doux Avocado Oil & Shea Butter Nourishing Shampoo 400 ml
# False
# SUNSILK Shampoo, For Soft & Smooth Hair, Soft & Smooth, With Silk Protein, Argan Oil & Vitamin C, 400ml
# False
# Dove Thicken Ritual Lavender Shampoo 400 ml
# False
# Head & Shoulders Classic Clean Anti-Dandruff Shampoo, 400ml
# False
# Tresemme Keratin Smooth Shampoo with Argan Oil for Dry & Frizzy Hair 400 ml
# False
# ...

# %%
products = data['products']
position = 0
for i in products:
    # print(i)
    if position < 20:
        position += 1
        title = i.get('name','')
        description = i.get('description','')
        sponsored = i.get('is_sponsored')
        # brand = i['attributes'][13].get('id', '')
        # if brand == 'brand':
        #     brand = i['attributes'][13].get('name', '')
        # else:
        #     brand = i['attributes'][14].get('name', '')
        brand = ''
        atributes = i['attributes']
        for i in atributes:
            if i.get('id', '') == 'brand':
                brand = i.get('name', '')
        final_price = i.get('price',0)
        old_price = i.get('original_price',0)
        sku = i.get('sku','')
        
    
        print(f"Postition:{position}")
        print(f"Title:{title}")
        print(f"Description:{description[0:100]}")
        print(f"Brand:{brand}")
        print(f"FinalPrice:{final_price}")
        print(f"OldPrice:{old_price}")
        print(f"Sku:{sku}")
        print(f"Sponsored: {sponsored}\n")
# Out:
# Postition:1
# Title:Giovanni Tea Tree Triple Treat Shampoo 8.5 oz
# Description:GIOV TEA TREE TRIPLE TREAT SHAMPOO 8.5OZ:13008
# Brand:
# FinalPrice:0
# OldPrice:0
# Sku:
# Sponsored: True
#
# Postition:2
# Title:Sunsilk Soft And Smooth Shampoo 400 ml x 2 Pcs
# Description:It deeply nourishes your hair. It contains Cashmere Keratin to moisturize your hair deeply. It reduc
# Brand:
# FinalPrice:0
# OldPrice:0
# Sku:
# Sponsored: True
#
# Postition:3
# Title:Dabur Vatika Naturals Honey & Egg Repair & Restore Shampoo, 2x400ml
# Description:Rejuvenating Shampoo Intensively Nourishes And Contains The Extract Of Egg Which Is A Rich Source Of
# Brand:
# FinalPrice:0
# OldPrice:0
# Sku:
# Sponsored: True
#
# Postition:4
# Title:SUNSILK Shampoo, For Weak & Dull Hair, Strength & Shine, With Provitamin B5, Argenine & Coconut Oil, 400ml
# Description:• Sunsilk Strength and Shine Shampoo nourishes hair deeply, strengthens weak hair and protects hair
# Brand:
# FinalPrice:0
# OldPrice:0
# Sku:
# ...

# %% [markdown]
# # Headers

# %%
# Al Hosn
url = "https://api.talabat.com/grocery/v1/ae/vendors/3287c581-06dd-482d-9027-fa4b0fda4394/products/search"

payload = json.dumps({
  "config": "Control",
  "country_code": "ae",
  "is_darkstore": True,
  "language_code": "en",
  "limit": 20,
  "offset": 0,
  "query": "oreo",
  "customer_id": None,
  "filters": {
    "variant": 2,
    "category_ids": []
  }
})
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'content-type': 'application/json',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6ImY4NzgwMzVmNjYxMzQ2Njg5OGViOTRkMTBkN2EyOTIyIiwiaWQiOiI5Y2QxYTMzNDc4Nzc0NDUzIiwidGkiOjE3MTY5MjIzOTg1NjYsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-f878035f6613466898eb94d10d7a2922-9cd1a33478774453-00',
  'tracestate': '346080@nr=0-2-938958-414461638-9cd1a33478774453----1716922398566',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1716921611995.518264933258225844.TxT6Rl9tdZ',
  'x-primary-request-id': '',
  'x-weightables-enabled': 'true',
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"filters":{"categories":[{"count":0,"id":"all","name":"All"},{"count":58,"id":"d3c06146-8177-4a9d-8e74-b630fc7f1055","name":"Snacks \u0026 Chocolate"},{"count":19,"id":"dfa80548-bc8e-47d1-a91e-ca29dacdc45b","name":"Ice Cream"},{"count":7,"id":"2fa242e6-3927-46ac-8adc-4a7231242ab6","name":"Bakery"},{"count":7,"id":"b71d4ccc-c1d5-4cbf-8114-0eb053a9307c","name":"Protein \u0026 Special Diet"},{"count":4,"id":"a49eeddf-c4a6-4c8d-835e-95609b09732d","name":"Baby Corner"}]},"graphql_config":{"search_products_graphql":"","search_vendors_graphql":""},"item_counts":{"returned":20,"total":88,"total_high_precision_count":10},"metadata":{"exp_qcommerce_in_vendor_search_config":{"abTest":false,"explanation":{"kind":"OFF_VARIATION"},"holdoutsEvaluations":null,"relevantContext":"","trackInfo":{"flagEnabled":false,"flagType":"abntest","variationName":"Variation2"},"variation":"Variation2"},"rc_qcommerce_search_config":{"abTest":false,"explanation":{"kind":"RULE"},"holdoutsEvaluations":null,"relevantC
# ...

# %%
# Al Warqa1
url = "https://api.talabat.com/grocery/v1/ae/vendors/3e4a1b63-2010-4818-a132-d1060e39e18b/products/search"

payload = json.dumps({
  "config": "Control",
  "country_code": "ae",
  "is_darkstore": True,
  "language_code": "en",
  "limit": 20,
  "offset": 0,
  "query": "oreo",
  "customer_id": None,
  "filters": {
    "variant": 2,
    "category_ids": []
  }
})
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'content-type': 'application/json',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6ImU4ZmExMmJhYmNmNzRlNmQ5YzNlMTUyZTE5YmY3ZWQ3IiwiaWQiOiI3NjdjNjA5NmEyZjI0YjRlIiwidGkiOjE3MTY5MjI2MDg0OTgsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-e8fa12babcf74e6d9c3e152e19bf7ed7-767c6096a2f24b4e-00',
  'tracestate': '346080@nr=0-2-938958-414461638-767c6096a2f24b4e----1716922608498',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1716921611995.518264933258225844.TxT6Rl9tdZ',
  'x-primary-request-id': '',
  'x-weightables-enabled': 'true',
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)

# %%
# BussinesBay
url = "https://api.talabat.com/grocery/v1/ae/vendors/f2a9da55-9bcb-4f16-a647-0952aff7f180/products/search"

payload = json.dumps({
  "config": "Control",
  "country_code": "ae",
  "is_darkstore": True,
  "language_code": "en",
  "limit": 20,
  "offset": 0,
  "query": "oreo",
  "customer_id": None,
  "filters": {
    "variant": 2,
    "category_ids": []
  }
})
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'content-type': 'application/json',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6IjA3MTUwMzliYTUxZDQ3ZWFhZGZjNWI0ZmNhMWFhZmZlIiwiaWQiOiIxZmM1NDBhNzU2OGM0OTJmIiwidGkiOjE3MTY5MjI3MTU4ODIsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-0715039ba51d47eaadfc5b4fca1aaffe-1fc540a7568c492f-00',
  'tracestate': '346080@nr=0-2-938958-414461638-1fc540a7568c492f----1716922715882',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1716921611995.518264933258225844.TxT6Rl9tdZ',
  'x-primary-request-id': '',
  'x-weightables-enabled': 'true',
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)

# %%
# Muwailah
url = "https://api.talabat.com/grocery/v1/ae/vendors/f58fe865-a5eb-4cfc-add6-0bf9293514d9/products/search"

payload = json.dumps({
  "config": "Control",
  "country_code": "ae",
  "is_darkstore": True,
  "language_code": "en",
  "limit": 20,
  "offset": 0,
  "query": "oreo",
  "customer_id": None,
  "filters": {
    "variant": 2,
    "category_ids": []
  }
})
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'content-type': 'application/json',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6ImRjNmMxZjdlODBkZTQzOWZhZTZlYWRmZDlkNTg1OTA4IiwiaWQiOiJhNzI1OWJkZDdhMTE0MzU1IiwidGkiOjE3MTY5MjI4NDE1OTksInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-dc6c1f7e80de439fae6eadfd9d585908-a7259bdd7a114355-00',
  'tracestate': '346080@nr=0-2-938958-414461638-a7259bdd7a114355----1716922841599',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1716921611995.518264933258225844.TxT6Rl9tdZ',
  'x-primary-request-id': '',
  'x-weightables-enabled': 'true',
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
