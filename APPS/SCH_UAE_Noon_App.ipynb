# %%
import requests

# %%
username = 'user-spwnapellv-country-ae-city-dubai'
password = '3dxWxvajxn4k7SiF4G'
proxy = f"http://{username}:{password}@gate.smartproxy.com:10001"

# %%
url = "https://api-app-instant.noon.com/_svc/catalog/search?q=cake flour"

payload = {}
headers = {
  'accept': 'application/json, text/plain, */*',
  'accept-encoding': 'gzip',
  'cache-control': 'no-cache',
  'connection': 'Keep-Alive',
  'content-type': 'application/json',
  'user-agent': 'okhttp/4.11.0',
  'x-abx': 'ipl_entrypoint_v2=1,ipl_v2=1,noon_pass=1,otp_login=1',
  'x-aby': '{"ipl_entrypoint_v2.enabled":1,"ipl_v2.enabled":1,"noon_pass.enabled":1,"otp_login.enabled":1}',
  'x-border-enabled': 'true',
  'x-build': '4102',
  'x-content': 'mobile',
  'x-device-id': '6878ce25372efc2f',
  'x-ecom-zonecode': 'AE_DXB-S3',
  'x-experience': 'nooninstant',
  'x-food-zonecode': 'FOOD-AE-DXB-HUB5-BARSHA_SOUTH',
  'x-lat': '251095970',
  'x-lng': '551971345',
  'x-locale': 'en-ae',
  'x-mp': 'nooninstant',
  'x-nooninstant-zonecode': 'W00000123A',
  'x-noonnownow-zonecode': 'NOWNOW-AE-DXB-HUB14-BARSHA_SOUTH',
  'x-platform': 'android',
  'x-rocket-enabled': 'true',
  'x-rocket-mp-zonecode': 'W00067526A',
  'x-rocket-zonecode': 'W00067526A',
  'x-visitor-id': 'b56bf1ae-6acc-4150-b11c-1ce9ab8171fd'
}

# %%
response = requests.request("GET", url, headers=headers, data=payload, proxies = {'https': proxy})
data = response.json()

# %%
print(data['results'][1])
# Out:
# {'modules': [{'type': 'instantProductBox', 'numPerRow': 2, 'products': [{'sku': 'ZCDC88A2F3341FE226665Z-1', 'title': 'All Purpose Flour', 'brand': 'Al Baker', 'brand_code': 'al_baker', 'id_partner': 9411, 'size_info': '2kg', 'image_keys': ['v1661160355/N12278246A_1', 'v1661160355/N12278246A_2', 'v1661160356/N12278246A_3', 'v1661160357/N12278246A_4', 'v1661160357/N12278246A_5', 'v1661160357/N12278246A_6', 'v1629696685/N12278246A_15'], 'is_buyable': True, 'not_buyable_reason': None, 'price': 11.45, 'offerPrice': 11.45, 'strikedPrice': 11.5, 'label': None, 'sale_price': None, 'discountPercent': None, 'max_qty': 37, 'salePriceQty': None, 'isCustomizable': False, 'customizationOptions': None, 'exclusivePriceDetails': None, 'salePriceDetails': None, 'lockedProductDetails': None, 'vipPriceDetails': None, 'media': [{'type': 'image', 'path': 'v1661160355/N12278246A_1', 'isAbsolutePath': False, 'thumbnail': None}, {'type': 'image', 'path': 'v1661160355/N12278246A_2', 'isAbsolutePath': False, '
# ...

# %%
grid = {}
rows = data['results']
position = 0
for i in rows:
    if position < 20:
        try: # Primer producto de las fila
            if i['modules'][0].get('widgetCode', '') == '' or i['modules'][0].get('widgetCode', '') == None:
                product1 = i['modules'][0]['products'][0]
                product1_title = product1.get('title', '')
                product1_final_price = product1.get('offerPrice', 0)
                product1_old_price = product1.get('strikedPrice', 0)
                if product1_old_price == 0 or product1_old_price == None:
                    product1_old_price = product1.get('price', 0)
                product1_sku = product1.get('sku', '')
                product1_brand = product1.get('brand', '')
                grid[position] = {'title':product1_title, 'final_price':product1_final_price, 'old_price':product1_old_price, 'brand':product1_brand}
                position += 1
        except Exception as e:
            print(f"No se pudo Procesar el primer producto - {e} - de la fila {position} - {i}")
            # product1_title = ''
            # product1_final_price = 0
            # product1_old_price = 0
            # product1_brand = ''
            # sku = ''
            # grid[position] = {'title':product1_title, 'final_price':product1_final_price, 'old_price':product1_old_price, 'brand':product1_brand}
            position += 1
            
        
    
        
        try: # Segundo producto de la fila
            if i['modules'][0].get('widgetCode', '') == '' or i['modules'][0].get('widgetCode', '') == None:
                product2 = i['modules'][0]['products'][1]
                product2_title = product2.get('title', '')
                product2_final_price = product2.get('offerPrice', 0)
                product2_old_price = product2.get('strikedPrice', 0)
                if product2_old_price == 0 or product2_old_price == None:
                    product2_old_price = product2.get('price', 0)
                product2_sku = product2.get('sku', '')
                product2_brand = product2.get('brand', '')
                grid[position] = {'title':product2_title, 'final_price':product2_final_price, 'old_price':product2_old_price, 'brand':product2_brand}
                position += 1
        except Exception as e:
            print(f"No se pudo Procesar el segundo producto - {e} - de la fila {position}")
            # product2_title = ''
            # product2_final_price = 0
            # product2_old_price = 0
            # product2_brand = ''
            # sku = ''
            # grid[position] = {'title':product2_title, 'final_price':product2_final_price, 'old_price':product2_old_price, 'brand':product2_brand}
            position += 1
        

for i in grid:
    print(f"Position{i+1}:{grid[i]}")
# Out:
# Position1:{'title': 'Self Raising Cake Flour', 'final_price': 8.6, 'old_price': 12.24, 'brand': 'Al Baker'}
# Position2:{'title': 'All Purpose Flour', 'final_price': 6.1, 'old_price': 6.5, 'brand': 'Al Baker'}
# Position3:{'title': 'All Purpose Flour', 'final_price': 11.45, 'old_price': 11.5, 'brand': 'Al Baker'}
# Position4:{'title': 'Baking Powder', 'final_price': 4.35, 'old_price': 4.7, 'brand': "Foster Clark's"}

# %% [markdown]
# # Test Al Barsha

# %%
url = "https://api-app-instant.noon.com/_svc/catalog/search?q=oreo"

payload = {}
headers = {
  'accept': 'application/json, text/plain, */*',
  'accept-encoding': 'gzip',
  'cache-control': 'no-cache',
  'connection': 'Keep-Alive',
  'cookie': 'dcae=1; x-location-ecom-ae=eyJsYXQiOiAyNTA4MzgyNjcsICJsbmciOiA1NTIyMDM5NjYsICJhcmVhIjogIkFsIEJhcnNoYSJ9; x-available-ae=ecom-food-nooninstant-noonnownow-money; x-location-nooninstant-ae=eyJsYXQiOiAyNTA4MzgyNjUsICJsbmciOiA1NTIyMDM5NjMsICJhcmVhIjogIkFsIEJhcnNoYSJ9; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiJhYzRjZTRhZTI3MTU0ZmI1YmY0NzNjYzRhMjcwMGY5ZSIsImlhdCI6MTcxNTE3MTg4OSwiZXhwIjoxNzE1MTcyMTg5fQ.xHoTTKDOZ5xqnc0Rxx23Fl7-4DttOPjMpUb7KozFhJA; ak_bmsc=3787C570150EA5058C0F8099C8D6E5F2~000000000000000000000000000000~; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiI3ZjM4MjgzYjI0OWM0ZTg5YTkwNGQwOTE4OGU3NTcxYSIsImlhdCI6MTcxNTEwMDk1NywiZXhwIjoxNzE1MTAxMjU3fQ.uSoCjJPQ90-h0Pqm4RBfJcpBfJltb2AyJI819VQ50Tk',
  'host': 'api-app-instant.noon.com',
  'user-agent': 'okhttp/4.11.0',
  'x-abx': 'ipl_entrypoint_v2=1,ipl_v2=1,noon_pass=1,otp_login=1',
  'x-aby': '{"ipl_entrypoint_v2.enabled":1,"ipl_v2.enabled":1,"noon_pass.enabled":1,"otp_login.enabled":1}',
  'x-border-enabled': 'true',
  'x-build': '4102',
  'x-content': 'mobile',
  'x-device-id': '6878ce25372efc2f',
  'x-ecom-zonecode': 'AE_DXB-S3',
  'x-experience': 'nooninstant',
  'x-food-zonecode': 'FOOD-AE-DXB-HUB5-BARSHA_SOUTH',
  'x-lat': '250838265',
  'x-lng': '552203963',
  'x-locale': 'en-ae',
  'x-mp': 'nooninstant',
  'x-nooninstant-zonecode': 'W00057638A',
  'x-noonnownow-zonecode': 'NOWNOW-AE-DXB-HUB84-BARSHA_SOUTH',
  'x-platform': 'android',
  'x-rocket-enabled': 'true',
  'x-rocket-zonecode': 'W00067526A',
  'x-visitor-id': 'b56bf1ae-6acc-4150-b11c-1ce9ab8171fd'
}

response = requests.request("GET", url, headers=headers, data=payload, proxies = {'https': proxy})
data = response.json()
grid = {}
rows = data['results']
position = 1
for i in rows:
    product1 = i['modules'][0]['products'][0]
    grid[position] = {'title':product1['title'], 'old_price':product1['offerPrice'], 'final_price':product1['price'], 'brand':product1['brand']}
    position += 1

    product2 = i['modules'][0]['products'][1]
    grid[position] = {'title':product2['title'], 'old_price':product2['offerPrice'], 'final_price':product2['price'], 'brand':product2['brand']}
    position += 1

for i in grid:
    print(f"Position{i}:{grid[i]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 39
#      37 position = 1
#      38 for i in rows:
# ---> 39     product1 = i['modules'][0]['products'][0]
#      40     grid[position] = {'title':product1['title'], 'old_price':product1['offerPrice'], 'final_price':product1['price'], 'brand':product1['brand']}
#      41     position += 1
#
# KeyError: 'products'

# %% [markdown]
# # Test Silicon Oasis

# %%
url = "https://api-app-instant.noon.com/_svc/catalog/search?q=Oreo"

payload = {}
headers = {
  'accept': 'application/json, text/plain, */*',
  'accept-encoding': 'gzip',
  'cache-control': 'no-cache',
  'connection': 'Keep-Alive',
  'cookie': 'dcae=1; x-location-ecom-ae=eyJsYXQiOiAyNTA4MzgyNjcsICJsbmciOiA1NTIyMDM5NjYsICJhcmVhIjogIkFsIEJhcnNoYSJ9; x-available-ae=ecom-food-nooninstant-noonnownow-money; ak_bmsc=3787C570150EA5058C0F8099C8D6E5F2~000000000000000000000000000000~; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiIyZWRhYzVmZWUxNjM0YmEzODQ2ZjVlMjJkNjg2ZWFiNiIsImlhdCI6MTcxNTE3MjE5OCwiZXhwIjoxNzE1MTcyNDk4fQ.NqaW0vEp42eTjGigJUSXTvUsPIrpT4iIBT5M6oFc4Yc; x-location-nooninstant-ae=eyJsYXQiOiAyNTEyNDQ4ODgsICJsbmciOiA1NTQwMzc1NjgsICJhcmVhIjogIlVubmFtZWQgUm9hZCAtIER1YmFpIFNpbGljb24gT2FzaXMgLSBEdWJhaSJ9; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiI3ZjM4MjgzYjI0OWM0ZTg5YTkwNGQwOTE4OGU3NTcxYSIsImlhdCI6MTcxNTEwMDk1NywiZXhwIjoxNzE1MTAxMjU3fQ.uSoCjJPQ90-h0Pqm4RBfJcpBfJltb2AyJI819VQ50Tk',
  'host': 'api-app-instant.noon.com',
  'user-agent': 'okhttp/4.11.0',
  'x-abx': 'ipl_entrypoint_v2=1,ipl_v2=1,noon_pass=1,otp_login=1',
  'x-aby': '{"ipl_entrypoint_v2.enabled":1,"ipl_v2.enabled":1,"noon_pass.enabled":1,"otp_login.enabled":1}',
  'x-border-enabled': 'true',
  'x-build': '4102',
  'x-content': 'mobile',
  'x-device-id': '6878ce25372efc2f',
  'x-ecom-zonecode': 'AE_DXB-S3',
  'x-experience': 'nooninstant',
  'x-food-zonecode': 'FOOD-AE-DXB-HUB5-BARSHA_SOUTH',
  'x-lat': '251244888',
  'x-lng': '554037568',
  'x-locale': 'en-ae',
  'x-mp': 'nooninstant',
  'x-nooninstant-zonecode': 'W00000146A',
  'x-noonnownow-zonecode': 'NOWNOW-AE-DXB-HUB84-BARSHA_SOUTH',
  'x-platform': 'android',
  'x-rocket-enabled': 'true',
  'x-rocket-zonecode': 'W00067526A',
  'x-visitor-id': 'b56bf1ae-6acc-4150-b11c-1ce9ab8171fd'
}

response = requests.request("GET", url, headers=headers, data=payload, proxies = {'https': proxy})
data = response.json()
grid = {}
rows = data['results']
position = 1
for i in rows:
    product1 = i['modules'][0]['products'][0]
    grid[position] = {'title':product1['title'], 'old_price':product1['offerPrice'], 'final_price':product1['price'], 'brand':product1['brand']}
    position += 1

    product2 = i['modules'][0]['products'][1]
    grid[position] = {'title':product2['title'], 'old_price':product2['offerPrice'], 'final_price':product2['price'], 'brand':product2['brand']}
    position += 1

for i in grid:
    print(f"Position{i}:{grid[i]}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 39
#      37 position = 1
#      38 for i in rows:
# ---> 39     product1 = i['modules'][0]['products'][0]
#      40     grid[position] = {'title':product1['title'], 'old_price':product1['offerPrice'], 'final_price':product1['price'], 'brand':product1['brand']}
#      41     position += 1
#
# KeyError: 'products'

# %% [markdown]
# # Test KEYWORDS

# %%
keywords = ["pampers","baby wipes","water wipes","diaper","newborn diaper"]
for i in keywords:
    url_k = f"https://api-app-instant.noon.com/_svc/catalog/search?q={i}"
    response = requests.request("GET", url_k, headers=headers, data=payload, proxies = {'https': proxy})
    data = response.json()
    
    grid = {}
    rows = data['results']
    position = 0
    for i in rows:
        if position < 20:
            try: # Primer producto de las fila
                if i['modules'][0].get('widgetCode', '') == '' or i['modules'][0].get('widgetCode', '') == None:
                    product1 = i['modules'][0]['products'][0]
                    product1_title = product1.get('title', '')
                    product1_final_price = product1.get('price', 0)
                    product1_old_price = product1.get('strikedPrice', 0)
                    if product1_old_price == 0 or product1_old_price == None:
                        product1_old_price = product1.get('offerPrice', 0)
                    product1_sku = product1.get('sku', '')
                    product1_brand = product1.get('brand', '')
                    grid[position] = {'title':product1_title, 'final_price':product1_final_price, 'old_price':product1_old_price, 'brand':product1_brand}
                    position += 1
            except Exception as e:
                print(f"No se pudo Procesar el primer producto - {e} - de la fila {position} - {i}")
                product1_title = ''
                product1_final_price = 0
                product1_old_price = 0
                product1_brand = ''
                sku = ''
                grid[position] = {'title':product1_title, 'final_price':product1_final_price, 'old_price':product1_old_price, 'brand':product1_brand}
                position += 1
                
            
        
            
            try: # Segundo producto de la fila
                if i['modules'][0].get('widgetCode', '') == '' or i['modules'][0].get('widgetCode', '') == None:
                    product2 = i['modules'][0]['products'][1]
                    product2_title = product2.get('title', '')
                    product2_final_price = product2.get('price', 0)
                    product2_old_price = product2.get('strikedPrice', 0)
                    if product2_old_price == 0 or product2_old_price == None:
                        product2_old_price = product2.get('offerPrice', 0)
                    product2_sku = product2.get('sku', '')
                    product2_brand = product2.get('brand', '')
                    grid[position] = {'title':product2_title, 'final_price':product2_final_price, 'old_price':product2_old_price, 'brand':product2_brand}
                    position += 1
            except Exception as e:
                print(f"No se pudo Procesar el segundo producto - {e} - de la fila {position} - {i}")
                product2_title = ''
                product2_final_price = 0
                product2_old_price = 0
                product2_brand = ''
                sku = ''
                grid[position] = {'title':product2_title, 'final_price':product2_final_price, 'old_price':product2_old_price, 'brand':product2_brand}
                position += 1
            
    
    for i in grid:
        print(f"Position{i+1}:{grid[i]}")
    print(f"\n\n")
# Out:
# Position1:{'title': 'Baby-Dry Pants with Aloe Vera Lotion, 360 Fit , Size 5, 12-18kg, Carry Pack, 22 Count Size 5, 12-18 Kg', 'final_price': 33.3, 'old_price': 33.3, 'brand': 'Pampers'}
# Position2:{'title': 'Premium Care Newborn Taped Diapers, Size 2, 3-8kg,  Softest Absorption for Ultimate Skin Protection, 136 Count', 'final_price': 80.35, 'old_price': 100, 'brand': 'Pampers'}
# Position3:{'title': 'Baby Dry Pants Diapers with Aloe Vera Lotion 360 Fit & up to 100% Leakproof Size 6 16-21kg Mega Pack 44 Count', 'final_price': 72.15, 'old_price': 72.15, 'brand': 'Pampers'}
# Position4:{'title': 'Baby-Dry Pants with Aloe Vera Lotion, 360 Fit , Size 5, 12-18kg, Mega Pack, 48 Count', 'final_price': 72.15, 'old_price': 72.15, 'brand': 'Pampers'}
# Position5:{'title': 'Baby-Dry Taped Diapers with Aloe Vera Lotion, Leakage Protection, Size 4, 9-14kg, 76 Count Size 4, 9-14 Kg', 'final_price': 87.71, 'old_price': 87.71, 'brand': 'Pampers'}
# ...
