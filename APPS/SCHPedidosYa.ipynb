# %%
# Importacion de librerias necesarias
import requests
import re
from bs4 import BeautifulSoup
import json
from BeOnFastCode import just_price


# Proxy y datos como header para la coneccion
username = 'Ec0m37ry'
password = 'fK7Ulvdm8zSVnyn22+'
proxy = f"https://{username}:{password}@ar.smartproxy.com:10000"

url = "https://web-apps.pedidosya.com/qc-gateway/qc-search-results-service/v1/search/vendors/285567/products?offset=0&page=0&limit=50&search=oreo&origin=SectionDetails&businessType=GROCERIES"
payload = {}
headers = {
  'accept': '*/*',
  'accept-encoding': 'gzip, deflate',
  'accept-language': 'es-AR,es;q=0.9,en-US;q=0.8,en;q=0.7',
  'authorization': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....hZmn4OqCAaHT27TYb8vaXB3eAZQd2x7y6b9EM1cELQHF7vKd2fBghrPBo49Zxs2S6nIzf-ORm7PGd1rTLIj79AGKwAFSukCk2rwJeTTOPlQgeemoj6F2l1k1qX4VCtDXQ1Pyu1-8a8qNO0KQkzxdZ0gsan_8PvTGL3jkLTPby0qdbC7UJDTiDjire4G7RzPmkDk3xy-uixxeu8kWhaRR0FXVQDlHfoUmKKe8wb02zPCmtoP8_pvq41LnP9DYW6Ep5_NB_3jc0mHe0ncSyRpc0itjLBIjUh1OkzJ9WH2i6hOHgSM3IFqWx1_avS3L4lHT_Q4H9R1Hn8OY2K_BdNvIQQ',
  'baggage': 'sentry-environment=live,sentry-release=web-app-groceries-section-detail%406.80.0,sentry-public_key=bf9c82696a97a4f49831de445729d6c4,sentry-trace_id=b7f9bf28136f4588908a0d2b04c2ad44,sentry-sample_rate=0.01,sentry-sampled=false',
  'cache-control': 'no-cache',
  'connection': 'keep-alive',
  'cookie': '__cf_bm=UMFjB.bKRaViktkJP51IztM1sFHmoruTydIUgQUhW_Y-1728911924-1.0.1.1-4esCetjGN6EeyHClsyI5f2oTqY59mP8dvDh6cipjz9O14EBEti_1N1xkKj398Yd3ESU9C9RJrrx_6y77G3YqDA; peya.webview=...; peya.webview.sig=frGX1iH0M9G7gyF4Nr7DlgIXbLQ',
  'host': 'web-apps.pedidosya.com',
  'peya-app-platform': 'android',
  'peya-app-version': '8.28.7.2',
  'peya-context-country': 'ar',
  'peya-device-id': 'db9283feb4cf6855',
  'peya-global-entity-id': 'PY_ar',
  'peya-microsite-token-type': 'APP',
  'peya-os-version': '34',
  'peya-perseus-client-id': '1725396040934.581078583217633963.h3fngIeUIf',
  'peya-perseus-hitmatch-id': '1728912018557.542380124395099611.4OWClLYK2Z',
  'peya-perseus-session-id': '1728911876882.825344857135622868.h27o3gjlGK',
  'peya-session-id': '228c4ce9-0f7b-40d5-a347-d2305dd8c301',
  'peya-session-timestamp': '1728911876882',
  'peya-trace-id': '23d989d0-878d-4227-90bb-4da4cd9eed52',
  'peya-whitelabel-id': 'com.pedidosya',
  'pragma': 'no-cache',
  'referer': 'https://web-apps.pedidosya.com/groceries-section-detail/?c=.ar&lat=-34.5528754&lng=-58.4653203&age_validated=false&cart_id=C1B11d9a7aa3445e87460b39e3827700de99ae6e8f144daf97cfaea246905da0&partner_id=285567&origin=shop_details&overrideBack=true&show_navbar=true&show_searchbar=true&search_type=search_sx_open',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'sentry-trace': 'b7f9bf28136f4588908a0d2b04c2ad44-be61a566fa844471-0',
  'user-agent': 'Mozilla/5.0 (Linux; Android 14; sdk_gphone64_x86_64 Build/UE1A.230829.036.A1; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/113.0.5672.136 Mobile Safari/537.36',
  'x-requested-with': 'com.pedidosya'
}

# Consulta y extraccion de data
response = requests.request("GET", url, data=payload, headers=headers, proxies = {'https': proxy})
print(response.status_code)
data_json = response.json()
data_product = data_json.get('results', '')

# Parseo de la data
for product in data_product:
    title = product.get('name', '')
    brand = product.get('defaultBrandName', '')
    price = product.get('pricing', '')
    final_price = price.get('price', '')
    old_price = price.get('beforePrice', '')
    old_price = 0 if old_price == '' else old_price
    image = product.get('image', '')

    print(f"Title: {title}")
    print(f"Brand: {brand}")
    print(f"FinalPrice: {final_price}")
    print(f"OldPrice: {old_price}")
    print(f"Image: {image}\n")
# Out:
# 403

# %%
url = "https://client-api-gateway.pedidosya.com/v1/alchemist-resolver/resolve"

payload = "{\"data\":{\"businessType\":\"groceries\",\"context\":{\"actionOrigin\":\"search_autocomplete\",\"flowOrigin\":\"products_qc\",\"locationArea\":\"18944\"},\"countryId\":3,\"filters\":[],\"location\":{\"lat\":-34.5528754,\"long\":-58.4653203},\"origin\":\"shop_details\",\"query\":\"Oreo\",\"vendorId\":\"285567\"},\"section\":\"PRODUCT_QC_RESULTS\"}"
headers = {
  'accept-encoding': 'gzip',
  'authorization': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....N5t9Pm_7vr535IK7q4qr0AJEt8KWTx1l80qmtnfgqyTp_ujFG6O3VegtfFCmWMN3iD8cXIPAXCwase1p4nHJn4NXa19d7gdhrGVmDNBjts-qU7FJVGD1YpEnLtPFIvb_mya0Z2ENC-jdnNOuyBdo4tTNBHkNnWZrLgsysOvE-kgEn1U6VJofgKMRuyrxsDfgiKT4rvOyPqcPJfFZ5cyqUtpn6wbb0K2WIW1C7kup7JM7LQ_hijtKQbFhl0klkL0nfOBonwVNJJnSUK2ffUb-g5-Am4iGHJTQWzxxM3UGpetZDWrmuaFPqo26cLLB9IhbjTIXqB4h7V6wuJzDthXcXA',
  'baggage': 'sentry-environment=production,sentry-public_key=aa27ec0b39de46e3ad47971be7ad0fba,sentry-release=9.5.6.1,sentry-trace_id=4452627829a54d69a70a2a45dc512589',
  'connection': 'Keep-Alive',
  'content-type': 'application/json; charset=UTF-8',
  'host': 'client-api-gateway.pedidosya.com',
  'origin': 'PedidosYa',
  'peya-app-platform': 'android',
  'peya-app-version': '9.5.6.1',
  'peya-device-id': 'db9283feb4cf6855',
  'peya-global-entity-id': 'PY_ar',
  'peya-os-version': '34',
  'peya-performance-class': 'LOW_END',
  'peya-perseus-client-id': '1725396040934.581078583217633963.h3fngIeUIf',
  'peya-perseus-hitmatch-id': '1739543095506.808606497863691275.eVJNxv7Y3Y',
  'peya-perseus-sdk-version': '3.6.0',
  'peya-perseus-session-id': '1739543081505.171151203148733939.g7CmZTZGfD',
  'peya-screen-dpi': '3',
  'peya-session-id': 'be4061d3-70a0-458c-912d-520f11c509cb',
  'peya-session-timestamp': '1739543081505',
  'peya-trace-id': '25545a2f-963a-40cc-9822-d63a0e50d417',
  'peya-whitelabel-id': 'com.pedidosya',
  'sentry-trace': '4452627829a54d69a70a2a45dc512589-1a409efd66f94639',
  'user-agent': 'google',
  'x-px-authorization': '3:2603e61c637525cda045713f83a9487a2cb390c3733ff315f6904862e48cedb8:VFoBmX5ovaKBd/SlzaYjOgyFLed70LY/7GcoHUc5UwqTx5lAzfD96p0aj8BLYg8pljfo3fjuvLiNFV7up6gV2Q==:1000:Rlp60+2i0HsAoIx18yay7w5PACl+VCYpezcbDRlzR0yRWSrFz+yQzdOLa+ygTiC6GZNPthI4f0qFh2HJftIOewXSBPWGBnXa4d3NRiiXcAzV5s0dyZm4SuNWP36oZitJjdb6mlcpWRHULKD5ZeAUV6rR+KWaJyYNZpiE9a9ut3E+hKEtrbzc6gWiD5h7DxSk7DpuVBwMa9Ij57GIKY8rmoIr7rAgMdAmNwD44ofGJz8=',
  'x-px-device-fp': 'db9283feb4cf6855',
  'x-px-device-model': 'sdk_gphone64_x86_64',
  'x-px-hello': 'VgJQAAMKBAEeVlJQVR4CAlZVHlEFCwEeBwRQVlYAAgcFV1dS',
  'x-px-mobile-sdk-version': '3.3.0',
  'x-px-os': 'Android',
  'x-px-os-version': '14',
  'x-px-uuid': 'e1c30972-eacf-11ef-b682-47cee3146dda',
  'x-px-vid': 'c6d92520-6a34-11ef-8ad2-498b7336ef21',
  'x-trace-id': 'be4061d3-70a0-458c-912d-520f11c509cb',
  'Cookie': '__cf_bm=XC7.BCF5ZRuiytD9T3SswVLGGCABZeAcPubYTeXbyls-1739543278-1.0.1.1-o3fW2Zypu_s7WTmMajLObwE66luwkF.u6GFlUpXnb9xoFIzDJHpNLvmdGKuFuuxtM9NQ1gAV0noEk4VRRBKs4A'
}

response = requests.request("POST", url, headers=headers, data=payload)

data_json = response.json()

# %%
# count = 0
# childrens = data_json.get("children", "")
# for i in childrens:
#     data_products = i.get("children", "") if i.get("children", "") != [] else None
#     if data_products:
#         data_products = i.get("children", "")
#         for j in data_products:
#             content = j.get("content", "")
#             count += 1
#             print(content)
# print(count)

# %%
products = [
    product_data.get("content", "")  # Obtiene el contenido de cada producto
    for children in data_json.get("children", [])  # Itera sobre los children, todo el contenido
    for product_data in children.get("children") or []  # Evita None asegurándose de que sea una lista
    if product_data.get("content", None) not in [None, "", []]  # Filtra valores vacíos
]

# %%
for i in products:
    title = i.get("name", "")
    pricing = i.get("pricing", "")
    final_price = pricing.get("price", "0") if pricing.get("price", "0") != None else "0"
    final_price = just_price(price_str=final_price, dotted_price=True)
    old_price = pricing.get("beforePrice", "0") if pricing.get("beforePrice", "0") != "" else "0"
    old_price = just_price(price_str=old_price, dotted_price=True)
    
    
    
    print(f"Title: {title}")
    print(f"FinalPrice: {final_price}")
    print(f"OldPrice: {old_price}\n")

# %%
from PeYa_Headers_Update import headers_update

headers_update(type="SCH")
url = "https://client-api-gateway.pedidosya.com/v1/alchemist-resolver/resolve"
kw = "Pañuelitos"

payload = "{\"data\":{\"businessType\":\"groceries\",\"context\":{\"actionOrigin\":\"search_autocomplete\",\"flowOrigin\":\"products_qc\",\"locationArea\":\"18944\"},\"countryId\":3,\"filters\":[],\"location\":{\"lat\":-34.5528754,\"long\":-58.4653203},\"origin\":\"shop_details\",\"query\":\"Keyword\",\"vendorId\":\"285567\"},\"section\":\"PRODUCT_QC_RESULTS\"}"
payload = payload.replace("\"query\":\"Keyword\"", f"\"query\":\"{kw}\"")
headers = {
  'accept-encoding': 'gzip',
  'authorization': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....RnklvT9oWkvMJHumktTeisnFsjwq_3WpYRplJX_Z3pvloMXF8FZGUzndMrmyiW1Ft3uspQqqgQ62GJ5UnRRn8cgQ1O_ZdGr3en3zIte-1SJkAm1LYyUcOn36SU0ju739-wopzbAyBLPQfEfowu6ZNyKFa-bwjaOQ9rsZFBjIEuRCKy7hDPetkHJsbEYAeBVsu_NEXhiAdA0xHbp8fAZYgFgwBxAzm7LM1YGJG4NhgINZMXiKmuTQWwjP71vMxOpRPq5MVAWMnJunXLDUBLBwi_Eja0RqREdjT4RTRnxzXWQkIoXke64RCyxX3X8MPx2HT2IKNd36k8_y3iXGEHS80Q',
  'baggage': 'sentry-environment=production,sentry-public_key=aa27ec0b39de46e3ad47971be7ad0fba,sentry-release=9.5.6.1,sentry-trace_id=4452627829a54d69a70a2a45dc512589',
  'connection': 'Keep-Alive',
  'content-type': 'application/json; charset=UTF-8',
  'host': 'client-api-gateway.pedidosya.com',
  'origin': 'PedidosYa',
  'peya-app-platform': 'android',
  'peya-app-version': '9.5.6.1',
  'peya-device-id': 'db9283feb4cf6855',
  'peya-global-entity-id': 'PY_ar',
  'peya-os-version': '34',
  'peya-performance-class': 'LOW_END',
  'peya-perseus-client-id': '1725396040934.581078583217633963.h3fngIeUIf',
  'peya-perseus-hitmatch-id': '1739543095506.808606497863691275.eVJNxv7Y3Y',
  'peya-perseus-sdk-version': '3.6.0',
  'peya-perseus-session-id': '1739543081505.171151203148733939.g7CmZTZGfD',
  'peya-screen-dpi': '3',
  'peya-session-id': 'be4061d3-70a0-458c-912d-520f11c509cb',
  'peya-session-timestamp': '1739543081505',
  'peya-trace-id': '25545a2f-963a-40cc-9822-d63a0e50d417',
  'peya-whitelabel-id': 'com.pedidosya',
  'sentry-trace': '4452627829a54d69a70a2a45dc512589-1a409efd66f94639',
  'user-agent': 'google',
  'x-px-authorization': '3:2603e61c637525cda045713f83a9487a2cb390c3733ff315f6904862e48cedb8:VFoBmX5ovaKBd/SlzaYjOgyFLed70LY/7GcoHUc5UwqTx5lAzfD96p0aj8BLYg8pljfo3fjuvLiNFV7up6gV2Q==:1000:Rlp60+2i0HsAoIx18yay7w5PACl+VCYpezcbDRlzR0yRWSrFz+yQzdOLa+ygTiC6GZNPthI4f0qFh2HJftIOewXSBPWGBnXa4d3NRiiXcAzV5s0dyZm4SuNWP36oZitJjdb6mlcpWRHULKD5ZeAUV6rR+KWaJyYNZpiE9a9ut3E+hKEtrbzc6gWiD5h7DxSk7DpuVBwMa9Ij57GIKY8rmoIr7rAgMdAmNwD44ofGJz8=',
  'x-px-device-fp': 'db9283feb4cf6855',
  'x-px-device-model': 'sdk_gphone64_x86_64',
  'x-px-hello': 'VgJQAAMKBAEeVlJQVR4CAlZVHlEFCwEeBwRQVlYAAgcFV1dS',
  'x-px-mobile-sdk-version': '3.3.0',
  'x-px-os': 'Android',
  'x-px-os-version': '14',
  'x-px-uuid': 'e1c30972-eacf-11ef-b682-47cee3146dda',
  'x-px-vid': 'c6d92520-6a34-11ef-8ad2-498b7336ef21',
  'x-trace-id': 'be4061d3-70a0-458c-912d-520f11c509cb',
  'Cookie': '__cf_bm=XC7.BCF5ZRuiytD9T3SswVLGGCABZeAcPubYTeXbyls-1739543278-1.0.1.1-o3fW2Zypu_s7WTmMajLObwE66luwkF.u6GFlUpXnb9xoFIzDJHpNLvmdGKuFuuxtM9NQ1gAV0noEk4VRRBKs4A'
}

response = requests.request("POST", url, headers=headers, data=payload, proxies = {'https': proxy})

data_json = response.json()
print(response.status_code)
# Out:
# ✅ Token actualizado en SCH
# ✅ JSON actualizado y guardado en A:\BeOn_Repositories\headers_peyapp.json
# 🔑 Nuevo Token: eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....FY3NBjpQYesAUBRitdv9cxIeIp_47WAMcFV252bklnY44vQfY2ASzQjj0vnWthHXMFzvUhpN2OM0ckEXdXzmIZH2NlbV3I0QrKRIvAlVEK4In3V5AgQgzpda-Sxtyc8pdY41MOdfsyeQdq1h08s0tJbmU2cwaLw0tydZUvtgp5xr4HgjMP9URf5kJYh1xLwrkpJB5s8U2wAcF3R7zu2tidk1_FJXn-u3xNnsztDo940kzO9hUI9K1CcKvTxCo-J38pWq-hM0zdZQDdtb0jdJ3IQ14C02Noljxz6WIURufo9AT-qBPEaxsJ0uTJW6a2QolBb2GbY0aALtTcOrc247lw
# 400

# %%
products = [
    product_data.get("content", "")  # Obtiene el contenido de cada producto
    for children in data_json.get("children", [])  # Itera sobre los children, todo el contenido
    for product_data in children.get("children") or []  # Evita None asegurándose de que sea una lista
    if product_data.get("content", None) not in [None, "", []]  # Filtra valores vacíos
]

for i in products:
    title = i.get("name", "")
    pricing = i.get("pricing", "")
    final_price = pricing.get("price", "0") if pricing.get("price", "0") != None else "0"
    final_price = just_price(price_str=final_price, dotted_price=True)
    old_price = pricing.get("beforePrice", "0") if pricing.get("beforePrice", "0") != "" else "0"
    old_price = just_price(price_str=old_price, dotted_price=True)
    
    
    
    print(f"Title: {title}")
    print(f"FinalPrice: {final_price}")
    print(f"OldPrice: {old_price}\n")

# %%
# Test Request HTTP
from urllib.parse import quote
import requests

url = "https://client-api-gateway.pedidosya.com/v1/alchemist-resolver/resolve"

# payload = "{\"data\":{\"businessType\":\"groceries\",\"context\":{\"actionOrigin\":\"search_manual\",\"flowOrigin\":\"products_qc\",\"locationArea\":\"18944\"},\"countryId\":3,\"filters\":[],\"location\":{\"lat\":-34.5528754,\"long\":-58.4653203},\"origin\":\"shop_details\",\"query\":\"Pañuelitos\",\"vendorId\":\"285567\"},\"section\":\"PRODUCT_QC_RESULTS\"}"
kw = quote("Pañuelitos")
# payload = payload.replace("\"query\":\"Keyword\"", f"\"query\":\"{kw}\"")


payload = {
    "data": {
        "businessType": "groceries",
        "context": {
            "actionOrigin": "search_manual",
            "flowOrigin": "products_qc",
            "locationArea": "18944"
        },
        "countryId": 3,
        "filters": [],
        "location": {
            "lat": -34.5528754,
            "long": -58.4653203
        },
        "origin": "shop_details",
        "query": kw,
        "vendorId": "285567"
    },
    "section": "PRODUCT_QC_RESULTS"
}


headers = {
    "authorization": "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....GJxYUk03-YUgIALCJ54u1HBE3bXIuTPBIVYN_raPy1TaxewUH4_ylFkdXJO7xdgjDgfVH3RhFedu8pbKp8or9b0_JWrCOdik0rsNsHQIKyVn1iNYTdX1g4AK-vwvr7PHYTlPngoOd_01jIqlniSSZd6FgoUROj2CSxEXFojnB5GFCrybAO6p-KSG_ZkoWTP4PzcMuUPH8s8hC6QW6F_Zm5RHBk2eaycmsPAbqFeoTIjDwVfat4PmJDvHnnGHUhzAnN0_v1vmWr6YS8kk1kKivEV2vrHptYGMz7_q36gjrS8NcOIceMrazrTsjO5-Xffq8aRHN_m-F_CiHj7vgcI23Q",
    "peya-app-version": "9.5.6.1",
    "peya-app-platform": "android",
    "x-trace-id": "a863ae5d-58cc-44cd-9e63-c218d72cd291",
    "peya-session-id": "a863ae5d-58cc-44cd-9e63-c218d72cd291",
    "peya-trace-id": "0748ff90-65a5-4666-b144-d2ae5a6ad66b",
    "peya-whitelabel-id": "com.pedidosya",
    "user-agent": "google",
    "peya-device-id": "db9283feb4cf6855",
    "origin": "PedidosYa",
    "peya-os-version": "34",
    "peya-global-entity-id": "PY_ar",
    "peya-performance-class": "LOW_END",
    "peya-screen-dpi": "3",
    "peya-perseus-session-id": "1739800165447.860549494389444080.acTsQIDp8d",
    "peya-perseus-client-id": "1725396040934.581078583217633963.h3fngIeUIf",
    "peya-perseus-hitmatch-id": "1739800345172.332948378800539860.5oQYQiGGla",
    "peya-perseus-sdk-version": "3.6.0",
    "peya-session-timestamp": "1739800165447",
    "x-px-vid": "c6d92520-6a34-11ef-8ad2-498b7336ef21",
    "x-px-os-version": "14",
    "x-px-uuid": "feb81063-ed35-11ef-b37e-dd994fbf93a2",
    "x-px-device-fp": "db9283feb4cf6855",
    "x-px-device-model": "sdk_gphone64_x86_64",
    "x-px-os": "Android",
    "x-px-hello": "VVZRCwIDBQAeVlcABh4CAlZVHlEABFYeV1cKCgdVUVUKAFIB",
    "x-px-mobile-sdk-version": "3.3.0",
    "x-px-authorization": "3:d3f563b71374c4297919bf5edb42f14150aeefa1701315f7450cd901a2f49533:djF9fnYWwnnlJJq2fI0FX7AjV5xWsos1MSYpnm9jRcpTCli99u0/la/a+mCq9Mvh/RAsCg5fmz+ib++6HjxzoA==:1000:nBOf96EqEn511VNFmWgbCekhDerL0kNZG7dzMZ1cfhnGPLD/E8qJt71/tPtWsS8DHWXM5er99Hgpgz7p/Z2skjqp8S4s+YA7VEGCvLYpTyOm0EvVIL6A+/JRym0wMneKGZAX4TGeN3iwuFdHSditthH086xiTMYTweLCCE79F7iQ4GXXmzxBJUjZT4n8aNX6hIlKWRWwHh3bWgSKd8klmMBAV5EASK47IOsHOqbjaIg=",
    "sentry-trace": "b177d806152947c59b2a2c5a56fc5f13-f6dc0a3d61514044",
    "baggage": "sentry-environment=production,sentry-public_key=aa27ec0b39de46e3ad47971be7ad0fba,sentry-release=9.5.6.1,sentry-trace_id=b177d806152947c59b2a2c5a56fc5f13",
    "content-type": "application/json; charset=UTF-8",
    "host": "client-api-gateway.pedidosya.com",
    "connection": "Keep-Alive",
    "accept-encoding": "gzip"
}

response = requests.post(url, json=payload, headers=headers, proxies = {'https': proxy})

print(response.text)
print(response.request.body)
print(response.request.headers)
print(response.status_code)
print(payload)
# Out:
# {"children":[{"children":[],"componentType":"fenixLabel","content":{"contentStyle":{"padding":{"bottom":8,"left":16,"right":16,"top":8}},"text":"Resultados para \"Pa%C3%B1uelitos\"","textAlignment":"left","typographyColorToken":"textColorPrimary","typographyToken":"textTitleMedium"},"id":"productSearchQcHighResults"},{"children":[{"actions":[{"componentActionId":"card","id":"navigate","properties":{"targetUrl":"pedidosya://pharma/productConfiguration?productSku=112129895\u0026vendorId=285567\u0026trackingData=eyJjb21tb24iOnsic2VhcmNoUmVxdWVzdElkIjoiUGJMWlRtSzlFNmVucm8wUEh2SER0S3lMM0FtdWJPMVAiLCJhY3Rpb24iOiJzZWFyY2hfbWFudWFsIiwicHJvZHVjdFNlYXJjaGVkIjoiUGElQzMlQjF1ZWxpdG9zIiwicHJvZHVjdEluZGV4IjoiMSJ9LCJhZGRUb0NhcnQiOnt9fQ==\u0026origin=search_results"},"trigger":"clicked"}],"children":[],"componentType":"fenixQCProductCardVertical","content":{"disabled":false,"image":"https://pedidosya.dhmedia.io/image/product-information-management/670d3651ce0c7887c86459b2.jpg?width=130\u0026height=13
# ...
