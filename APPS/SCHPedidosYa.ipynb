# %%
# Importacion de librerias necesarias
import requests
import re
from bs4 import BeautifulSoup

# Proxy y datos como header para la coneccion
username = 'Ec0m37ry'
password = 'fK7Ulvdm8zSVnyn22+'
proxy = f"https://{username}:{password}@ar.smartproxy.com:10000"

url = "https://web-apps.pedidosya.com/qc-gateway/qc-search-results-service/v1/search/vendors/285567/products?offset=0&page=0&limit=50&search=toallitas humedas&origin=SectionDetails&businessType=GROCERIES"
payload = {}
headers = {
    "host": "web-apps.pedidosya.com",
    "connection": "keep-alive",
    "pragma": "no-cache",
    "cache-control": "no-cache",
    "peya-perseus-client-id": "1725396040934.581078583217633963.h3fngIeUIf",
    "peya-whitelabel-id": "com.pedidosya",
    "peya-global-entity-id": "PY_ar",
    "peya-perseus-session-id": "1727199337410.416231446987186729.faHfQRYGtz",
    "peya-session-timestamp": "1727199337410",
    "peya-device-id": "db9283feb4cf6855",
    "peya-session-id": "792c17ae-8655-4477-9ced-da790ea85145",
    "peya-os-version": "34",
    "user-agent": "Mozilla/5.0 (Linux; Android 14; sdk_gphone64_x86_64 Build/UE1A.230829.036.A1; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/113.0.5672.136 Mobile Safari/537.36",
    "peya-trace-id": "7b064403-6c33-4d28-9067-e2757256ec82",
    "peya-microsite-token-type": "APP",
    "peya-context-country": "ar",
    "peya-perseus-hitmatch-id": "1727199535025.980847642279059184.Ey1yvKFcAP",
    "baggage": "sentry-environment=live,sentry-release=web-app-groceries-section-detail%406.78.0,sentry-public_key=bf9c82696a97a4f49831de445729d6c4,sentry-trace_id=a27d964b91cc4822bb9471ddeee5b80d,sentry-sample_rate=0.01,sentry-sampled=false",
    "peya-app-platform": "android",
    "peya-app-version": "8.28.7.2",
    "sentry-trace": "a27d964b91cc4822bb9471ddeee5b80d-9362123db0714916-0",
    "accept": "*/*",
    "x-requested-with": "com.pedidosya",
    "sec-fetch-site": "same-origin",
    "sec-fetch-mode": "cors",
    "sec-fetch-dest": "empty",
    "referer": "https://web-apps.pedidosya.com/groceries-section-detail/?c=.ar&lat=-34.5528754&lng=-58.4653203&age_validated=false&cart_id=C1B1a4e80be14dd090994506a95bb00800d4dc5c30b94168a32c362e01f649d1&partner_id=285567&origin=shop_details&overrideBack=true&show_navbar=true&show_searchbar=true&search_type=search_sx_open",
    "accept-encoding": "gzip, deflate",
    "accept-language": "es-AR,es;q=0.9,en-US;q=0.8,en;q=0.7",
    "cookie": "__cf_bm=6w_so2aiJbwEGPzJKvtKOsqPUAwnwXUMfWqNXeen2FQ-1727199421-1.0.1.1-BiDzxPe5_vCalsReMvCUJb_EtnULqpA6QffR9zJqMW6GRxK5BHHqlMlPMMB4GvfTjAvdjN5xbKhZrNtmbOxxzg; peya.webview=...; peya.webview.sig=LRVOEOwYpAin4NhOgeh7_jWgYmE"
}

# Consulta y extraccion de data
response = requests.request("GET", url, data=payload, headers=headers, proxies = {'https': proxy})
print(response.status_code)
data_json = response.json()
data_product = data_json.get('results', '')

# Parseo de la data
for product in data_product:
    title = product.get('name', '')
    brand = product.get('defaultBrandName', '')
    price = product.get('pricing', '')
    final_price = price.get('price', '')
    old_price = price.get('beforePrice', '')
    old_price = 0 if old_price == '' else old_price
    image = product.get('image', '')

    print(f"Title: {title}")
    print(f"Brand: {brand}")
    print(f"FinalPrice: {final_price}")
    print(f"OldPrice: {old_price}")
    print(f"Image: {image}\n")
# Out:
# 200
# Title: Toallas Húmedas Huggies Limpieza Cotidiana 48 Unidades
# Brand: Huggies
# FinalPrice: $ 3.482
# OldPrice: 0
# Image: https://images.deliveryhero.io/image/pedidosya/products/6c301ee4-6b57-4968-811a-720d2660a6c9.jpg?width=130&height=130
#
# Title: Toallas Húmedas Estrella Cuidado Relajante Baby X 50 Uni.
# Brand: Estrella
# FinalPrice: $ 3.648
# OldPrice: 0
# Image: https://images.deliveryhero.io/image/pedidosya/products/646fa4d05bf260d7ff543612.jpg?width=130&height=130
#
# Title: Toallas Húmedas Estrella Humectación Sensitive Baby X 50 Uni.
# Brand: Estrella
# FinalPrice: $ 3.933
# OldPrice: 0
# Image: https://images.deliveryhero.io/image/pedidosya/products/646fa4d15bf260d7ff543613.jpg?width=130&height=130
#
# Title: Toallas Húmedas Estrella Cuidado Diario Con Tapa 50 Uni.
# Brand: Estrella
# FinalPrice: $ 3.488
# OldPrice: 0
# Image: https://images.deliveryhero.io/image/pedidosya/products/646fa4cf5bf260d7ff543611.jpg?width=130&height=130
#
# ...

# %%
for i in data_product:
    print(f"{i}\n")
# Out:
# {'categoryId': '145f422b-163c-4708-a8c8-ec134224aef2', 'defaultBrandName': 'Huggies', 'id': '66751369', 'image': 'https://images.deliveryhero.io/image/pedidosya/products/6c301ee4-6b57-4968-811a-720d2660a6c9.jpg?width=130&height=130', 'isPremiumPlacement': False, 'isWeighable': False, 'max_quantity': 10, 'name': 'Toallas Húmedas Huggies Limpieza Cotidiana 48 Unidades', 'precision': 'HIGH', 'pricing': {'beforePrice': '', 'discount': '', 'price': '$ 3.482', 'pricePerMeasurementUnit': '$ 72,54/un', 'unformattedPrice': 3482, 'unit': ''}, 'productDetailUrl': 'pedidosya://pharma/productConfiguration?productSku=66751369&vendorId=285567', 'restrictions': [], 'size': '48un', 'tags': []}
#
# ...
