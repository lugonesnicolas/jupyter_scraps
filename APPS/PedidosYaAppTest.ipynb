# %%
import requests

url = "https://client-api-gateway.pedidosya.com/v1/pharma/vendor/164044/product/112126841/details"

querystring = {
    # "cartId": "C1B0a9ed27a449a7b783261a0fe55c3ec9328182adae48989c534ac5b7a39c15",
    # "hasValidatedAge": "false",
    "queryParams": "productSku=112126841&vendorId=164044&cartId=C1B0a9ed27a449a7b783261a0fe55c3ec9328182adae48989c534ac5b7a39c15"
}

# headers = {
#     "authorization": "eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....tMaVbCcS-Kbj25H8vqNTrB_oEw3_cikcpN5oyqGTpxR0QX93oRrB49t2vi1GUbUeYcDMvf6eAugc-Kd0_wgRbqXwGW3mEF1FIXSllgUnAFv4OtVC_cfVEhA-fEDVGVzKXqEmULi0Nd6EpXX6qzHOmblkwlhQ2IX159L9IlqjrizzKpT-jgwKcffoWVw3Zg1Oq7qTASqTe5H0S0EuzqzqUWFoeb_BB-joxWmJZQF8tnu6Bdiw4xlqnuZYTso4knRZBBjR9osCHZcSmMCz2eG8pzpe63L4Ajda_ENchFxPoaPKRPSWMpWeNraptzZ5EQfIA4elHKIGqyTx2iaxs_H4XA",
#     "content-type": "application/json; charset=utf-8",
#     "peya-app-version": "8.28.7.2",
#     "peya-app-platform": "android",
#     "x-trace-id": "4306fbbf-baf0-4785-b5f6-d1d18570c900",
#     "peya-session-id": "4306fbbf-baf0-4785-b5f6-d1d18570c900",
#     "peya-trace-id": "8070df36-a143-49a9-a653-de3f62f3e171",
#     "peya-whitelabel-id": "com.pedidosya",
#     "user-agent": "google",
#     "peya-device-id": "db9283feb4cf6855",
#     "origin": "PedidosYa",
#     "peya-os-version": "34",
#     "peya-global-entity-id": "PY_ar",
#     "peya-performance-class": "LOW_END",
#     "peya-perseus-session-id": "1726150586897.133210651191788304.euvMRofWuB",
#     "peya-perseus-client-id": "1725396040934.581078583217633963.h3fngIeUIf",
#     "peya-perseus-hitmatch-id": "1726150897222.436494922789675398.2IFvrs5VVe",
#     "peya-perseus-sdk-version": "2.3.6",
#     "peya-session-timestamp": "1726150586897",
#     "x-px-vid": "c6d92520-6a34-11ef-8ad2-498b7336ef21",
#     "x-px-os-version": "14",
#     "x-px-uuid": "986baa5b-7111-11ef-ba6b-d5a63f0ddcf8",
#     "x-px-device-fp": "db9283feb4cf6855",
#     "x-px-device-model": "sdk_gphone64_x86_64",
#     "x-px-os": "Android",
#     "x-px-hello": "CgsFUVJSBlEeBAICAh4CAlZVHlFSBVEeVwZSBQBVA1dXUFUL",
#     "x-px-mobile-sdk-version": "3.3.0",
#     "x-px-authorization": "3:7e83092adf1e1c0394b46ac1183dbcb0f431ab81962a262273115f2f5747efd9:2yXjbVgKzv+EdH5zbjc3zN5gw63Hl5EmEnJknz8lJRK8Wuc684+Ftj/YVfu8XF2Ow8irtDLr3Py9SKTUo5GCZQ==:1000:/3/00KxuyBcY9PzPiG7uYSdjMdb0or3MnGJWmbzixV22XLgZn0RIHTjyDebiVQKtDVJgoIzE79/oq6NlYYSjmsscQ5qyv2dQKoKqp9aDpxqEm0uQ7KZjP2guVMkAakGk7HvZtBAt9j5Cz7/42KrY2sclwj5kEyzdnn0ukN6bwnfE0L13v60XJz43uIgINpUj3F/hk6UWfogIWM+/plCkZKFmulC4ephXStUUCx5HY4s=",
#     "sentry-trace": "cc7744db67ff46f2aafa154846a21d67-8ff31295f4f7451f",
#     "baggage": "sentry-environment=production,sentry-public_key=aa27ec0b39de46e3ad47971be7ad0fba,sentry-release=8.28.7.2,sentry-trace_id=cc7744db67ff46f2aafa154846a21d67",
#     "host": "client-api-gateway.pedidosya.com",
#     "connection": "Keep-Alive",
#     "accept-encoding": "gzip"
# }

headers = {
  'accept-encoding': 'gzip',
  'authorization': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....tHJzphjgad3yMO6QqWr-TSBXCMj0l7GRO-wn_AM-jObJPfbH7eUmEDzOLD40nK0YNwdplSyh7lpQAYljCAJnGpe9fMfQNj1JAzcz7R5OvKrD9aRxJJXOPl5XpeBfSvqi6UaiWh200kem-a6QqJVVnTQIxc-nobpNBmJ-Bpnm258zDpaP6_KKS9CexD8_CJ1Un7lUYsk32aGioXYAEZ1AIXH1f_xGBTnsfbyjkEuxsPECDRArFoDASV1PGlwGdo-lY9KrfW7wDtlXX1iUaau7-ecQf8kHIAzcwelNfPI0leGFOvJ66WdhhBHOQKXTAzjd9NKc3wWTfZZ05xU589hRxA',
  'connection': 'Keep-Alive',
  'content-type': 'application/json; charset=utf-8',
  'host': 'client-api-gateway.pedidosya.com',
  'origin': 'PedidosYa',
  'peya-app-platform': 'android',
  'peya-app-version': '8.28.7.2',
  'peya-device-id': 'db9283feb4cf6855',
  'peya-global-entity-id': 'PY_ar',
  'peya-os-version': '34',
  'peya-performance-class': 'LOW_END',
  'peya-perseus-client-id': '1725396040934.581078583217633963.h3fngIeUIf',
  'peya-perseus-hitmatch-id': '1726086272558.402868367447326218.C1EIKprHWY',
  'peya-perseus-sdk-version': '2.3.6',
  'peya-perseus-session-id': '1726085958799.504982374571057203.XyKEdjwwro',
  'peya-session-id': '79c540e3-f6f5-4828-8e89-45465f2cdeb4',
  'peya-session-timestamp': '1726085958799',
  'peya-trace-id': '9d8eb831-8ec5-42a6-b1d6-d9924e74a6ea',
  'peya-whitelabel-id': 'com.pedidosya',
  'sentry-trace': '6b9c755764be41f68db52032ac47a54e-c8dae5e2a486408d',
  'user-agent': 'google',
  'x-px-device-fp': 'db9283feb4cf6855',
  'x-px-device-model': 'sdk_gphone64_x86_64',
  'x-px-hello': 'BwVQCwIBBgQeBAMEUR4CAlZVHgsAA1IeCwAKUQsGBQJXVVIC',
  'x-px-mobile-sdk-version': '3.3.0',
  'x-px-os': 'Android',
  'x-px-os-version': '14',
}

response = requests.get(url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"children":[{"actions":[],"children":[{"actions":[],"children":[],"componentType":"px_pd_image_slider","content":{"contentStyle":null,"images":["https://images.deliveryhero.io/image/product-information-management/63f678b2e1c00436a7012389.jpg?webp=1\u0026quality=90\u0026width=570"],"thumbnailPadding":12,"title":"Galletitas Oreo Rellenas Con Crema Sabor Original 118 g"},"events":null,"id":"photo","tracking":[{"componentActionId":null,"id":"multi_image.loaded","properties":{"productSku":"112126841","quantity":"1","screenName":"ProductConfiguration","shopId":"164044"},"trigger":"loaded"},{"componentActionId":null,"id":"image.clicked","properties":{"productHasPhoto":"main_image","productSku":"112126841","screenName":"ProductConfiguration","screenType":"shop_details","shopId":"164044"},"trigger":"clicked"}]},{"actions":[],"children":[],"componentType":"fenixLabel","content":{"contentStyle":{"dividers":null,"padding":{"bottom":0,"left":16,"right":16,"top":16}},"maxLines":null,"text":"Galle
# ...
