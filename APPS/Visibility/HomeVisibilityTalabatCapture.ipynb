# %%
import requests
import datetime
import time
import glob
import os

# %%
path = f"A:\\BeOn_Repositories\\imagenes_talabat\\visibility_home_talabat"
app_name = "Talabat App UAE"
app_section = 'H'

# %% [markdown]
# # Primer Home de la App

# %%
url = "https://api.talabat.com/home/v1/ae/content?lat=25.187459393372798&lon=55.40563557296991&area_id=1241"

payload = {}
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'external_experiments': 'show_voucher_code_entry,talabatProPlanId=94a02bf2-4317-4541-a5cc-a3dfd20381a4',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6IjBmNDI0ZTIwNDIwYTQ0ZmY5MzJlY2U3ZjNhZGRjZDU1IiwiaWQiOiJjMmFkZmViZTU2YzQ0Nzc0IiwidGkiOjE3MTQ2NzA1Nzc4NzUsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-0f424e20420a44ff932ece7f3addcd55-c2adfebe56c44774-00',
  'tracestate': '346080@nr=0-2-938958-414461638-c2adfebe56c44774----1714670577875',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-device-width': '393',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1714670249759.836055986224561927.qr9wdRxaxf',
  'Cookie': '__cf_bm=Wg4BmOOCN9n6cLdluK9oHEx0eUFCc.DhfOS5G_5gyGI-1714671471-1.0.1.1-OkaBbN4svE2erNEmslaHLuD952nPYw1TrI8w7htoxqT2wI9yNHoCCR_aRPmPcllV3D8vGe_qDCrCsBx8E7edTMkfPY.RuzflQeeZLrbBm_g; AWSALB=QK8ipDPt2jcp174vV2rChVQzm97LbCDHeKXfrLyX0uYjb6sRKvAngozykRGc8vqrdx4hJiDVHUA9rcFXSyWs2uzea7NGj6Q6KvSi4NBNYwrNDjv9TdGVJ3qiaWBA; AWSALBCORS=QK8ipDPt2jcp174vV2rChVQzm97LbCDHeKXfrLyX0uYjb6sRKvAngozykRGc8vqrdx4hJiDVHUA9rcFXSyWs2uzea7NGj6Q6KvSi4NBNYwrNDjv9TdGVJ3qiaWBA'
}

response = requests.request("GET", url, headers=headers, data=payload)
data = response.json()

# %%
banner1 = data['data']['components'][3]['items'][0]['properties'].get('image', '')
banner2 = data['data']['components'][3]['items'][1]['properties'].get('image', '')
banner3 = data['data']['components'][3]['items'][2]['properties'].get('image', '')
print(f"Banner1:{banner1}")
print(f"Banner2:{banner2}")
print(f"Banner3:{banner3}")
# Out:
# Banner1:https://images.deliveryhero.io/image/talabat/Banners/Hardees_Banner_rot_e_6385638512736070034935.jpg
# Banner2:https://images.deliveryhero.io/image/talabat/Banners/pizza_hut__Melts_Si_63851638512740209487020.jpg
# Banner3:https://images.deliveryhero.io/image/talabat/Banners/EPIK_FOODS__RB_VEND_63851638517896228925365.jpg

# %% [markdown]
# # Home de Talabat Mart 1

# %%
import requests

url = "https://api.talabat.com/grocery/v3/ae/pages/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/home?isDarkstore=true&areaId=1464&pageNumber=0"

payload = {}
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6IjAyYmI3NjFjNjdhZDQ1ZGY4NWFjOTc5YjhjOTA1ZGZhIiwiaWQiOiIxMmNiMGExZGI3MTQ0NGY1IiwidGkiOjE3MTQ2NzQzNTQzODQsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-02bb761c67ad45df85ac979b8c905dfa-12cb0a1db71444f5-00',
  'tracestate': '346080@nr=0-2-938958-414461638-12cb0a1db71444f5----1714674354383',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-customer-id': '0',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1714673516283.720101786062417709.xyWpIRmT4H',
  'Cookie': '__cf_bm=aDBkfPrXBQogxgIksUaLMOhMGArU8u0AjQfgARHFG0A-1714674512-1.0.1.1-vs90FnKv3Dq6pzUdJpJfJLO1Ve3rnTOUVnxez6OOreTA4KX3FHGoaEWui79Y_MJKKm8TOCWNEVZ0WgmKEzCtEsluwEHR2vLPB8nyEaX167A; AWSALB=0QdpimnMBhFA2LB5Zt85GCZWSI34elaXJ9Vqy8SEswRAZeAKS0G1gD4yMlPAEA1m2blELg8xill8kNh+OfYkuFcedPXI4apLnR/ye0/g9A4K8tv3hl5rKUdXROU9; AWSALBCORS=0QdpimnMBhFA2LB5Zt85GCZWSI34elaXJ9Vqy8SEswRAZeAKS0G1gD4yMlPAEA1m2blELg8xill8kNh+OfYkuFcedPXI4apLnR/ye0/g9A4K8tv3hl5rKUdXROU9'
}

response2 = requests.request("GET", url, headers=headers, data=payload)

data2 = response2.json()
data2 = data2.get('components', '')

# %%
# for i in data2:
#     print(f"{i}\n")

# %%
# for i in range(0,len(data2)):
#     type = ''
#     banner = data2[i].get('image_url', '')

#     title = data2[i].get('title', '')
#     type = data2[i].get('type', '')
#     location = ''
#     items = data2[i].get('items', '')
#     images_url = [j.get('image_url', '') for j in items]

#     if i == 0:
#         location = 'H'
#     else:
#         location = 'M'
    
#     if "product_swimlanes" in type:
#         type = 'F'
#     else:
#         type = 'O'

#     print(f"{location}-{type}")

#     try:
#         if banner != '':
#             time.sleep(1)
#             fecha_hora_actual = datetime.datetime.now()
#             fecha_actual = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
#             file_name = f"A:\\BeOn_Repositories\\visibility_talabat_test\\{fecha_actual}_H{location}B.jpg"
#             response_image = requests.request("GET", banner, data=payload)
#             with open(file_name, "wb") as f:
#                     f.write(response_image.content)
#                     print(f"Imagen descargada, Url:{banner}")
#     except Exception as e:
#         print(f"No se pudo descargar el banner - {e}")


#     for i in images_url:
#         if i != '':
#             try:
#                 time.sleep(1)
#                 fecha_hora_actual = datetime.datetime.now()
#                 fecha_actual = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
#                 file_name = f"A:\\BeOn_Repositories\\visibility_talabat_test\\{fecha_actual}_H{location}{type}.jpg"
#                 response_image = requests.request("GET", i, data=payload)
#                 with open(file_name, "wb") as f:
#                         f.write(response_image.content)
#                         print(f"Imagen descargada, Url:{i}")
#             except Exception as e:
#                 print(f"No se pudo descargar la imagen - {e}")
#         else:
#             products = [j.get('products', '') for j in items]
#             for product in products:
#                 print(f"Entre en el carrusel de productos")
#                 image_url = product.get('image_url', '')
#                 try:
#                     time.sleep(1)
#                     fecha_hora_actual = datetime.datetime.now()
#                     fecha_actual = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
#                     file_name = f"A:\\BeOn_Repositories\\visibility_talabat_test\\{fecha_actual}_H{location}F.jpg"
#                     response_image = requests.request("GET", image_url, data=payload)
#                     with open(file_name, "wb") as f:
#                             f.write(response_image.content)
#                             print(f"Imagen descargada, Url:{image_url}")
#                 except Exception as e:
#                     print(f"No se pudo descargar la imagen - {e}")

# %%
for i in range(0,len(data2)):
    type = ''
    banner = data2[i].get('image_url', '')

    title = data2[i].get('title', '')
    type = data2[i].get('type', '')
    location = ''
    items = data2[i].get('items', '')

    if i == 0:
        location = 'H'
    else:
        location = 'M'
    
    if "product_swimlanes" in type:
        type = 'F'
    else:
        type = 'B'

    print(f"{location}-{type}")

    try:
        if banner != '':
            time.sleep(1)
            fecha_hora_actual = datetime.datetime.now()
            fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
            file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - H{location}{type}.jpg"
            response_image = requests.request("GET", banner, data=payload)
            with open(file_name, "wb") as f:
                    f.write(response_image.content)
                    print(f"Imagen descargada, Url:{banner}")
    except Exception as e:
        print(f"No se pudo descargar el banner - {e}")


    for i in items:
        image_url = i.get('image_url', '')
        if image_url != '':
            try:
                time.sleep(1)
                fecha_hora_actual = datetime.datetime.now()
                fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
                file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - H{location}{type}.jpg"
                response_image = requests.request("GET", image_url, data=payload)
                with open(file_name, "wb") as f:
                        f.write(response_image.content)
                        print(f"Imagen descargada, Url:{image_url}")
            except Exception as e:
                print(f"No se pudo descargar la imagen - {e}")
        else:
            products = i.get('products', '')
            count = 0
            for product in products:
                if count < 3:
                    print(f"Entre en el carrusel de productos")
                    product_image_url = product.get('image_url', '')
                    try:
                        time.sleep(1)
                        fecha_hora_actual = datetime.datetime.now()
                        fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
                        file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - H{location}F.jpg"
                        response_image = requests.request("GET", product_image_url, data=payload)
                        with open(file_name, "wb") as f:
                                f.write(response_image.content)
                                print(f"Imagen descargada, Url:{product_image_url}")
                    except Exception as e:
                        print(f"No se pudo descargar la imagen - {e}")
# Out:
# H-B
# Imagen descargada, Url:https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/Top%20Savers%20B2233ss2S.png
# Imagen descargada, Url:https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/Piiz.png
# Imagen descargada, Url:https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/ravvbfg.png
# Imagen descargada, Url:https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/Lpittio.png
# Imagen descargada, Url:https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/szax%20(231).png
# Imagen descargada, Url:https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/UAE_5000328250762-removebg-previewwwww%20(1).png
# M-B
# ...

# %% [markdown]
# # Home de Talabat Mart 2

# %%
url = "https://api.talabat.com/grocery/v3/ae/pages/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/home?isDarkstore=true&areaId=1464&pageNumber=1"

payload = {}
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6ImI5OGJkOTc2YmE2NTQyNTY4NDhmYzViYWQ5NTQyZDZmIiwiaWQiOiI3ZGNlZjgwMzM3N2I0MzNmIiwidGkiOjE3MTUwMDA5NDc4MTcsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-b98bd976ba654256848fc5bad9542d6f-7dcef803377b433f-00',
  'tracestate': '346080@nr=0-2-938958-414461638-7dcef803377b433f----1715000947817',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-customer-id': '0',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1715000126641.421165773691747638.y4FwjN6f47',
  'x-weightables-enabled': 'true',
  'Cookie': '__cf_bm=r__jicu58hYlSv51b7Qg1kCtIuGwTsbCfX_bNGFjGEw-1715001064-1.0.1.1-KRxSLPJ3zT53Ts_sa0e4AvYu3_dnLz8qftFX8JUk5F3v.G2RDZjZxFCYLP_ybnMXnhXd4Sd23aMeoff2W3X5ligtJRhkLAAwcYoU2t61vxY; AWSALB=cxeGYtlyjgMTqwdY1XdxBPbRCSrBv24ATVIyOq7LTIcYNQiyIAP3ifBwd2gwQLRTUXZ4BTjRXOPI4EEgORUKgpWjF0bE8i6CCrnbhNO7fSL9X92CbPd9GDJfhKHT; AWSALBCORS=cxeGYtlyjgMTqwdY1XdxBPbRCSrBv24ATVIyOq7LTIcYNQiyIAP3ifBwd2gwQLRTUXZ4BTjRXOPI4EEgORUKgpWjF0bE8i6CCrnbhNO7fSL9X92CbPd9GDJfhKHT'
}

response = requests.request("GET", url, headers=headers, data=payload)
data3 = response.json()
data3 = data3.get('components', '')

# %%
for i in range(0,len(data3)):
    type = ''
    title = data3[i].get('title', '')
    type = data3[i].get('type', '')
    banner = data3[i].get('image_url', '')
    location = ''
    items = data3[i].get('items', '')


    if i == len(data3) - 1:
        location = 'F'
    else:
        location = 'M'
    
    if "product_swimlanes" in type:
        type = 'F'
    else:
        type = 'B'

    print(f"{location}-{type}")

    try:
        if banner != '':
            time.sleep(1)
            fecha_hora_actual = datetime.datetime.now()
            fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
            file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - H{location}{type}.jpg"
            response_image = requests.request("GET", banner, data=payload)
            with open(file_name, "wb") as f:
                    f.write(response_image.content)
                    print(f"Imagen descargada, Url:{banner}")
    except Exception as e:
        print(f"No se pudo descargar el banner - {e}")


    for i in items:
        image_url = i.get('image_url', '')
        if image_url != '':
            try:
                time.sleep(1)
                fecha_hora_actual = datetime.datetime.now()
                fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
                file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - H{location}{type}.jpg"
                response_image = requests.request("GET", image_url, data=payload)
                with open(file_name, "wb") as f:
                        f.write(response_image.content)
                        print(f"Imagen descargada, Url:{image_url}")
            except Exception as e:
                print(f"No se pudo descargar la imagen - {e}")
        else:
            products = i.get('products', '')
            count = 0
            for product in products:
                if count < 3:
                    print(f"Entre en el carrusel de productos")
                    product_image_url = product.get('image_url', '')
                    try:
                        time.sleep(1)
                        fecha_hora_actual = datetime.datetime.now()
                        fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
                        file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - H{location}F.jpg"
                        response_image = requests.request("GET", product_image_url, data=payload)
                        with open(file_name, "wb") as f:
                                f.write(response_image.content)
                                print(f"Imagen descargada, Url:{product_image_url}")
                    except Exception as e:
                        print(f"No se pudo descargar la imagen - {e}")
# Out:
# M-F
# Imagen descargada, Url:https://images.deliveryhero.io/image/talabat-nv/Hero_Images/Final/8001090125620.png
# Imagen descargada, Url:https://images.deliveryhero.io/image/darkstores/groceries-catalog/products-uae/UAE_8001090151780.jpg
# Imagen descargada, Url:https://images.deliveryhero.io/image/talabat-nv/P_G/8001090662231.jpg
# Imagen descargada, Url:https://images.deliveryhero.io/image/talabat-nv/Regional_Images_2024/Hero_Images/8001090662293.png
# Imagen descargada, Url:https://images.deliveryhero.io/image/talabat-nv/Hero_Images/Final/4084500190665.png
# Imagen descargada, Url:https://images.deliveryhero.io/image/talabat-nv/P_G/7702018085514.jpg
# Imagen descargada, Url:https://images.deliveryhero.io/image/talabat-nv/P_G/7702018606597.jpg
# Imagen descargada, Url:https://images.deliveryhero.io/image/talabat-nv/Regional_Images/Images/Hero_Images/New_Hero_Images/5011321361058.png
# ...

# %%
imagenes = glob.glob(os.path.join(path, "*.jpg"))# Obtengo una lista de imagenes que tengas la extencion jpg
for i in range(0, len(imagenes)):# Recorro la lista y remplazo el nombre de la ruta
    if i < len(imagenes) / 2:
        new_path = imagenes[i].replace("Talabat App UAE", "AE - Talabat App UAE")
        os.rename(imagenes[i], new_path)
    else:
        new_path = imagenes[i].replace("Talabat App UAE", "AF - Talabat App UAE")
        os.rename(imagenes[i], new_path)
    print(f"RutaOriginal: {imagenes[i]}")
    print(f"RutaNueva: {new_path}\n")
# Out:
# RutaOriginal: A:\BeOn_Repositories\imagenes_talabat\visibility_home_talabat\2024_05_23_10_00_22_Talabat App UAE - HHB.jpg
# RutaNueva: A:\BeOn_Repositories\imagenes_talabat\visibility_home_talabat\2024_05_23_10_00_22_AD_Talabat App UAE - HHB.jpg
#
# RutaOriginal: A:\BeOn_Repositories\imagenes_talabat\visibility_home_talabat\2024_05_23_10_00_23_Talabat App UAE - HHB.jpg
# RutaNueva: A:\BeOn_Repositories\imagenes_talabat\visibility_home_talabat\2024_05_23_10_00_23_AD_Talabat App UAE - HHB.jpg
#
# RutaOriginal: A:\BeOn_Repositories\imagenes_talabat\visibility_home_talabat\2024_05_23_10_00_24_Talabat App UAE - HHB.jpg
# RutaNueva: A:\BeOn_Repositories\imagenes_talabat\visibility_home_talabat\2024_05_23_10_00_24_AD_Talabat App UAE - HHB.jpg
#
# RutaOriginal: A:\BeOn_Repositories\imagenes_talabat\visibility_home_talabat\2024_05_23_10_00_25_Talabat App UAE - HHB.jpg
# RutaNueva: A:\BeOn_Repositories\imagenes_talabat\visibility_home_talabat\2024_05_23_10_00_25_AD_Talabat App UAE - HHB.jpg
#
# ...
