# %%
import requests
import json
import time
import datetime

# %%
username = '978ViS1biLtY876'
password = 'MZv_BTy9eh7bko6y7n'
proxy = f"http://{username}:{password}@gate.smartproxy.com:7000"

# %%
path = f"A:\\BeOn_Repositories\\imagenes_noon\\visibility_group_noon"
app_name = "Noon APP UAE"

# %%
url = "https://api-app-instant.noon.com/_svc/catalog/search"

payload = json.dumps({
  "q": None,
  "sort": None,
  "f": {
    "category": [
      "food",
      "baby"
    ]
  },
  "pillType": None,
  "showReorder": 0,
  "subcategory": 0,
  "page": 1,
  "rows": 60,
  "reorderItems": 0
})
headers = {
  'accept': 'application/json, text/plain, */*',
  'accept-encoding': 'gzip',
  'cache-control': 'no-cache',
  'connection': 'Keep-Alive',
  'content-type': 'application/json',
  'host': 'api-app-instant.noon.com',
  'user-agent': 'okhttp/4.9.2',
  'x-abx': 'ipl_entrypoint_v2=1,ipl_v2=1,noon_pass=1,otp_login=1,tip_amount_minutes_ae=1',
  'x-aby': '{"ipl_entrypoint_v2.enabled":1,"ipl_v2.enabled":1,"noon_pass.enabled":1,"otp_login.enabled":1,"tip_amount_minutes_ae.enabled":1}',
  'x-border-enabled': 'true',
  'x-build': '3568',
  'x-content': 'mobile',
  'x-device-id': 'd18aab29fd9bbc3e',
  'x-ecom-zonecode': 'AE_DXB-S5',
  'x-experience': 'nooninstant',
  'x-food-zonecode': 'FOOD-AE-DXB-HUB2-BUSINESS_BAY',
  'x-lat': '251244888',
  'x-lng': '554037568',
  'x-locale': 'en-ae',
  'x-mp': 'nooninstant',
  'x-nooninstant-zonecode': 'W00000146A',
  'x-noonnownow-zonecode': 'NOWNOW-AE-DXB-HUB6-DOWNTOWN_DUBAI',
  'x-platform': 'android',
  'x-rocket-enabled': 'true',
  'x-rocket-mp-zonecode': 'W00067526A',
  'x-rocket-zonecode': 'W00067526A',
  'x-visitor-id': '8ecdb855-a8a9-4636-968b-742fddeb6056'
}

response = requests.request("POST", url, headers=headers, data=payload, proxies = {'https': proxy})
data = response.json()
data_results = data.get('results', '')

# %%
print(data)
# Out:
# {'nbHits': 126, 'nbPages': 3, 'search': {'q': None, 'sort': None, 'f': {'category': ['food', 'baby']}, 'pillType': None, 'showReorder': 0, 'subcategory': 0, 'page': 1, 'rows': 60, 'minCount': None, 'reorderItems': 0, 'recommendedProducts': 0}, 'type': 'catalog', 'facets': [{'code': 'category', 'name': 'Category', 'type': 'category', 'data': [{'name': 'Baby', 'code': 'baby', 'count': 482, 'children': [{'name': 'Accessories', 'code': 'baby_accessories', 'count': 87, 'children': [], 'isSelected': False}, {'name': 'Baby Care', 'code': 'baby_care', 'count': 77, 'children': [], 'isSelected': False}, {'name': 'Diapers', 'code': 'diapers', 'count': 84, 'children': [], 'isSelected': False}, {'name': 'Food', 'code': 'food', 'count': 126, 'children': [], 'isSelected': True}, {'name': 'Formula & Feeding', 'code': 'formula', 'count': 59, 'children': [], 'isSelected': False}, {'name': 'Health & Safety', 'code': 'baby_health_and_saftey', 'count': 13, 'children': [], 'isSelected': False}, {'name': '
# ...

# %%
pills = data.get('navPills', '')
for pill in pills:
    icon_image = pill.get('imageKey', '')
    if icon_image != None and icon_image != '':
        print(f"IconImage: {icon_image}")
# print(f"{f}")
# Out:
# IconImage: https://storage.googleapis.com/noonprd-mp-gcs-instant-cms/instant/categories-144x144/baby.1651306406.8651974.png
# IconImage: https://z.nooncdn.com/rn/instant/misc/fire-new-in%20copy.png
# IconImage: https://z.nooncdn.com/rn/instant/category-icons/diapers.png
# IconImage: https://storage.googleapis.com/noonprd-mp-gcs-instant-cms/instant/categories-651x651/Nav pill – 64.1678282519.1907177.png
# IconImage: https://storage.googleapis.com/noonprd-mp-gcs-instant-cms/instant/categories-288x289/Baby care.1671976999.6204247.png
# IconImage: https://z.nooncdn.com/rn/instant/category-icons/formula.png
# IconImage: https://z.nooncdn.com/rn/instant/category-icons/food.png
# IconImage: https://storage.googleapis.com/noonprd-mp-gcs-instant-cms/instant/categories-1302x1302/Nav pill – 25 (1).1693564209.0119758.png
# IconImage: https://storage.googleapis.com/noonprd-mp-gcs-instant-cms/instant/categories-1302x1302/Nav pill – 24.1693564149.6617785.png

# %%
for i in data_results:
    modules = i.get('modules', '')
    for j in modules:
        type = j.get('type', '')
        if type == 'productCarousel':
            name = j.get('moduleHeader','').get('titleText', '')
            feature = j.get('moduleHeader','').get('linkUrl', '')
            print(f"Title:{name}")
            print(f"Type:{type}")
            link = f'https://api-app-instant.noon.com/_svc/catalog{feature}'
            print(f"LinkCarousel:{link}")
        if type == 'adBannerSlider':
            name = 'Banner'
            banners = j.get('banners', '')
            for banner in banners:
                banner_url = banner.get('imageUrl', '')
            print(f"Type:{type}")
            print(f"BannerUrl: {banner_url}")
# Out:
# Type:adBannerSlider
# BannerUrl: https://k.nooncdn.com/instant/cms-800x300/en-banner – 1 (3).1720072508.6208732.png

# %% [markdown]
# # Group

# %%
url = "https://api-app-instant.noon.com/_svc/catalog/search?f[category]=baby"# Link de Grupo

payload = {}
headers = {
  'accept': 'application/json, text/plain, */*',
  'accept-encoding': 'gzip',
  'cache-control': 'no-cache',
  'connection': 'Keep-Alive',
  'cookie': 'dcae=1; x-location-ecom-ae=eyJsYXQiOiAyNTIwMDAwNzMsICJsbmciOiA1NTI3MTYzODYsICJhcmVhIjogIkQ4NiAtIER1YmFpIC0gRHViYWkifQ; x-available-ae=ecom-food-nooninstant-noonnownow-money-rocket; ak_bmsc=D38E3B43A9C877B94316DD197C2E40EE~000000000000000000000000000000~; x-location-nooninstant-ae=eyJsYXQiOiAyNTEyNDQ4ODgsICJsbmciOiA1NTQwMzc1NjgsICJhcmVhIjogIlVubmFtZWQgUm9hZCAtIER1YmFpIFNpbGljb24gT2FzaXMgLSBEdWJhaSJ9; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiJlODNmMTU0NmZkODU0YTQwYjBiMTQ3ZDFhOTRlMjY3ZiIsImlhdCI6MTcxNjMwMzI2MywiZXhwIjoxNzE2MzAzNTYzfQ.OqAPPv528DW1Vwug_6-5KrAllakq_hzhaDeLcVAOpdk; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiIyMjAxNGJhMzdhOWY0Y2E5YTM3OTcxZmYzN2U0MWJlOCIsImlhdCI6MTcxNjMwMzY0NSwiZXhwIjoxNzE2MzAzOTQ1fQ.6NswdOh5-R9RN9braCwfJRPiI-Y1uJ_5_J-mccAd3W0',
  'host': 'api-app-instant.noon.com',
  'user-agent': 'okhttp/4.9.2',
  'x-abx': 'ipl_entrypoint_v2=1,ipl_v2=1,noon_pass=1,otp_login=1,tip_amount_minutes_ae=1',
  'x-aby': '{"ipl_entrypoint_v2.enabled":1,"ipl_v2.enabled":1,"noon_pass.enabled":1,"otp_login.enabled":1,"tip_amount_minutes_ae.enabled":1}',
  'x-border-enabled': 'true',
  'x-build': '3568',
  'x-content': 'mobile',
  'x-device-id': 'd18aab29fd9bbc3e',
  'x-ecom-zonecode': 'AE_DXB-S5',
  'x-experience': 'nooninstant',
  'x-food-zonecode': 'FOOD-AE-DXB-HUB2-BUSINESS_BAY',
  'x-lat': '251244888',
  'x-lng': '554037568',
  'x-locale': 'en-ae',
  'x-mp': 'nooninstant',
  'x-nooninstant-zonecode': 'W00000146A',
  'x-noonnownow-zonecode': 'NOWNOW-AE-DXB-HUB6-DOWNTOWN_DUBAI',
  'x-platform': 'android',
  'x-rocket-enabled': 'true',
  'x-rocket-mp-zonecode': 'W00067526A',
  'x-rocket-zonecode': 'W00067526A',
  'x-visitor-id': '8ecdb855-a8a9-4636-968b-742fddeb6056'
}

response = requests.request("GET", url, headers=headers, data=payload, proxies = {'https': proxy})
data = response.json()
data_results = data.get('results', '')
print(data_results)
# Out:
# [{'modules': [{'type': 'adBannerModuleStrip', 'widgetCode': 'aa_baby_strip_plp', 'numPerRow': None, 'moduleHeader': None, 'banners': [{'code': 'visa_may_24_strip_april_baby', 'linkUrl': '/page/visa', 'imageUrl': 'https://k.nooncdn.com/instant/cms-800x70/en_mb_uae-strip-01.1715712215.2429316.png', 'lottieUrl': None, 'gapt': {'name': 'visa_may_24_strip_april_baby', 'position': 'aa_baby_strip_plp/0'}, 'label': {'position': {'bottom': 0, 'right': 0}, 'bgColor': 'transparent', 'textColor': 'white', 'text': ''}}], 'position': 0, 'outerSpacing': {'top': 0, 'bottom': 0}, 'curl': '/search?f%5Bcategory%5D=baby'}]}, {'modules': [{'type': 'adBannerSlider', 'widgetCode': 'baby_plp_banner', 'numPerRow': None, 'moduleHeader': None, 'banners': [{'code': 'baby_incategorybanner_1', 'linkUrl': '', 'imageUrl': None, 'lottieUrl': None, 'gapt': {'name': 'baby_incategorybanner_1', 'position': 'baby_plp_banner/0'}, 'label': {'position': {'bottom': 0, 'right': 0}, 'bgColor': 'transparent', 'textColor': 'whit
# ...

# %%
for i in range(0, len(data_results)):
    if i == 0:
        location = "H"
    elif i == len(data_results) - 1:
        location = "F"
    else:
        location = "M"
        
    modules = data_results[i].get('modules', '')
    for j in modules:
        type = j.get('type', '')
        print(f"{type}")
        if 'Banner' in type:
            banners = j.get('banners', '')
            for banner in banners:
                time.sleep(1)
                fecha_hora_actual = datetime.datetime.now()
                fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
                file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - G{location}B.jpg"
                banner_url = banner.get('imageUrl', '')
                try:
                    response_image = requests.get(banner_url)
                    with open(file_name, "wb") as f:
                        f.write(response_image.content)
                    print(f"Imagen Descargada: {banner_url}")
                except Exception as e:
                    print(f"No se puedo descargar la Imagen: {banner_url}")
# Out:
# adBannerModuleStrip
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x70/en_mb_uae-strip-01.1715712215.2429316.png
# adBannerSlider
# No se puedo descargar la Imagen: None
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/Hero EN banner (2).1715778528.0844345.png
# No se puedo descargar la Imagen: None
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/en_mb_uae-hero – 1.1715941732.7313182.png
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/en_mb_uae-hero-01.1715876629.3461685.jpg
# adBannerModuleStrip
# No se puedo descargar la Imagen: None
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# ...

# %% [markdown]
# # Category

# %%
path = f"A:\\BeOn_Repositories\\imagenes_noon\\visibility_category_noon"

# %%
username = 'user-spwnapellv-country-ae-city-dubai'
password = '3dxWxvajxn4k7SiF4G'
proxy = f"http://{username}:{password}@gate.smartproxy.com:10001"
url = "https://api-app-instant.noon.com/_svc/catalog/search"

payload = json.dumps({
  "q": None,
  "sort": None,
  "f": {
    "category": [
      "deodorant",# Categoria
      "personal_care"# Grupo
    ]
  },
  "pillType": None,
  "showReorder": 0,
  "subcategory": 0,
  "page": 1,
  "rows": 60,
  "reorderItems": 0
})
headers = {
  'accept': 'application/json, text/plain, */*',
  'accept-encoding': 'gzip',
  'cache-control': 'no-cache',
  'connection': 'Keep-Alive',
  'content-type': 'application/json',
  'host': 'api-app-instant.noon.com',
  'user-agent': 'okhttp/4.9.2',
  'x-abx': 'ipl_entrypoint_v2=1,ipl_v2=1,noon_pass=1,otp_login=1,tip_amount_minutes_ae=1',
  'x-aby': '{"ipl_entrypoint_v2.enabled":1,"ipl_v2.enabled":1,"noon_pass.enabled":1,"otp_login.enabled":1,"tip_amount_minutes_ae.enabled":1}',
  'x-border-enabled': 'true',
  'x-build': '3568',
  'x-content': 'mobile',
  'x-device-id': 'd18aab29fd9bbc3e',
  'x-ecom-zonecode': 'AE_DXB-S5',
  'x-experience': 'nooninstant',
  'x-food-zonecode': 'FOOD-AE-DXB-HUB2-BUSINESS_BAY',
  'x-lat': '251244888',
  'x-lng': '554037568',
  'x-locale': 'en-ae',
  'x-mp': 'nooninstant',
  'x-nooninstant-zonecode': 'W00000146A',
  'x-noonnownow-zonecode': 'NOWNOW-AE-DXB-HUB6-DOWNTOWN_DUBAI',
  'x-platform': 'android',
  'x-rocket-enabled': 'true',
  'x-rocket-mp-zonecode': 'W00067526A',
  'x-rocket-zonecode': 'W00067526A',
  'x-visitor-id': '8ecdb855-a8a9-4636-968b-742fddeb6056'
}

response = requests.request("POST", url, headers=headers, data=payload, proxies = {'https': proxy})
data = response.json()
data_results = data.get('results', '')

# %%
print(data_results)
# Out:
# [{'modules': [{'type': 'adBannerSlider', 'widgetCode': 'personal_care_plp_banner', 'numPerRow': None, 'moduleHeader': None, 'banners': [{'code': 'personalcare_incategorybanner_1', 'linkUrl': '', 'imageUrl': None, 'lottieUrl': None, 'gapt': {'name': 'personalcare_incategorybanner_1', 'position': 'personal_care_plp_banner/0'}, 'label': {'position': {'bottom': 0, 'right': 0}, 'bgColor': 'transparent', 'textColor': 'white', 'text': ''}, 'slotId': 'personalcare_incategorybanner_1', 'is_ad': 1}, {'code': 'lux_personal_care_admon_may_24_plp_banner', 'linkUrl': '/search?f[tag]=lux_personal_care_admon_may_24', 'imageUrl': 'https://k.nooncdn.com/instant/cms-800x300/NOON banner LUX 100 (800x300px) EN.1716049702.301871.jpg', 'lottieUrl': None, 'gapt': {'name': 'lux_personal_care_admon_may_24_plp_banner', 'position': 'personal_care_plp_banner/1'}, 'label': {'position': {'bottom': 0, 'right': 0}, 'bgColor': 'transparent', 'textColor': 'white', 'text': ''}}, {'code': 'personalcare_incategorybanner_
# ...

# %%
for i in range(0, len(data_results)):
    if i == 0:
        location = "H"
    elif i == len(data_results) - 1:
        location = "F"
    else:
        location = "M"
        
    modules = data_results[i].get('modules', '')
    for j in modules:
        type = j.get('type', '')
        print(f"{type}")
        if 'Banner' in type:
            banners = j.get('banners', '')
            for banner in banners:
                time.sleep(1)
                fecha_hora_actual = datetime.datetime.now()
                fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
                file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - C{location}B.jpg"
                banner_url = banner.get('imageUrl', '')
                try:
                    response_image = requests.get(banner_url)
                    with open(file_name, "wb") as f:
                        f.write(response_image.content)
                    print(f"Imagen Descargada: {banner_url}")
                except Exception as e:
                    print(f"No se puedo descargar la Imagen: {banner_url}")
# Out:
# adBannerSlider
# No se puedo descargar la Imagen: None
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/NOON banner LUX 100 (800x300px) EN.1716049702.301871.jpg
# No se puedo descargar la Imagen: None
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/NOON in-cat banner DOVE (800x300px) EN.1715694454.6293066.png
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/en_nim_ae-beauty-banner – 2.1693503999.429847.png
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox
# instantProductBox

# %%
cadena = "baking_sugars,syrups_toppings_baking"
list_group_cat = cadena.split(",")
print(lista_separada)
# Out:
# ['baking_sugars', 'syrups_toppings_baking']
