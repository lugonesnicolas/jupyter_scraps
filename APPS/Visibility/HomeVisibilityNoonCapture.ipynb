# %%
import time
import requests
import json
import datetime

# %%
path = f"A:\\BeOn_Repositories\\imagenes_noon\\visibility_home_noon"
app_name = "Noon App UAE"
app_section = 'H'

# %%
headers_feature = {
  'accept': 'application/json, text/plain, */*',
  'accept-encoding': 'gzip',
  'cache-control': 'no-cache',
  'connection': 'Keep-Alive',
  'cookie': 'dcae=1; x-location-ecom-ae=eyJsYXQiOiAyNTA4MzgyNjcsICJsbmciOiA1NTIyMDM5NjYsICJhcmVhIjogIkFsIEJhcnNoYSJ9; x-available-ae=ecom-food-nooninstant-noonnownow-money-rocket; ak_bmsc=C4B59585D611B72BB724656F9CE30049~000000000000000000000000000000~; x-location-nooninstant-ae=eyJsYXQiOiAyNTA4MzgyNjcsICJsbmciOiA1NTIyMDM5NjYsICJhcmVhIjogIkFsIEJhcnNoYSJ9; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiJhZjJmZDZhZGY0YTk0YzQxYjJmOTRjNzI2OWYyNzU0ZSIsImlhdCI6MTcxNTg3MzI4NCwiZXhwIjoxNzE1ODczNTg0fQ.6SAQm5kL2CRDaRO6g_C84lytReTFEwGVj7GkgA_HvOQ; nguestv2=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJraWQiOiJmMjZmYmEwNzY2OWM0MzZmOGY4YTQxYTk5NzI3ZWQwMyIsImlhdCI6MTcxNTg3NDkwOSwiZXhwIjoxNzE1ODc1MjA5fQ.6tbDjqBER5bpe50ep6W9Y13nqbfbWfs-BEwoyZM1k6Y',
  'host': 'api-app-instant.noon.com',
  'user-agent': 'okhttp/4.11.0',
  'x-abx': 'ipl_entrypoint_v2=1,ipl_v2=1,noon_pass=1,otp_login=1,tip_amount_minutes_ae=1',
  'x-aby': '{"ipl_entrypoint_v2.enabled":1,"ipl_v2.enabled":1,"noon_pass.enabled":1,"otp_login.enabled":1,"tip_amount_minutes_ae.enabled":1}',
  'x-border-enabled': 'true',
  'x-build': '4102',
  'x-content': 'mobile',
  'x-device-id': '6878ce25372efc2f',
  'x-ecom-zonecode': 'AE_DXB-S3',
  'x-experience': 'nooninstant',
  'x-food-zonecode': 'FOOD-AE-DXB-HUB5-BARSHA_SOUTH',
  'x-lat': '250838267',
  'x-lng': '552203966',
  'x-locale': 'en-ae',
  'x-mp': 'nooninstant',
  'x-nooninstant-zonecode': 'W00057638A',
  'x-noonnownow-zonecode': 'NOWNOW-AE-DXB-HUB14-BARSHA_SOUTH',
  'x-platform': 'android',
  'x-rocket-enabled': 'true',
  'x-rocket-mp-zonecode': 'W00067526A',
  'x-rocket-zonecode': 'W00067526A',
  'x-visitor-id': 'b56bf1ae-6acc-4150-b11c-1ce9ab8171fd'
}

# %%
username = 'user-spwnapellv-country-ae-city-dubai'
password = '3dxWxvajxn4k7SiF4G'
proxy = f"http://{username}:{password}@gate.smartproxy.com:7000"

# %%
url = "https://api-app-instant.noon.com/_svc/catalog/search"

payload = json.dumps({
  "q": None,
  "sort": None,
  "f": {
    "page_code": [
      "home_app_mobile_ae"
    ]
  },
  "pillType": None,
  "showReorder": 0,
  "subcategory": 0,
  "page": 1,
  "rows": 60,
  "reorderItems": 0
})
headers = {
  'accept': 'application/json, text/plain, */*',
  'accept-encoding': 'gzip',
  'cache-control': 'no-cache',
  'connection': 'Keep-Alive',
  'content-type': 'application/json',
  'host': 'api-app-instant.noon.com',
  'user-agent': 'okhttp/4.11.0',
  'x-abx': 'ipl_entrypoint_v2=1,ipl_v2=1,noon_pass=1,otp_login=1',
  'x-aby': '{"ipl_entrypoint_v2.enabled":1,"ipl_v2.enabled":1,"noon_pass.enabled":1,"otp_login.enabled":1}',
  'x-border-enabled': 'true',
  'x-build': '4102',
  'x-content': 'mobile',
  'x-device-id': '6878ce25372efc2f',
  'x-ecom-zonecode': 'AE_DXB-S3',
  'x-experience': 'nooninstant',
  'x-food-zonecode': 'FOOD-AE-DXB-HUB5-BARSHA_SOUTH',
  'x-lat': '250838267',
  'x-lng': '552203966',
  'x-locale': 'en-ae',
  'x-mp': 'nooninstant',
  'x-nooninstant-zonecode': 'W00057638A',
  'x-noonnownow-zonecode': 'NOWNOW-AE-DXB-HUB84-BARSHA_SOUTH',
  'x-platform': 'android',
  'x-rocket-enabled': 'true',
  'x-rocket-zonecode': 'W00067526A',
  'x-visitor-id': 'b56bf1ae-6acc-4150-b11c-1ce9ab8171fd'
}

response = requests.request("POST", url, headers=headers, data=payload, proxies = {'https': proxy})
data = response.json()
print(data)
# Out:
# {'nbHits': 1, 'nbPages': 1, 'search': {'q': None, 'sort': None, 'f': {'page_code': ['home_app_mobile_ae']}, 'pillType': None, 'showReorder': 0, 'subcategory': 0, 'page': 1, 'rows': 60, 'reorderItems': 0}, 'type': 'catalog', 'facets': [], 'navPills': [], 'displayType': 'navPill', 'canonical_url': '/search?f%5Bpage_code%5D=home_app_mobile_ae', 'whCode': 'W00057638A', 'pills': None, 'analytics': None, 'bgColor': '#ffffff', 'postATCCMSLimit': 2, 'floatingComponent': {'code': 'clearance_sale', 'title': 'Trending Now', 'iconUrl': 'https://k.nooncdn.com/instant/cms-512x512/discount_icon.1714973922.347585.png', 'url': '/page/personal_beauty_toys_electronics_clearance_may', 'bgColor': '#029a46', 'textColor': '#ffffff'}, 'results': [{'modules': [{'type': 'adBannerModuleStrip', 'widgetCode': 'widget_1', 'numPerRow': None, 'moduleHeader': None, 'banners': [{'code': 'upperstrip_banner_ad', 'linkUrl': '', 'imageUrl': None, 'lottieUrl': None, 'gapt': {'name': 'upperstrip_banner_ad', 'position': 'wi
# ...

# %%
data = data.get('results', '')
# print(data)

# %%
modules = [i.get('modules', '') for i in data]

# %%
# print(len(modules))
# for i in modules:
#     print(f"{i}\n")

# %%
payload = {}
for i in range(0,len(modules)):
    if i == 0:
        location = 'Header'
    elif i == len(modules) - 1:
        location = 'Footer'
    else:
        location = 'Mid'
        
    element = modules[i][0]
    type = element.get('type', '')
    print(f"Type: {type}")
    print(f"Location: {location}")
    if 'instantReorder' == type:
        module_header = element.get('moduleHeader', '')
        name_module = module_header.get('linkText', '')
        curl = element.get('curl', '')
        print(f"NameModule: {name_module}")
        print(f"Curl: {curl}")
    # Este caso requiere una request por carrusel
    if 'productCarousel' == type:
        products_url = element.get('productUrl', '')
        if products_url != None:
            products_url = f"https://api-app-instant.noon.com/_svc/catalog{products_url}"
            print(f"ProductsUrl: {products_url}")
            response = requests.request("GET", products_url, headers=headers_feature, data=payload, proxies = {'https': proxy})
            data = response.json()
            hits = data.get('hits', '')
            # print(hits)
        else:
            # Chequear que tipo de elementos son
            module_header = element.get('moduleHeader', '')
            name_module = module_header.get('linkText', '')
            curl = element.get('curl', '')
            print(f"NameModule: {name_module}")
            print(f"Curl: {curl}")
    else:
        banners = element.get('banners', '')
        for banner in banners:
            url_banner = banner.get('imageUrl', '')
            print(f"Banner: {url_banner}")
        
    print(f"\n")
# Out:
# Type: adBannerModuleStrip
# Location: Header
# Banner: None
# Banner: https://k.nooncdn.com/instant/cms-800x70/en-strip.1716783834.4738631.png
#
#
# Type: adBannerSlider
# Location: Mid
# Banner: https://k.nooncdn.com/instant/cms-800x300/en-hero-banner – 1.1716480511.485343.png
# Banner: https://k.nooncdn.com/instant/cms-800x300/en-banner – 2.1716995525.364453.png
# Banner: https://k.nooncdn.com/instant/cms-800x300/ENG Hero banner 800X300 (1).1716481779.0898674.jpg
# Banner: https://k.nooncdn.com/instant/cms-800x300/En-hero banner – 28.1716956647.598956.png
# Banner: https://k.nooncdn.com/instant/cms-1667x625/Noon May 2024_20 off_EN_Hero + Categroy Banner_800x300.1716568063.8656373.png
# Banner: https://k.nooncdn.com/instant/cms-800x300/NOON banner OMO  (800x300px) EN.1716568093.1026425.jpg
# Banner: https://k.nooncdn.com/instant/cms-800x300/en_mb_uae-hero-01 – 9.1717004269.3277338.png
# Banner: https://k.nooncdn.com/instant/cms-800x300/en-banner – 1 (52).1716958051.4931068.png
# ...

# %%
# 'bannerModuleScroller' son los iconos de categorias que para nosotros son others y no banners

# %%
payload = {}
for i in range(0,len(modules)):
    if i == 0:
        location = 'H'
    elif i == len(modules) - 1:
        location = 'F'
    else:
        location = 'M'
        
    element = modules[i][0]
    type = element.get('type', '')
    print(f"Type: {type}")
    print(f"Location: {location}")
    if 'instantReorder' == type:# No tiene elementos visibles 
        module_header = element.get('moduleHeader', '')
        name_module = module_header.get('linkText', '')
        curl = element.get('curl', '')
        print(f"NameModule: {name_module}")
        print(f"Curl: {curl}")
    
    if 'productCarousel' == type:# Este caso requiere una request por carrusel
        products_url = element.get('productUrl', '')
        if products_url != None:
            products_url = f"https://api-app-instant.noon.com/_svc/catalog{products_url}"
            print(f"ProductsUrl: {products_url}")
            response_product_carrousel = requests.request("GET", products_url, headers=headers_feature, data=payload, proxies = {'https': proxy})
            data_carrousel = response_product_carrousel.json()
            hits_carrousel = data_carrousel.get('hits', '')
            for id in range(0, len(hits_carrousel)):
                if id < 3:
                    time.sleep(1)
                    fecha_hora_actual = datetime.datetime.now()
                    fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
                    file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - H{location}F.jpg"
                    images = hits_carrousel[id].get('image_keys', '')
                    image = f"https://f.nooncdn.com/p/{images[0]}.jpg?width=400&format=webp"
                    response_image = requests.get(image)
                    try:
                        with open(file_name, "wb") as f:
                            f.write(response_image.content)
                        print(f"Imagen Descargada: {image}")
                    except Exception as e:
                        print(f"No se puedo descargar la Imagen: {image}")
        else:
            # Chequear que tipo de elementos son
            module_header = element.get('moduleHeader', '')
            name_module = module_header.get('linkText', '')
            curl = element.get('curl', '')
            print(f"NameModule: {name_module}")
            print(f"Curl: {curl}")
    # if type == 'bannerModuleScroller':
    #     banners = element.get('banners', '')
    #     for banner in banners:
    #         time.sleep(1)
    #         fecha_hora_actual = datetime.datetime.now()
    #         fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
    #         file_name = f"{path}\\{fecha_hora_formateada}_H{location}O.jpg"
    #         url_banner = banner.get('imageUrl', '')
    #         try:
    #             response_image = requests.get(url_banner)
    #             with open(file_name, "wb") as f:
    #                 f.write(response_image.content)
    #             print(f"Imagen Descargada: {url_banner}")
    #         except Exception as e:
    #             print(f"No se puedo descargar la Imagen: {url_banner}")
    else:
        banners = element.get('banners', '')
        for banner in banners:
            time.sleep(1)
            fecha_hora_actual = datetime.datetime.now()
            fecha_hora_formateada = fecha_hora_actual.strftime("%Y_%m_%d_%H_%M_%S")
            file_name = f"{path}\\{fecha_hora_formateada}_{app_name} - H{location}B.jpg"
            url_banner = banner.get('imageUrl', '')
            if ".gif" not in url_banner:
                try:
                    response_image = requests.get(url_banner)
                    with open(file_name, "wb") as f:
                        f.write(response_image.content)
                    print(f"Imagen Descargada: {url_banner}")
                except Exception as e:
                    print(f"No se puedo descargar la Imagen: {url_banner}")
        
    print(f"\n")
# Out:
# Type: adBannerModuleStrip
# Location: H
# No se puedo descargar la Imagen: None
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x70/en-strip-banner – 13.1716462776.5825796.png
#
#
# Type: adBannerSlider
# Location: M
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/en-banner – 1 (1).1716200208.4404716.png
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/en_mb_uae-hero-01 – 3.1716313010.3274007.png
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/en-banner – 39.1716347324.0329094.png
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/En-hero banner.1715948351.7466063.png
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/800X300 eng.1715963330.4552944.jpg
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/ENG Freez Mix- -Home banner.1715949819.5611687.png
# Imagen Descargada: https://k.nooncdn.com/instant/cms-800x300/en_mb-uae-hero.1716281974.8480673.png
# ...

# %%
import glob
import os

# %%
imagenes = glob.glob(os.path.join(path, "*.jpg"))# Obtengo una lista de imagenes que tengas la extencion jpg
for i in range(0, len(imagenes)):# Recorro la lista y remplazo el nombre de la ruta
    if i < len(imagenes) / 2:
        new_path = imagenes[i].replace("Noon App UAE", "AE - Noon App UAE")
        os.rename(imagenes[i], new_path)
    else:
        new_path = imagenes[i].replace("Noon App UAE", "AF - Noon App UAE")
        os.rename(imagenes[i], new_path)
    print(f"RutaOriginal: {imagenes[i]}")
    print(f"RutaNueva: {new_path}\n")
# Out:
# RutaOriginal: A:\BeOn_Repositories\imagenes_noon\visibility_home_noon\2024_05_23_10_31_31_Noon App UAE - HHB.jpg
# RutaNueva: A:\BeOn_Repositories\imagenes_noon\visibility_home_noon\2024_05_23_10_31_31_AD_Noon App UAE - HHB.jpg
#
# RutaOriginal: A:\BeOn_Repositories\imagenes_noon\visibility_home_noon\2024_05_23_10_31_32_Noon App UAE - HMB.jpg
# RutaNueva: A:\BeOn_Repositories\imagenes_noon\visibility_home_noon\2024_05_23_10_31_32_AD_Noon App UAE - HMB.jpg
#
# RutaOriginal: A:\BeOn_Repositories\imagenes_noon\visibility_home_noon\2024_05_23_10_31_34_Noon App UAE - HMB.jpg
# RutaNueva: A:\BeOn_Repositories\imagenes_noon\visibility_home_noon\2024_05_23_10_31_34_AD_Noon App UAE - HMB.jpg
#
# RutaOriginal: A:\BeOn_Repositories\imagenes_noon\visibility_home_noon\2024_05_23_10_31_35_Noon App UAE - HMB.jpg
# RutaNueva: A:\BeOn_Repositories\imagenes_noon\visibility_home_noon\2024_05_23_10_31_35_AD_Noon App UAE - HMB.jpg
#
# ...
