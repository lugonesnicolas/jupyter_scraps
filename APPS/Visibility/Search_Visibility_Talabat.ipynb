# %%
import requests

# %% [markdown]
# # Home

# %%
url = "https://api.talabat.com/grocery/v3/ae/pages/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/home?isDarkstore=true&areaId=1464&pageNumber=0&chainId=25065&branchId=613210"

payload = {}
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6IjU2MjMxZjcwMjczNDRjZmQ5ZWQ3MzFjYzBjNzJjZDgzIiwiaWQiOiI1YzAwYWZmMmVlNzA0NWQ4IiwidGkiOjE3MTU3Nzk4MTU5MzAsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-56231f7027344cfd9ed731cc0c72cd83-5c00aff2ee7045d8-00',
  'tracestate': '346080@nr=0-2-938958-414461638-5c00aff2ee7045d8----1715779815929',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-customer-id': '0',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1715778504621.355588470198769525.9AQ6y7bzBz',
  'x-weightables-enabled': 'true',
  'Cookie': '__cf_bm=xJHINqqtpMMgqLxPM8R4ouIvF.O2faYSfLJN.6hlD1s-1715778711-1.0.1.1-wViulpxpFF30kr___VeNxs4hpP5c57cf56HjHivnMqGdRwaKq3maERUP06a0W7HUHMM6EDqIDhpmrrXDPLCcG9hI34MxVKTF35CE3GTlJ3A; AWSALB=iO61DtraSbXiQqMNYKpVeBvY93M9xJrsaujwetfYzW2Yh1s4Y7LsGp9EJBlBKDZCFXb8YHCPOlDy3lDvoz6GaoLdPFrAKQmA1zLqMItFv6Mdr9tK31uW9BdATovZ; AWSALBCORS=iO61DtraSbXiQqMNYKpVeBvY93M9xJrsaujwetfYzW2Yh1s4Y7LsGp9EJBlBKDZCFXb8YHCPOlDy3lDvoz6GaoLdPFrAKQmA1zLqMItFv6Mdr9tK31uW9BdATovZ'
}

response = requests.request("GET", url, headers=headers, data=payload)
data = response.json()
components = data['components']
items = [i.get('items', '') for i in components]
# Out:
# [{'component_version': 'v0', 'is_scrollable': True, 'items': [{'bg_color': '#DBE7AF', 'id': '9234d2db-0699-4a26-8c10-f49e1d75a803.f243b85b-503c-412f-9bbe-7c7135ba6f0a.af87d300-68dd-4a8b-acd5-01690126ffee', 'image_url': 'https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/teerfe.png', 'title': 'Grocery Offers'}, {'bg_color': '#FFDADF', 'id': '9234d2db-0699-4a26-8c10-f49e1d75a803.4dc868bd-8cf6-4d28-803a-1a36edc92e6e.af87d300-68dd-4a8b-acd5-01690126ffee', 'image_url': 'https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/szax%20(231).png', 'title': 'Seasonal Freshness'}, {'bg_color': '#C3E3E9', 'id': '9234d2db-0699-4a26-8c10-f49e1d75a803.f3ae2b94-6f1d-4b18-bc82-eb6d18a33648.af87d300-68dd-4a8b-acd5-01690126ffee', 'image_url': 'https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/grrrlsop%20(31ddw1).png', 'title': 'Daily Discounts'}, {'bg_color': '#FEE3A9', 'id': 
# ...

# %% [markdown]
# # Categorias

# %%
for i in components:
    print(f"{i}\n")
# Out:
# {'component_version': 'v0', 'is_scrollable': True, 'items': [{'bg_color': '#DBE7AF', 'id': '9234d2db-0699-4a26-8c10-f49e1d75a803.f243b85b-503c-412f-9bbe-7c7135ba6f0a.af87d300-68dd-4a8b-acd5-01690126ffee', 'image_url': 'https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/teerfe.png', 'title': 'Grocery Offers'}, {'bg_color': '#FFDADF', 'id': '9234d2db-0699-4a26-8c10-f49e1d75a803.4dc868bd-8cf6-4d28-803a-1a36edc92e6e.af87d300-68dd-4a8b-acd5-01690126ffee', 'image_url': 'https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/szax%20(231).png', 'title': 'Seasonal Freshness'}, {'bg_color': '#C3E3E9', 'id': '9234d2db-0699-4a26-8c10-f49e1d75a803.f3ae2b94-6f1d-4b18-bc82-eb6d18a33648.af87d300-68dd-4a8b-acd5-01690126ffee', 'image_url': 'https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/grrrlsop%20(31ddw1).png', 'title': 'Daily Discounts'}, {'bg_color': '#FEE3A9', 'id': '
# ...

# %%
for i in components:
    type = i.get('type', '')
    items = i.get('items', '')
    if type == 'categories':
        print(f"Type:{type}")
        print(f"Items:{len(items)}")
        # print(f"Items:{items}")
        for i in items:
            title = i.get('title', '')
            if title == 'Coffee & Tea':
                id = i.get('id', '')
                print(f"Title:{title}")
                print(f"Id:{id}")
                print(f"LinkSubcategorias:https://api.talabat.com/grocery/v1/ae/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/category-trees/{id}?isDarkstore=true")
                print(f"LinkProductos:https://api.talabat.com/grocery/v1/ae/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/categories/7eacaabf-cf95-4c59-b1e2-ca5585488a11/products?isDarkstore=true&pageNumber=0")
# Out:
# Type:categories
# Items:11
# Title:Coffee & Tea
# Id:7eacaabf-cf95-4c59-b1e2-ca5585488a11
# LinkSubcategorias:https://api.talabat.com/grocery/v1/ae/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/category-trees/7eacaabf-cf95-4c59-b1e2-ca5585488a11?isDarkstore=true
# LinkProductos:https://api.talabat.com/grocery/v1/ae/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/categories/7eacaabf-cf95-4c59-b1e2-ca5585488a11/products?isDarkstore=true&pageNumber=0

# %%
# for i in items:
#     print(i)

# %%
for i in sub_categories:
    name = i.get('name', '')
    id = i.get('id', '')
    print(f"Name: {name}")
    print(f"Id: {id}")
    print(f"LinkCategory: https://api.talabat.com/grocery/v1/ae/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/category-trees/{id}?isDarkstore=true")

# %% [markdown]
# # Headers (subcategorias)

# %%
url = "https://api.talabat.com/grocery/v1/ae/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/category-trees/7eacaabf-cf95-4c59-b1e2-ca5585488a11?isDarkstore=true"

payload = {}
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6IjUxOTU1MDJlN2M3ZDQxNzlhMWY4MDY3OTZkNDI4NjM3IiwiaWQiOiIzNjhmNDM5MDFmNWM0YzcxIiwidGkiOjE3MTU3ODAxNTQxMzQsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-5195502e7c7d4179a1f806796d428637-368f43901f5c4c71-00',
  'tracestate': '346080@nr=0-2-938958-414461638-368f43901f5c4c71----1715780154134',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1715778504621.355588470198769525.9AQ6y7bzBz',
  'Cookie': '__cf_bm=j4s55z9Vz4HejbXr_zne3lZd5hMLlLrqJ.XiGvHzzKg-1715780535-1.0.1.1-yEPQYngj9QPaUNXBjbhBH7.7BlNEHbbbNlfPeJDCpiSEhUoPYrIb8bKZCdI1VKpRr9rka.OI1KNcj8O8dtKinuEBGPrdPPbU7BddgdHVc6c; AWSALB=1Dts+pZKCfO+KQorj9vP0jMAaMEZnJLuO6rOmr6CRHtVXD3oqSKdHE+d651wp59TnemQpJPqHPOD1x+4owzMWQ6f0gtwEHDVWHP54fuWsz5OVocojjZB+Ly5jR62; AWSALBCORS=1Dts+pZKCfO+KQorj9vP0jMAaMEZnJLuO6rOmr6CRHtVXD3oqSKdHE+d651wp59TnemQpJPqHPOD1x+4owzMWQ6f0gtwEHDVWHP54fuWsz5OVocojjZB+Ly5jR62'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"id":"7eacaabf-cf95-4c59-b1e2-ca5585488a11","image_urls":["https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/9009210.png"],"name":"Coffee \u0026 Tea","sub_categories":[{"id":"7eacaabf-cf95-4c59-b1e2-ca5585488a11","image_urls":["https://images.deliveryhero.io/image/darkstores/Tmart%20UAE%20Campaign%20banners%20and%20Icons/9009210.png"],"name":"All","sub_categories":[]},{"id":"b627c3e5-35cd-448a-9c68-9fb2d00cd861","image_urls":["https://images.deliveryhero.io/image/talabat-nv/Regional_Images/Images/Category_New_Images/All-Coffee.png"],"name":"Coffee","sub_categories":[{"id":"b627c3e5-35cd-448a-9c68-9fb2d00cd861","image_urls":["https://images.deliveryhero.io/image/talabat-nv/Regional_Images/Images/Category_New_Images/All-Coffee.png"],"name":"All","sub_categories":[]},{"id":"181d98ae-2f7a-462f-b7fe-e0c9b4b7262f","image_urls":["https://images.deliveryhero.io/image/talabat-nv/Regional_Images/Images/Categories_Images/URL89.png"],"name":"Sachet",
# ...

# %% [markdown]
# # Productos de la categoria

# %%
url = "https://api.talabat.com/grocery/v1/ae/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/categories/7eacaabf-cf95-4c59-b1e2-ca5585488a11/products?isDarkstore=true&pageNumber=0"

payload = {}
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6IjQ4N2NhZTc1YzhkYzQ4YjdhY2MzNGE0YTQyNTZjMTA0IiwiaWQiOiIzNWI4MTMwNDkwMjk0ZGM5IiwidGkiOjE3MTU3ODAxNTUyMDAsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-487cae75c8dc48b7acc34a4a4256c104-35b8130490294dc9-00',
  'tracestate': '346080@nr=0-2-938958-414461638-35b8130490294dc9----1715780155200',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1715778504621.355588470198769525.9AQ6y7bzBz',
  'x-weightables-enabled': 'true',
  'Cookie': '__cf_bm=xJHINqqtpMMgqLxPM8R4ouIvF.O2faYSfLJN.6hlD1s-1715778711-1.0.1.1-wViulpxpFF30kr___VeNxs4hpP5c57cf56HjHivnMqGdRwaKq3maERUP06a0W7HUHMM6EDqIDhpmrrXDPLCcG9hI34MxVKTF35CE3GTlJ3A; AWSALB=b+7UsXUFpc4U9FUAJy78HzKrLOomqGiuBALxmhVEqB8WiIVY/ZmFMAovJSaX7Lf7gruyrYcoNLVfTu7Pk3R/vcpLCeAzTJnzZvjm7wtJ/VAjAl4CEvaAz+bfcOrO; AWSALBCORS=b+7UsXUFpc4U9FUAJy78HzKrLOomqGiuBALxmhVEqB8WiIVY/ZmFMAovJSaX7Lf7gruyrYcoNLVfTu7Pk3R/vcpLCeAzTJnzZvjm7wtJ/VAjAl4CEvaAz+bfcOrO'
}

response = requests.request("GET", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"last_page":false,"products":[{"age_limit":0,"attributes":[{"id":"originalPrice","name":"27.300000","type":"characteristic"},{"id":"available","name":"false","type":"characteristic"},{"id":"salesBuffer","name":"0","type":"characteristic"},{"id":"pieceBarcodes","name":"08720608616688,06281006856370","type":"characteristic"},{"id":"chainProductId","name":"1358575","type":"characteristic"},{"id":"sku","name":"503075","type":"characteristic"},{"id":"masterCode","name":"KW9AM64U","type":"characteristic"},{"id":"brand","name":"","type":"characteristic"},{"id":"weightValue","name":"400.00","type":"characteristic"},{"id":"weightUnit","name":"g","type":"characteristic"},{"id":"lengthInCm","name":"12.60","type":"characteristic"},{"id":"widthInCm","name":"6.80","type":"characteristic"},{"id":"heightInCm","name":"16.00","type":"characteristic"},{"id":"numberOfUnits","name":"1","type":"characteristic"},{"id":"contentsValue","name":"400.00","type":"characteristic"},{"id":"contentsUnit","name":"g"
# ...

# %% [markdown]
# # Productos de search

# %%
import requests
import json

url = "https://api.talabat.com/grocery/v1/ae/vendors/4b4f686b-0d68-4286-a0e4-b06a2c1567ea/products/search"

payload = json.dumps({
  "config": "Control",
  "country_code": "ae",
  "is_darkstore": True,
  "language_code": "en",
  "limit": 20,
  "offset": 0,
  "query": "snack",
  "customer_id": None,
  "filters": {
    "variant": 2,
    "category_ids": []
  }
})
headers = {
  'accept-encoding': 'gzip',
  'accept-language': 'en-US',
  'appbrand': '1',
  'content-type': 'application/json',
  'host': 'api.talabat.com',
  'newrelic': 'eyJ2IjpbMCwyXSwiZCI6eyJ0eSI6Ik1vYmlsZSIsImFjIjoiOTM4OTU4IiwiYXAiOiI0MTQ0NjE2MzgiLCJ0ciI6IjViZWRiOGZkZjQxYjRjNGM4MDgxNGRlMzk2NTFhZGNjIiwiaWQiOiI4MDYxZjdiODIyZjQ0MDVlIiwidGkiOjE3MTUwODk1Nzk2MzAsInRrIjoiMzQ2MDgwIn19',
  'traceparent': '00-5bedb8fdf41b4c4c80814de39651adcc-8061f7b822f4405e-00',
  'tracestate': '346080@nr=0-2-938958-414461638-8061f7b822f4405e----1715089579630',
  'user-agent': 'Dart/2.19 (dart:io)',
  'x-device-framework': 'flutter',
  'x-device-id': 'e95299ca0874b933',
  'x-device-source': '6',
  'x-device-version': '10.442',
  'x-perseusclientid': '1711459087436.182339997051444231.txpOK01DXW',
  'x-perseussessionid': '1715088150051.536399785542626270.uYxRL3Gkhf',
  'x-primary-request-id': '',
  'Cookie': '__cf_bm=b1ruXqUETQdIFiaLh8f6VEa0ZQHeo3c8jKW3jfM_Y4Y-1715088276-1.0.1.1-HsTRR794WuluJG28kl8VZfyeee57SQJM9yOkJuskt0EBVQ1J7anSeigNmivpbOaGY5t99b3K4InZ2sCHpoca7tYcsazawCLq7R3Aj.Vxg58; AWSALB=LkdYPwbuuOUoJwoZpIxZKYQhxuUagtWOZClppiJdTEIgUeQ9ok4uMFucJ3XyvXbHLWV5eFUVZHyA9LcRpZoWL1gRDI8WgNmzmI/wFE6RXRKvz2Gvxdw+FJJHXgZ6; AWSALBCORS=LkdYPwbuuOUoJwoZpIxZKYQhxuUagtWOZClppiJdTEIgUeQ9ok4uMFucJ3XyvXbHLWV5eFUVZHyA9LcRpZoWL1gRDI8WgNmzmI/wFE6RXRKvz2Gvxdw+FJJHXgZ6'
}

response = requests.request("POST", url, headers=headers, data=payload)
data = response.json()
products = data.get('products', '')

# %%
position = 0
for i in products:
    if position < 100:
        position += 1
        image_url = i.get('image_url', '')
        print(f"ImageUrl:{image_url}")
# Out:
# ImageUrl:https://images.deliveryhero.io/image/darkstores/groceries-catalog/products-uae/UAE_2961570555117.jpg
# ImageUrl:https://images.deliveryhero.io/image/darkstores/groceries-catalog/products-uae/UAE_8906028080012.jpg
# ImageUrl:https://images.deliveryhero.io/image/darkstores/groceries-catalog/products-uae/UAE_2961570555209.jpg
# ImageUrl:https://images.deliveryhero.io/image/darkstores/groceries-catalog/products-uae/UAE_2961570555179.jpg
# ImageUrl:https://images.deliveryhero.io/image/darkstores/groceries-catalog/products-uae/Jeff/UAE_8410076601865.jpg
# ImageUrl:https://images.deliveryhero.io/image/darkstores/groceries-catalog/products-uae/UAE_5060139431231.jpg
# ImageUrl:https://images.deliveryhero.io/image/darkstores-om/Product_Images/OM_0744702477790.jpg
# ImageUrl:https://images.deliveryhero.io/image/darkstores/groceries-catalog/products-uae/UAE_42768919125.jpg
# ImageUrl:https://images.deliveryhero.io/image/product-information-management/65fc84b47a38bb403d600c90.jpg
# ...
