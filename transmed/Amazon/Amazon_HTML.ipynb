# %%
import requests
import re
from bs4 import BeautifulSoup
import time
import urllib3

# %%
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
#Proxy n.lijtmaer@beon.la
username = 'spl7rorb75'
password = 's6_rtuzLl39yr0WjUI'
proxy = f"http://{username}:{password}@gate.smartproxy.com:7000"

# %%
# Posible error en url que viene a los spiders
url = 'https://www.amazon.ae/Head-Shoulders-Menthol-Refresh-Anti-Dandruff/dp/B098D1LS7S/ref=sr_1_1?crid=3MFUIMO1RQ4N0&dib=eyJ2IjoiMSJ9.fgqdwz278OpixllffimLFQ.VmLg5hBqBxaBSogl6JZAYGQ9BH-A03ebPEncwnEMNs0&dib_tag=se&keywords=B098D1LS7S&qid=1708111204&sprefix=b098d1ls7s%2Caps%2C271&sr=8-1'

# %%
# Reemplazar la parte que coincide con el patrón por una cadena vacía
url = re.sub(r"ref=.*$", "", url)
print(url)
# Out:
# https://www.amazon.ae/Head-Shoulders-Menthol-Refresh-Anti-Dandruff/dp/B098D1LS7S/

# %%
# Url como deberia estar
url = 'https://www.amazon.ae/Venus-Gillette-Skin-Smoothing-Exfoliant/dp/B0BLZMCNB3/ref=sr_1_1?crid=3PIJ15U5OIUE2&amp'

# %%
# Test de url
url = 'https://www.amazon.ae/Pampers-Baby-Dry-Diapers-Leakage-Protection/dp/B07FPL22V9/'

# %%
payload = {}
headers = {
  'User-Agent': '',
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/png,image/svg+xml,*/*;q=0.8',
  'Accept-Language': 'es-AR,es;q=0.8,en-US;q=0.5,en;q=0.3',
  'Accept-Encoding': 'gzip, deflate, br, zstd',
  'DNT': '1',
  'Sec-GPC': '1',
  'Alt-Used': 'www.amazon.ae',
  'Connection': 'keep-alive',
  'Cookie': '',
  'Upgrade-Insecure-Requests': '1',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'none',
  'Sec-Fetch-User': '?1',
  'Priority': 'u=0, i',
  'TE': 'trailers'
}

# %%
# response = requests.request("GET", url, headers=headers, data=payload, proxies = {'https': proxy})
response = requests.request("GET", url, data=payload, proxies = {'https': proxy})
html_content = response.text
soup = BeautifulSoup(html_content, "html.parser")

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-ae"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <!-- sp:end-feature:csm:head-open-part2 -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
for i in range(0,50):
    response = requests.request("GET", url, data=payload, proxies = {'https': proxy}, verify=False)
    html_content = response.text
    soup = BeautifulSoup(html_content, "html.parser")
    title = soup.find('span', id='productTitle').text.strip() if soup.find('span', id='productTitle') != None else 'No title'
    print(f"---- {i} -> Title: {title}")
    # time.sleep(1)
# Out:
# ---- 0 -> Title: Pampers Baby-Dry Taped Diapers with Aloe Vera Lotion, up to 100% Leakage Protection, Size 3, 6-10kg, 17 Count
# ---- 1 -> Title: Pampers Baby-Dry Taped Diapers with Aloe Vera Lotion, up to 100% Leakage Protection, Size 3, 6-10kg, 17 Count
# ---- 2 -> Title: Pampers Baby-Dry Taped Diapers with Aloe Vera Lotion, up to 100% Leakage Protection, Size 3, 6-10kg, 17 Count
# ---- 3 -> Title: Pampers Baby-Dry Taped Diapers with Aloe Vera Lotion, up to 100% Leakage Protection, Size 3, 6-10kg, 17 Count
# ---- 4 -> Title: Pampers Baby-Dry Taped Diapers with Aloe Vera Lotion, up to 100% Leakage Protection, Size 3, 6-10kg, 17 Count
# ---- 5 -> Title: Pampers Baby-Dry Taped Diapers with Aloe Vera Lotion, up to 100% Leakage Protection, Size 3, 6-10kg, 17 Count
# ---- 6 -> Title: Pampers Baby-Dry Taped Diapers with Aloe Vera Lotion, up to 100% Leakage Protection, Size 3, 6-10kg, 17 Count
# ...

# %%
final_price = 0
old_price = 0

# %%
#Capturo el elemento que tiene el contenido
best_sellers_rank_container = soup.select_one('#productDetails_detailBullets_sections1 > tr:nth-child(3) > td:nth-child(2) > span:nth-child(1)')
#Si el elemento no tiene Customer Reviews cambia el selector
if best_sellers_rank_container == []:
    best_sellers_rank_container = soup.select_one('#productDetails_detailBullets_sections1 > tr:nth-child(2) > td:nth-child(2) > span:nth-child(1)')
if best_sellers_rank_container == None or best_sellers_rank_container == []:
    best_sellers_rank_container = soup_select_one('#productDetails_detailBullets_sections1 > tr > td > span')
 
try:
    if best_sellers_rank_container != None:
        #Extraigo el contenido como lista de elementos
        best_sellers_rank_element = best_sellers_rank_container.find("span span")
        
        #Extraigo solamente el contenido de cada elemento
        best_sellers_rank_content = []
        if best_sellers_rank_element:
            for i in best_sellers_rank_element:
                pattern = r">([^<]+)<"
                matches = re.findall(pattern, i.extract(), re.DOTALL)
                cadena = "".join(matches)
                best_sellers_rank_content.append(cadena)
            
            #print(f"El elemento best_sellers_rank_container:{best_sellers_rank_content}")# Print para testear el elemento  
            
        if len(best_sellers_rank_content) == 3:
            catgroup_best_sellers_rank = best_sellers_rank_content[0]
            # category_best_sellers_rank = f"{best_sellers_rank_content[1]}, {best_sellers_rank_content[2]}"
            category_best_sellers_rank = f"{best_sellers_rank_content[1]}"
        else:
            catgroup_best_sellers_rank = best_sellers_rank_content[0]
            category_best_sellers_rank = best_sellers_rank_content[1]
    #Elimino (See Top 100 in Grocery) de la cadena
    category_best_sellers_rank = re.sub(r"[^\d]", "", category_best_sellers_rank)
    catgroup_best_sellers_rank = re.sub(r"\(.*?\)", "", catgroup_best_sellers_rank)
    catgroup_best_sellers_rank = re.sub(r"[^\d]", "", catgroup_best_sellers_rank)

except:
    catgroup_best_sellers_rank = ""
    category_best_sellers_rank = ""
    print(f"ADVERTENCIA No se pudo extraer Best Selle Rank")

if best_sellers_rank_container == None or best_sellers_rank_container == []:
    try:
        best_sellers_list = soup.select_one('ul.a-unordered-list:nth-child(4) > li:nth-child(1) > span:nth-child(1)').text
        best_sellers_list = re.findall(r"#(\d+)", best_sellers_list)
        catgroup_best_sellers_rank = best_sellers_list[0]
        category_best_sellers_rank = best_sellers_list[1]
    except:
        print(f"No pude capturar el BestSeller")
    
a_plus = 1 if soup.find('div', id='aplus') != None else 0
bullet_points = ''
bullet_points_list = soup.find(class_='a-unordered-list a-vertical a-spacing-mini').find_all(class_='a-spacing-mini')
for i in range(0, len(bullet_points_list)):
    if i != len(bullet_points_list) - 1:
        bullet_points += f"{bullet_points_list[i].text.strip()}, "
    else:
        bullet_points += f"{bullet_points_list[i].text.strip()}."
# Out:
# ADVERTENCIA No se pudo extraer Best Selle Rank

# %%
buy_box = soup.select_one('#merchantInfoFeature_feature_div > div:nth-child(2) > div:nth-child(1) > span:nth-child(1) > a:nth-child(1)').text.strip() if soup.select_one('#merchantInfoFeature_feature_div > div:nth-child(2) > div:nth-child(1) > span:nth-child(1) > a:nth-child(1)') != None else ''
if buy_box == '':  # Check if buy_box is None using "not" operator
    buy_box = soup.select_one('#merchantInfoFeature_feature_div > div:nth-child(2) > div:nth-child(1) > span:nth-child(1)').text.strip() if soup.select_one('#merchantInfoFeature_feature_div > div:nth-child(2) > div:nth-child(1) > span:nth-child(1)') else ''

elif buy_box == '':  # Check again and assign an empty string
    buy_box = soup.select_one('tr.a-spacing-micro:nth-child(2) > td:nth-child(2) > span:nth-child(1) > a:nth-child(1)').text.strip() if soup.select_one('tr.a-spacing-micro:nth-child(2) > td:nth-child(2) > span:nth-child(1) > a:nth-child(1)') else ''

elif buy_box == '' and 'Amazon.ae' not in buy_box:
    # Verificar si el store es transmed
    others_offer_container = soup.select('div.a-box-inner.a-padding-small span.a-declarative div.a-row')

    for store in others_offer_container:
        title_store = store.select_one('div.a-section.a-spacing-none span.a-size-small.mbcMerchantName').text.strip()  # Get text and strip spaces
        print(f"Store: {title_store}")
        if 'Amazon.ae' in title_store:
            final_price = store.select_one('span.a-size-medium.a-color-price').text.strip()  # Get text and strip spaces
            is_transmed = True

else:
    is_transmed = True
    if buy_box != None and 'Amazon.ae' in buy_box:#Si buybox es de transmed extraigo el precio de arriba
        #Extraccion de Final Price cuando no tiene punto => Nueva funcion para final price
        final_price_int = soup.select_one('span.a-price.aok-align-center.reinventPricePriceToPayMargin.priceToPay span span.a-price-whole').text if soup.select_one('span.a-price.aok-align-center.reinventPricePriceToPayMargin.priceToPay span span.a-price-whole') != None else ''
        final_price_decimals = soup.select_one('pan.a-price.aok-align-center.reinventPricePriceToPayMargin.priceToPay span span.a-price-fraction').text if soup.select_one('pan.a-price.aok-align-center.reinventPricePriceToPayMargin.priceToPay span span.a-price-fraction') != None else ''
        if final_price_int != None and final_price_int != 0:
            try:
                final_price = f"{final_price_int}{final_price_decimals}"
                final_price = float(final_price)
            except:
                final_price = 0
                # print(f"1:No se pudo convertir a flotante final_price:{final_price}")
                
        
        #Si estamos en el segundo caso    
        if final_price == 0:
            final_price = soup.select_one('#newAccordionRow_0 > div:nth-child(1) > div:nth-child(1) > h5:nth-child(2) > div:nth-child(2) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > span:nth-child(1) > span:nth-child(1)').text if soup.select_one('#newAccordionRow_0 > div:nth-child(1) > div:nth-child(1) > h5:nth-child(2) > div:nth-child(2) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > div:nth-child(1) > span:nth-child(1) > span:nth-child(1)') != None else 0        
                
            
        old_price = soup.select_one('.basisPrice > span:nth-child(1) > span:nth-child(1)').text if soup.select_one('.basisPrice > span:nth-child(1) > span:nth-child(1)') != None else 0
        if old_price == None or old_price == 0:
            # print(f"Entre al caso del old price cuando se localiza sobre el final price\n")
            old_price = soup.select_one('td.a-color-secondary:nth-child(2) > span:nth-child(1) > span:nth-child(1)').text if soup.select_one('td.a-color-secondary:nth-child(2) > span:nth-child(1) > span:nth-child(1)') != None else 0

# %%
print(f"FinalPrice: {final_price}")
print(f"OldPrice: {old_price}")
print(f"BuyBox: {buy_box}")
print(f"Cat group best sellers rank: {catgroup_best_sellers_rank}")
print(f"Category best sellers rank: {category_best_sellers_rank}")
print(f"A+ content: {a_plus}")
print(f"Bullet points: {bullet_points}")
# Out:
# FinalPrice: 0
# OldPrice: 0
# BuyBox:
# Cat group best sellers rank:
# Category best sellers rank:
# A+ content: 1
# ...

# %%
test = soup.select("#productDetails_db_sections div table tr") if soup.select("#productDetails_db_sections div table tr") != [] else ''
for i in test:
    content = i.text
    if "Best Sellers Rank" in content:
        print(f"Content: {content}")
# Out:
# Content:   Best Sellers Rank    #10,739 in Baby Products (See Top 100 in Baby Products)  #563 in Disposable Baby Diapers

# %%
best_sellers_rank_elements = soup.find("div", id="productDetails_db_sections").div.table.find_all("tr") if soup.find("div", id="productDetails_db_sections") != None else ''
for i in best_sellers_rank_elements:
    content = i.text
    if "Best Sellers Rank" in content:
        print(content)
# Out:
#   Best Sellers Rank    #10,739 in Baby Products (See Top 100 in Baby Products)  #563 in Disposable Baby Diapers
