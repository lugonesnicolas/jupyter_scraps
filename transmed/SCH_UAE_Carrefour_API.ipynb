# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
username = 'Ec0m37ry'
password = 'fK7Ulvdm8zSVnyn22+'
proxy = f"http://{username}:{password}@ae.smartproxy.com:20000"

# %%
url = 'https://www.carrefouruae.com/mafuae/en/v4/search?keyword=coffee capsules nespresso'

# %%
payload = {}
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:123.0) Gecko/20100101 Firefox/123.0',
  'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
  'Accept-Language': 'es-AR,es;q=0.8,en-US;q=0.5,en;q=0.3',
  'Accept-Encoding': 'gzip, deflate, br',
  'Connection': 'keep-alive',
  'Cookie': 'cart_api=v2; _abck=59F693FA2C262E4EB9B6DF0D13FE55B8~0~...~-1~-1~-1; storeInfo=mafuae|en|AED; OptanonConsent=isGpcEnabled=1&datestamp=Tue+Mar+19+2024+11%3A37%3A04+GMT-0300+(hora+est%C3%A1ndar+de+Argentina)&version=202301.2.0&hosts=&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&consentId=ccb02f39-f0b2-4416-b38b-a3192a1b75c6&landingPath=NotLandingPage; mafuae-web-preferred-delivery-area="Dubai Festival City - Dubai"; ab.storage.sessionId.e6577fac-30b0-4270-a5df-788ef16dc4cd=%7B%22g%22%3A%220e04a7eb-c8cc-972e-4668-ee26f7f07c7a%22%2C%22e%22%3A1710860822264%2C%22c%22%3A1710859022048%2C%22l%22%3A1710859022264%7D; guest-session-token=aOTnKRB7qXnobya0Pn_-DppGGlE; _gcl_au=1.1.885303438.1710425902; OptanonAlertBoxClosed=2024-03-14T14:42:37.947Z; lat=25.183604; long=55.40198700000001; mafuae-cart=eb38b524-f52f-493b-a815-1aa49d1ef3f5; mafuae-preferred-delivery-area=5CM2%2BCR3%20-%20Al%20Warqa%20 - %20Al%20Warqa%201%20; prevAreaCode=5CM2%2BCR3%20-%20Al%20Warqa%20 - %20Al%20Warqa%201%20; maf-session-id=982F8D31-79B7-9E28-DE0B-4A1AB4730E8B; hideCoachMark=true; AKA_A2=A; ak_bmsc=1BF0653CF2B36E6B711B3BBE402E24E7~000000000000000000000000000000~...; bm_sz=2B314C125A28A0FBFB0808B10AC32880~...~3491395~3424567; page_type=productsearch; app_version=v4; bm_sv=9B870D5819BA421950F96774F2A2DC78~~1; _abck=59F693FA2C262E4EB9B6DF0D13FE55B8~-1~...~0~-1~-1; bm_sv=9B870D5819BA421950F96774F2A2DC78~~1; cart_api=v2; storeInfo=mafuae|en|AED',
  'Upgrade-Insecure-Requests': '1',
  'Sec-Fetch-Dest': 'document',
  'Sec-Fetch-Mode': 'navigate',
  'Sec-Fetch-Site': 'none',
  'Sec-Fetch-User': '?1',
  'Sec-GPC': '1',
  'TE': 'trailers'
}

# %%
response = requests.post(url, json=payload, headers=headers, proxies = {'https': proxy})
html = response.text
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File a:\BeOn_Repositories\amazon_jupyter\.venv\Lib\site-packages\urllib3\connectionpool.py:779, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     778 try:
# --> 779     self._prepare_proxy(conn)
#     780 except (BaseSSLError, OSError, SocketTimeout) as e:
#
# File a:\BeOn_Repositories\amazon_jupyter\.venv\Lib\site-packages\urllib3\connectionpool.py:1048, in HTTPSConnectionPool._prepare_proxy(self, conn)
#    1042 conn.set_tunnel(
#    1043     scheme=tunnel_scheme,
#    1044     host=self._tunnel_host,
#    1045     port=self.port,
#    1046     headers=self.proxy_headers,
#    1047 )
# -> 1048 conn.connect()
#
# ...

# %%
soup = BeautifulSoup(html, "html.parser")
data_grid = soup.find(id="__NEXT_DATA__").text
data_grid = json.loads(data_grid)
products = data_grid["props"]["initialState"]["search"]["products"]

# %%
print(products[2])
# Out:
# {'addToCartTrackingUrl': [], 'brand': None, 'bulkMessage': '', 'clickTrackingUrl': [], 'viewTrackingUrl': [], 'updateCartTrackingURL': [], 'rightClickTrackingURL': [], 'currency': 'AED', 'currencyPosition': 'right', 'discount': {'price': 17.45, 'type': 'percentage', 'value': 25, 'minBuyingValue': '17.45'}, 'foodType': 'DRY', 'image': {'href': 'https://cdn.mafrservices.com/sys-master-root/h33/hf0/12634803470366/1651801_main.jpg?im=Resize=200', 'altText': 'Starbucks House Blend Lungo Medium Roast By Nespresso Coffee ( 10 Capsules) 57g'}, 'newProductCardImage': 'https://cdn.mafrservices.com/sys-master-root/h33/hf0/12634803470366/1651801_main.jpg?im=Resize=1700', 'imageLibrary': [{'href': 'https://cdn.mafrservices.com/sys-master-root/h33/hf0/12634803470366/1651801_main.jpg?im=Resize=200', 'altText': 'Starbucks House Blend Lungo Medium Roast By Nespresso Coffee ( 10 Capsules) 57g'}, {'href': 'https://cdn.mafrservices.com/sys-master-root/hc7/h1b/12547413770270/1651801_1.jpg?im=Resize=200',
# ...

# %%
count=1
for product in products[0:20]:
    title = product.get('name', '')
    brand = product.get('brand', '')
    promotion = product.get('discount', '')
    sku = product.get('productId', '')
    old_price = product.get('originalPrice', 0)
    final_price = product.get('applicablePrice', 0)
    stock = 0 if product.get('isAvailable',0) == None else 1
    link = product.get('url', '')
    url = f"https://www.carrefouruae.com{link}"
    supplier = product.get('supplier', '')
    sponsored = product.get('isSponsored', '')# True or False, si no se puede capturar va vacio
    bestseller = True if product.get('promoBadges', '') != [] else False
    
    print(f"Title:{title}")
    print(f"Brand:{brand}")
    print(f"Promotion:{promotion}")
    print(f"SKU:{sku}")
    print(f"OldPrice:{old_price}")
    print(f"FinalPrice:{final_price}")
    print(f"Stock:{stock}")
    print(f"URL:{url}")
    print(f"Supplier:{supplier}")
    print(f"Producto:{count}")
    print(f"Sponsored: {sponsored}")
    print(f"BestSeller: {bestseller}\n")
    count += 1
# Out:
# Title:L&#39;or Espresso Lungo Profondo Intensity 8 Coffee 10 Capsules
# Brand:L'or
# Promotion:{'price': 0, 'type': 'none', 'value': 0, 'minBuyingValue': ''}
# SKU:1594557
# OldPrice:24.2
# FinalPrice:24.20
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/capsules/l-or-profondo-52g/p/1594557
# Supplier:Carrefour
# Producto:1
# Sponsored: True
# BestSeller: False
#
# Title:L&#39;or Espresso Sontuoso Intensity 8 Coffee 10 Capsules
# Brand:L'or
# Promotion:{'price': 0, 'type': 'none', 'value': 0, 'minBuyingValue': ''}
# SKU:1594558
# OldPrice:24.2
# FinalPrice:24.20
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/capsules/l-or-sontuoso-52g/p/1594558
# Supplier:Carrefour
# Producto:2
# Sponsored: True
# BestSeller: False
#
# Title:Starbucks House Blend Lungo Medium Roast By Nespresso Coffee ( 10 Capsules) 57g
# Brand:None
# Promotion:{'price': 17.45, 'type': 'percentage', 'value': 25, 'minBuyingValue': '17.45'}
# SKU:1651801
# OldPrice:23.25
# FinalPrice:17.45
# Stock:1
# ...

# %%
username = 'Ec0m37ry'
password = 'fK7Ulvdm8zSVnyn22+'
proxy = f"http://{username}:{password}@gate.smartproxy.com:10001"

headers = {
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'es-419,es;q=0.9',
  'cache-control': 'max-age=0',
  'cookie': 'mafuae-preferred-delivery-area=Unnamed%20Road%20-%20Mirdif%20 - %20Dubai%20; prevAreaCode=Unnamed%20Road%20-%20Mirdif%20 - %20Dubai%20; storeInfo=mafuae|en|AED',
  'priority': 'u=0, i',
  'sec-ch-ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36'
}
payload = ''

# %%
response = requests.post(url, json=payload, headers=headers, proxies = {'https': proxy}, timeout=15000)

# %%
html = response.text

# %%
soup = BeautifulSoup(html, "html.parser")
data_grid = soup.find(id="__NEXT_DATA__").text
data_grid = json.loads(data_grid)
products = data_grid["props"]["initialState"]["search"]["products"]

# %%
count=1
for product in products[0:20]:
    title = product.get('name', '')
    brand = product.get('brand', '')
    promotion = product.get('discount', '')
    sku = product.get('productId', '')
    old_price = product.get('originalPrice', 0)
    final_price = product.get('applicablePrice', 0)
    stock = 0 if product.get('isAvailable',0) == None else 1
    link = product.get('url', '')
    url = f"https://www.carrefouruae.com{link}"
    supplier = product.get('supplier', '')
    print(f"Title:{title}")
    print(f"Brand:{brand}")
    print(f"Promotion:{promotion}")
    print(f"SKU:{sku}")
    print(f"OldPrice:{old_price}")
    print(f"FinalPrice:{final_price}")
    print(f"Stock:{stock}")
    print(f"URL:{url}")
    print(f"Supplier:{supplier}")
    print(f"Producto:{count}\n")
    count += 1
# Out:
# Title:DeLonghi EN 80 CW Inissia Nespresso Capsules Coffee Maker
# Brand:DeLonghi
# Promotion:{'price': 398, 'type': 'percentage', 'value': 37, 'minBuyingValue': '398.00'}
# SKU:8004399327931
# OldPrice:629
# FinalPrice:398.00
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/capsule-coffee-maker/delonghi-en-80-cw-inissia-nespresso-capsules-coffee-maker/p/8004399327931
# Supplier:TransTech
# Producto:1
#
# Title:Lushh Stainless Steel Coffee Capsule Holder, 360 Degree Rotating Coffee Pod Holder Tower Rack Stand for 40 Nespresso Coffee Capsules, Black
# Brand:Lushh
# Promotion:{'price': 69.95, 'type': 'percentage', 'value': 30, 'minBuyingValue': '69.95'}
# SKU:7036008991197
# OldPrice:99.99
# FinalPrice:69.95
# Stock:1
# URL:https://www.carrefouruae.com/mafuae/en/metal-storage/lushh-stainless-steel-coffee-capsule-holder-360-degree-rotating-coffee-pod-holder-tower-rack-stand-for-40-nespresso-coffee-capsules-black/p/7036008991197
# Supplier:Lushh
# Producto:2
#
# ...
